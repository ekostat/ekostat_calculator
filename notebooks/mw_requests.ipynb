# %%
# Reload when code changed:
# %load_ext autoreload
# %autoreload 2
# %pwd
import sys
import os
path = "../"
sys.path.append(path)
#os.path.abspath("../")
print(os.path.abspath(path))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# D:\Utveckling\git\ekostat_calculator

# %%
import os 
import core
import logging
import importlib
importlib.reload(core) 
try:
    logging.shutdown()
    importlib.reload(logging)
except:
    pass
import pandas as pd
import numpy as np
import json

from event_handler import EventHandler
print(core.__file__)
pd.__version__
# Out:
# ..\core\__init__.py
# '0.19.2'

# %%
user_id_1 = 'user_1'
user_id_2 = 'user_2'
ekos = EventHandler(path)
user_1_ws_1 = 'mw1'
# Out:
# 2018-03-19 16:42:18,524	logger.py	85	add_log	DEBUG
# 2018-03-19 16:42:18,534	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-19 16:42:18,534	logger.py	87	add_log	DEBUG	### Log added for log_id "event_handler" at locaton: ..\log\main_event_handler.log
# 2018-03-19 16:42:18,534	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-03-19 16:42:18,534	event_handler.py	64	__init__	DEBUG	Start EventHandler: event_handler
# 2018-03-19 16:42:18,535	event_handler.py	65	__init__	DEBUG
# 2018-03-19 16:42:18,535	event_handler.py	66	__init__	INFO	TEST info logger
# 2018-03-19 16:42:18,535	event_handler.py	67	__init__	WARNING	TEST warning logger
# 2018-03-19 16:42:18,535	event_handler.py	68	__init__	ERROR	TEST error logger
# 2018-03-19 16:42:18,538	event_handler.py	69	__init__	DEBUG	TEST debug logger
# ====================================================================================================
# event_handler
# ..//log
# main
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# event_handler _ main_event_handler

# %%
ekos.copy_workspace(user_id_1, source_alias='default_workspace', target_alias=user_1_ws_1)
ekos.copy_workspace(user_id_1, source_alias='default_workspace', target_alias='mw2')

ekos.copy_workspace(user_id_2, source_alias='default_workspace', target_alias='test1')
ekos.copy_workspace(user_id_2, source_alias='default_workspace', target_alias='test2')
# Out:
# 2018-03-19 16:42:19,218	event_handler.py	230	copy_workspace	DEBUG	Could not add workspace with alias "mw1". Workspace already exists!
# 2018-03-19 16:42:19,229	event_handler.py	241	copy_workspace	DEBUG	Trying to copy workspace "default_workspace" with alias "default_workspace". Copy has alias "mw2"
# 2018-03-19 16:42:19,352	event_handler.py	230	copy_workspace	DEBUG	Could not add workspace with alias "test1". Workspace already exists!
# 2018-03-19 16:42:19,353	event_handler.py	230	copy_workspace	DEBUG	Could not add workspace with alias "test2". Workspace already exists!
# ¤ mw1
# ¤ user_1
# ¤ mw2
# ¤ user_1
# source_workspace_path: ..//workspaces/default_workspace
# target_workspace_path: ..//workspaces/6d49f82f-f2d7-43b5-8087-b4468d31aa80
# ¤ test1
# ¤ user_2
# ¤ test2
# ¤ user_2
# False

# %%
ekos.load_test_requests()

# %%
# Request workspace list 
request = ekos.test_requests['request_workspace_list']
response = ekos.request_workspace_list(request) 
ekos.write_test_response('request_workspace_list', response)
# Out:
# status ['editable', 'readable', 'deleted']
# status ['editable', 'readable', 'deleted']
# status ['editable', 'readable', 'deleted']
# status ['editable', 'readable', 'deleted']

# %%
# Request subset list 
request = ekos.test_requests['request_subset_list']
response_subset_list = ekos.request_subset_list(request)
ekos.write_test_response('request_subset_list', response_subset_list)
# Out:
# 2018-03-19 16:42:22,624	event_handler.py	1248	load_workspace	DEBUG	Trying to load workspace "335af11c-a7d4-4edf-bc21-d90ffb762c70" with alias "mw1"
# status ['editable', 'readable', 'deleted']
# status ['editable', 'readable', 'deleted']
# ¤¤¤ alias mw1
# ¤¤¤ unique_id 335af11c-a7d4-4edf-bc21-d90ffb762c70
# ¤¤¤ user_id user_1
#
# ====================================================================================================
# Initiating WorkSpace: ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70
# Parent directory is: ..//workspaces
# Resource directory is: ..//resources
# 2018-03-19 16:42:22,892	logger.py	85	add_log	DEBUG
# 2018-03-19 16:42:22,892	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-19 16:42:22,892	logger.py	87	add_log	DEBUG	### Log added for log_id "1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047" at locaton: ..\workspaces\335af11c-a7d4-4edf-bc21-d90ffb762c70\log\subset_1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047.log
# 2018-03-19 16:42:22,893	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-03-19 16:42:22,995	logger.py	85	add_log	DEBUG
# 2018-03-19 16:42:22,995	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-19 16:42:23,005	logger.py	87	add_log	DEBUG	### Log added for log_id "default_subset" at locaton: ..\workspaces\335af11c-a7d4-4edf-bc21-d90ffb762c70\log\subset_default_subset.log
# 2018-03-19 16:42:23,005	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# === 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# status ['editable', 'readable', 'deleted']
# !!! test_subset_1
# !!! 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# !!! ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets/1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# ===
# ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets/1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets/1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets/1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047/step_2
# ====================================================================================================
# 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/log
# subset
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047 _ main_event_handler
# 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047 _ subset_1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# === default_subset
# !!! default_subset
# !!! default_subset
# !!! ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets/default_subset
# ===
# ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets/default_subset
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets/default_subset/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/subsets/default_subset/step_2
# ====================================================================================================
# default_subset
# ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/log
# subset
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047', 'subset_default_subset'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# default_subset _ main_event_handler
# default_subset _ subset_1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# default_subset _ subset_default_subset
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/step_0
# 2018-03-19 16:42:23,225	logger.py	85	add_log	DEBUG
# 2018-03-19 16:42:23,225	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-19 16:42:23,235	logger.py	87	add_log	DEBUG	### Log added for log_id "335af11c-a7d4-4edf-bc21-d90ffb762c70" at locaton: ..\workspaces\335af11c-a7d4-4edf-bc21-d90ffb762c70\log\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log
# 2018-03-19 16:42:23,235	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# ====================================================================================================
# 335af11c-a7d4-4edf-bc21-d90ffb762c70
# ..//workspaces/335af11c-a7d4-4edf-bc21-d90ffb762c70/log
# workspace
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047', 'subset_default_subset', 'workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# 335af11c-a7d4-4edf-bc21-d90ffb762c70 _ main_event_handler
# 335af11c-a7d4-4edf-bc21-d90ffb762c70 _ subset_1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 335af11c-a7d4-4edf-bc21-d90ffb762c70 _ subset_default_subset
# 335af11c-a7d4-4edf-bc21-d90ffb762c70 _ workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70
# =====SUBSET_UUID "1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047"
# status ['editable', 'readable', 'deleted']
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# list_quality_elements []
# 2018-03-19 16:42:26,427	workspaces.py	1391	load_all_data	DEBUG	data has been loaded from existing all_data.txt file.
# 2018-03-19 16:42:26,427	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:26,509	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:26,558	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:26,558	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['CPHL_SLANG/CPHL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:26,696	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:26,837	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:26,837	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:26,847	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:26,847	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:26,920	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:26,921	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:26,921	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,020	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,053	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,101	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,103	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['CPHL_SLANG/CPHL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:27,229	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,359	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,359	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,359	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,363	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:27,455	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,455	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,456	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,556	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,602	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,632	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,652	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['CPHL_SLANG/CPHL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:27,764	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,906	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,906	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,907	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,907	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:27,987	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,987	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:27,990	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,092	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,148	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:28,214	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,221	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,371	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['CPHL_SLANG/CPHL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:28,506	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,507	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,507	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,507	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,600	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,600	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,600	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,691	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:28,742	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,772	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,774	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:28,918	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['CPHL_SLANG/CPHL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# 2018-03-19 16:42:29,038	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:29,038	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:29,039	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:29,039	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:29,131	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:29,131	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-19 16:42:29,131	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-97-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1473, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:29,225	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-97-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1473, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:29,322	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-97-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1473, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:29,372	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-97-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1473, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:29,385	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['CPHL_SLANG/CPHL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-97-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1473, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:29,539	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-97-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1473, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:29,682	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
# ...
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-97-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1473, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 540, in dict_subset
#     request=request.get('supporting_elements', []))
#   File "..\event_handler.py", line 990, in list_supporting_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:33,110	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-97-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1473, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 540, in dict_subset
#     request=request.get('supporting_elements', []))
#   File "..\event_handler.py", line 990, in list_supporting_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:33,120	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-97-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1473, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 540, in dict_subset
#     request=request.get('supporting_elements', []))
#   File "..\event_handler.py", line 990, in list_supporting_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:33,132	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# =====SUBSET_UUID "default_subset"
# status ['editable', 'readable', 'deleted']
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# list_quality_elements []
# list_supporting_elements []
# request []

# %%
# Load default data
request = ekos.test_requests['request_workspace_load_default_data']
response = ekos.request_workspace_load_default_data(request) 
print(response)
# Out:
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-98-0df1175139e3>", line 3, in <module>
#     response = ekos.request_workspace_load_default_data(request)
#   File "..\event_handler.py", line 1641, in request_workspace_load_default_data
#     all_ok = workspace_object.import_default_data(force=True)
#   File "..\core\workspaces.py", line 954, in import_default_data
#     self._logger.debug('Default data has been copied to workspace raw data folder.')
# Message: 'Default data has been copied to workspace raw data folder.'
# Arguments: ()
# 2018-03-19 16:42:35,566	workspaces.py	954	import_default_data	DEBUG	Default data has been copied to workspace raw data folder.
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-98-0df1175139e3>", line 3, in <module>
#     response = ekos.request_workspace_load_default_data(request)
#   File "..\event_handler.py", line 1645, in request_workspace_load_default_data
#     workspace_object.load_all_data()
#   File "..\core\workspaces.py", line 1393, in load_all_data
#     self._logger.debug('all_data.txt already loaded, delete it if you want to re-load it.')
# Message: 'all_data.txt already loaded, delete it if you want to re-load it.'
# Arguments: ()
# 2018-03-19 16:42:35,581	workspaces.py	1393	load_all_data	DEBUG	all_data.txt already loaded, delete it if you want to re-load it.
# {'all_ok': True, 'message': ''}

# %%
# Edit workspace
request = ekos.test_requests['request_workspace_edit']
response = ekos.request_workspace_edit(request)
# Out:
# status ['editable', 'readable']

# %%
# Delete workspace
request = ekos.test_requests['request_workspace_delete']
response = ekos.request_workspace_delete(request)
# Out:
# 2018-03-19 16:42:35,989	event_handler.py	335	delete_workspace	WARNING	Removing workspace "07f672c6-8637-4bbf-b110-a5115edc2617" with alias "test1".
# status ['editable', 'readable', 'deleted']

# %%
# Add new subset 
request = ekos.test_requests['request_subset_add']
response_subset_add = ekos.request_subset_add(request)
ekos.write_test_response('request_subset_add', response_subset_add)
# Out:
# 2018-03-19 16:42:36,146	event_handler.py	202	copy_subset	DEBUG	Trying to copy subset "default_subset". Copy has alias "test_subset_1"
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-101-e6dc216091ff>", line 3, in <module>
#     response_subset_add = ekos.request_subset_add(request)
#   File "..\event_handler.py", line 1290, in request_subset_add
#     subset_target_alias=new_alias)
#   File "..\event_handler.py", line 203, in copy_subset
#     return_dict = workspace_object.copy_subset(subset_source_alias, subset_target_alias)
#   File "..\core\workspaces.py", line 1088, in copy_subset
#     self._logger.debug('Could not add subset with alias "{}". Workspace already exists!'.format(target_alias))
# Message: 'Could not add subset with alias "test_subset_1". Workspace already exists!'
# Arguments: ()
# 2018-03-19 16:42:36,157	workspaces.py	1088	copy_subset	DEBUG	Could not add subset with alias "test_subset_1". Workspace already exists!
# 2018-03-19 16:42:36,179	event_handler.py	397	dict_time	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,181	event_handler.py	661	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,187	event_handler.py	661	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# SUBSET_SOURCE_UUID default_subset
# status ['editable', 'readable', 'deleted']
# SUBSET_SOURCE_ALIAS default_subset
# default_subset test_subset_1
# self.user_id user_1
# ¤ test_subset_1
# ¤ user_1
# target_uuid False
# RETURN_DICT False
# status ['editable', 'readable', 'deleted']
# SUBSET_UNIQUE_ID False
# SUBSET_UNIQUE_ID False
# 2018-03-19 16:42:36,188	event_handler.py	661	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,192	event_handler.py	661	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,195	event_handler.py	661	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,196	event_handler.py	661	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,198	event_handler.py	459	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,201	event_handler.py	459	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,203	event_handler.py	459	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,206	event_handler.py	459	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-19 16:42:36,208	event_handler.py	459	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# SUBSET_UNIQUE_ID False
# SUBSET_UNIQUE_ID False
# SUBSET_UNIQUE_ID False
# SUBSET_UNIQUE_ID False
# list_quality_elements []
# list_supporting_elements []
# request []

# %%
# Edit subset 
request = ekos.test_requests['request_subset_edit']
response_subset_edit = ekos.request_subset_edit(request)
ekos.write_test_response('request_subset_edit', response_subset_edit)
# Out:
# 2018-03-19 16:42:36,395	event_handler.py	781	get_workspace	DEBUG	Getting workspace "335af11c-a7d4-4edf-bc21-d90ffb762c70" with alias "None"
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 826, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:36,490	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 826, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:36,529	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# =====SUBSET_UUID "1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047"
# FILTER_LIST [2013, 2014, 2015]
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# FILTER_LIST []
# FILTER_LIST []
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# SUBSET_UNIQUE_ID 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# FILTER_LIST []
# list_quality_elements [{'label': 'bottom fauna', 'children': [{'label': 'BQI', 'status': 'not selectable', 'selected': False, 'value': 'bqi'}]}, {'label': 'macroalgae and macrophytes', 'children': [{'label': 'MSMDI', 'status': 'not selectable', 'selected': False, 'value': 'msmdi'}]}, {'label': 'phytoplankton', 'children': [{'label': 'Biovolume', 'status': 'not selectable', 'selected': False, 'value': 'biov'}, {'label': 'Chlorophyll', 'status': 'not selectable', 'selected': False, 'value': 'chl'}]}]
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 826, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:36,596	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 826, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:36,597	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 826, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:36,735	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['CPHL_SLANG/CPHL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 826, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:36,879	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 826, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:36,880	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
#     request=request.get('quality_elements', []))
#   File "..\event_handler.py", line 905, in list_quality_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 826, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:36,892	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 535, in dict_subset
# ...
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 540, in dict_subset
#     request=request.get('supporting_elements', []))
#   File "..\event_handler.py", line 990, in list_supporting_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:44,194	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 540, in dict_subset
#     request=request.get('supporting_elements', []))
#   File "..\event_handler.py", line 990, in list_supporting_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:44,207	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\335af11c-a7d4-4edf-bc21-d90ffb762c70\\log\\workspace_335af11c-a7d4-4edf-bc21-d90ffb762c70.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-102-e81d9d58d80c>", line 3, in <module>
#     response_subset_edit = ekos.request_subset_edit(request)
#   File "..\event_handler.py", line 1342, in request_subset_edit
#     response = self.list_subsets(user_id=user_id, workspace_unique_id=workspace_uuid, request=request_subset_list)
#   File "..\event_handler.py", line 953, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 540, in dict_subset
#     request=request.get('supporting_elements', []))
#   File "..\event_handler.py", line 990, in list_supporting_elements
#     request=request)
#   File "..\event_handler.py", line 473, in dict_quality_element
#     request=request_dict)}
#   File "..\event_handler.py", line 842, in list_indicators
#     request=request_dict)
#   File "..\event_handler.py", line 367, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1283, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1260, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-19 16:42:44,224	workspaces.py	1260	get_filtered_data	DEBUG	STEP: step_1
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['NTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# "['PTOT'] not in index"
# subset 1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047
# =====SUBSET_UUID "default_subset"
# status ['editable', 'readable', 'deleted']
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# SUBSET_UNIQUE_ID default_subset
# list_quality_elements []
# list_supporting_elements []
# request []

# %%
w_id = '335af11c-a7d4-4edf-bc21-d90ffb762c70'
s_id = '1bdd7eb5-2f2a-44f6-bd7e-c26bf09ce047'

# %%
w = ekos.get_workspace(user_id=user_id_1, unique_id=w_id)
# Out:
# 2018-03-19 16:43:10,297	event_handler.py	781	get_workspace	DEBUG	Getting workspace "335af11c-a7d4-4edf-bc21-d90ffb762c70" with alias "None"

# %%
w.index_handler.data_handler_object.all_data.head()
# Out:
#    Unnamed: 0  AMON BIOV_CONC_ALL BQIm DEPH   DIN DOXY_BTL DOXY_CTD  LATIT_DD  \
# 0           0  0.20                       0   0.3     6.34      6.1  56.94063
# 1           1  0.20                       5   0.3     6.32      6.1  56.94063
# 2           2  0.20                      10   0.3     6.33      6.0  56.94063
# 3           3  0.20                      15  0.96     5.40      4.8  56.94063
# 4           4  0.20                      20  5.23     4.10      3.8  56.94063
#
#    LONGI_DD  ...  SHARKID_MD5 SHIPC           STATN  STIME TEMP_BTL TEMP_CTD  \
# 0  12.21162  ...               34EB  N14 FALKENBERG  00:40             13.01
# 1  12.21162  ...               34EB  N14 FALKENBERG  00:40             13.00
# 2  12.21162  ...               34EB  N14 FALKENBERG  00:40    13.01    13.00
# 3  12.21162  ...               34EB  N14 FALKENBERG  00:40             14.09
# 4  12.21162  ...               34EB  N14 FALKENBERG  00:40             14.64
#
#   WATER_DISTRICT WATER_TYPE_AREA WLTYP MONTH
# 0                                         10
# 1                                         10
# 2                                         10
# 3                                         10
# 4                                         10
#
# [5 rows x 49 columns]

# %%
# w.index_handler.booleans

# %%
# Apply data filter step_0
ekos.apply_data_filter(user_id=user_id_1,  
                           workspace_uuid=w_id,
                           step='step_0')
# Out:
# step step_0

# %%
# Apply data filter step_1
ekos.apply_data_filter(user_id=user_id_1,  
                           workspace_uuid=w_id,
                           subset_uuid=s_id, 
                           step='step_1')
# Out:
# step step_1

# %%
# Apply indicator data filter (step_2) 
indicator = 'din_winter'
water_body_1 = '575340-113000' # Tex: Marstrandsfjorden, WB=3
water_body_2 = '572072-115880' # Tex: Varren, WB=1s
ekos.apply_indicator_data_filter(user_id=user_id_1,  
                                 workspace_uuid=w_id,
                                 subset_uuid=s_id, 
                                 indicator=indicator, 
                                 water_body=water_body_1)
# Out:
# step step_2
# water_body 575340-113000
# 3-s
# 3
# s
# Series([], Name: DEPH_INTERVAL, dtype: object)
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-116-ed9862dd2617> in <module>()
#       7                                  subset_uuid=s_id,
#       8                                  indicator=indicator,
# ----> 9                                  water_body=water_body_1)
#
# D:\Utveckling\git\ekostat_calculator\event_handler.py in apply_indicator_data_filter(self, user_id, workspace_uuid, subset_uuid, indicator, water_body, step)
#     165                                                indicator=indicator,
#     166                                                water_body=water_body,
# --> 167                                                step=step)
#     168         return all_ok
#     169
#
# D:\Utveckling\git\ekostat_calculator\core\workspaces.py in apply_indicator_data_filter(self, subset, indicator, water_body, step)
#    1039             filter_object = step_object.get_indicator_data_filter_settings(indicator)
#    1040
# -> 1041         all_ok = self.index_handler.add_filter(filter_object=filter_object, step=step, subset=subset, indicator=indicator, water_body=water_body)
#    1042         return all_ok
#    1043
#
# D:\Utveckling\git\ekostat_calculator\core\index_handler.py in add_filter(self, filter_object, subset, step, water_body, indicator)
#     226                                   filter_object=filter_object,
#     227                                   df=df,
# --> 228                                   wb=water_body)
#     229
#     230
#
# D:\Utveckling\git\ekostat_calculator\core\index_handler.py in _add_boolean_to_dict(self, filter_object, df, wb, *args)
#      82                 if bool_dict.get('boolean') is not None:
#      83                     # Merge boolean from parent with new boolean from filter_object
# ---> 84                     bool_dict[key]['boolean'] = bool_dict.get('boolean') & filter_object.get_filter_boolean_for_df(df, water_body=wb)
#      85
#      86                 else:
#
# D:\Utveckling\git\ekostat_calculator\core\filters.py in get_filter_boolean_for_df(self, df, water_body)
#     743 #        get_type_area_for_water_body(wb, include_suffix=False)
#     744         return self.settings.get_filter_boolean_for_df(df=df,
# --> 745                                                        water_body=water_body)
#     746
#     747
#
# D:\Utveckling\git\ekostat_calculator\core\filters.py in get_filter_boolean_for_df(self, df, water_body)
#     654                 boolean = self._get_boolean_from_interval(df=df,
#     655                                                           type_area=type_area,
# --> 656                                                           variable=variable)
#     657             elif variable in self.list_columns:
#     658                 boolean = self._get_boolean_from_list(df=df,
#
# D:\Utveckling\git\ekostat_calculator\core\filters.py in _get_boolean_from_interval(self, df, type_area, variable)
#     678     def _get_boolean_from_interval(self, df=None, type_area=None, variable=None):
#     679         from_value, to_value = self.get_value(type_area=type_area,
# --> 680                                               variable=variable)
#     681
#     682         parameter = variable.split('_')[0]
#
# D:\Utveckling\git\ekostat_calculator\core\filters.py in get_value(self, variable, type_area)
#     533         print(suf)
#     534         print(value)
# --> 535         assert len(value) == 1, 'More than one setting for given filter_dict\n{}'.format(value)
#     536
#     537         value = value.values[0]
#
# AssertionError: More than one setting for given filter_dict
# Series([], Name: DEPH_INTERVAL, dtype: object)

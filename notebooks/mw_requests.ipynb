# %%
# Reload when code changed:
# %load_ext autoreload
# %autoreload 2
# %pwd
import sys
import os
path = "../"
sys.path.append(path)
#os.path.abspath("../")
print(os.path.abspath(path))
# Out:
# D:\Utveckling\git\ekostat_calculator

# %%
import os 
import core
import logging
import importlib
importlib.reload(core) 
try:
    logging.shutdown()
    importlib.reload(logging)
except:
    pass
import pandas as pd
import numpy as np
import json
import time

from event_handler import EventHandler
print(core.__file__)
pd.__version__
# Out:
# ..\core\__init__.py
# '0.19.2'

# %%
user_id_1 = 'user_1'
user_id_2 = 'user_2'
user_1_ws_1 = 'mw1'
print(path)
paths = {'user_id': user_id_1, 
         'workspace_directory': path + '/workspaces', 
         'resource_directory': path + '/resources', 
         'log_directory': path + '/log', 
         'test_data_directory': path + '/test_data'}

# ekos = EventHandler(**paths)
# Out:
# ../

# %%
def update_workspace_uuid_in_test_requests(workspace_alias=False):
    ekos = EventHandler(**paths)
    
    workspace_uuid = None
    if workspace_alias:
        workspace_uuid = ekos.get_unique_id_for_alias(workspace_alias=workspace_alias)
    else:
        uuid_list_for_user = ekos.get_workspaces_for_user(status=['editable'])
        if uuid_list_for_user: 
            workspace_uuid = uuid_list_for_user[0]
    
    
    if workspace_uuid: 
        workspace_uuid = uuid_list_for_user[0]
        print('Updating user {} with uuid: {}'.format(user_id_1, workspace_uuid))
        print('-'*70)
        ekos.update_workspace_uuid_in_test_requests(workspace_uuid)
    else:
        print('No workspaces for user: {}'.format(user_id_1))

# %%
def update_subset_uuid_in_test_requests(workspace_alias=False, 
                                        subset_alias=False):
    ekos = EventHandler(**paths)

    uuid_list_for_user = ekos.get_workspaces_for_user(status=['editable'])
    workspace_uuid = None
    if uuid_list_for_user:
        workspace_uuid = uuid_list_for_user[0]
        print('Updating user {} with uuid: {}'.format(user_id_1, workspace_uuid))
        print('-'*70)
        ekos.update_workspace_uuid_in_test_requests(workspace_uuid)
    else:
        print('No workspaces for user: {}'.format(user_id_1))

# %%
# ekos.copy_workspace(user_id_1, source_alias='default_workspace', target_alias=user_1_ws_1)
# ekos.copy_workspace(user_id_1, source_alias='default_workspace', target_alias='mw2')

# ekos.copy_workspace(user_id_2, source_alias='default_workspace', target_alias='test1')
# ekos.copy_workspace(user_id_2, source_alias='default_workspace', target_alias='test2')

# %% [markdown]
# #### Load test requests

# %%
# ekos.load_test_requests()

# %%
ekos = EventHandler(**paths)
ekos.print_workspaces()
# Out:
# 2018-06-01 11:40:16,829	logger.py	85	add_log	DEBUG
# 2018-06-01 11:40:16,832	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-06-01 11:40:16,833	logger.py	87	add_log	DEBUG	### Log added for log_id "event_handler" at locaton: ..\log\main_event_handler.log
# 2018-06-01 11:40:16,835	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-06-01 11:40:16,838	event_handler.py	74	__init__	DEBUG	Start EventHandler: event_handler
# ====================================================================================================
# event_handler
# ..//log
# main
# ----------------------------------------------------------------------------------------------------
# ====================================================================================================
# Current workspaces for user are:
#
# uuid                                    alias                         status
# ----------------------------------------------------------------------------------------------------
# default_workspace                       default_workspace             readable
# 448eeeaa-50db-4873-a840-61bfba3cc719    New test workspace            editable
# 9ffb9abd-ce92-47ff-abaa-d98a81284ebd    Another test workspace        editable
# ====================================================================================================

# %% [markdown]
# ### Request workspace list

# %%
t0 = time.time()
ekos = EventHandler(**paths)
request = ekos.test_requests['request_workspace_list']
response = ekos.request_workspace_list(request) 
ekos.write_test_response('request_workspace_list', response)
print('-'*50)
print('Time for request: {}'.format(time.time()-t0))
# Out:
# 2018-06-01 11:25:10,479	event_handler.py	74	__init__	DEBUG	Start EventHandler: event_handler
# 2018-06-01 11:25:15,362	event_handler.py	2097	request_workspace_list	DEBUG	Start: request_workspace_list
# 2018-06-01 11:25:15,381	event_handler.py	2102	request_workspace_list	DEBUG	Time for excecuting request_workspace_list: 0.018999814987182617
# --------------------------------------------------
# Time for request: 4.9150002002716064

# %% [markdown]
# ### Request workspace add

# %%
t0 = time.time()
ekos = EventHandler(**paths)
request = ekos.test_requests['request_workspace_add_1']
response_workspace_add = ekos.request_workspace_add(request)
ekos.write_test_response('request_workspace_add_1', response_workspace_add)

request = ekos.test_requests['request_workspace_add_2']
response_workspace_add = ekos.request_workspace_add(request)
ekos.write_test_response('request_workspace_add_2', response_workspace_add)
print('-'*50)
print('Time for request: {}'.format(time.time()-t0))
# Out:
# 2018-06-01 10:34:36,243	logger.py	85	add_log	DEBUG
# 2018-06-01 10:34:36,243	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-06-01 10:34:36,253	logger.py	87	add_log	DEBUG	### Log added for log_id "event_handler" at locaton: ..\log\main_event_handler.log
# 2018-06-01 10:34:36,253	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-06-01 10:34:36,253	event_handler.py	74	__init__	DEBUG	Start EventHandler: event_handler
# ====================================================================================================
# event_handler
# ..//log
# main
# ----------------------------------------------------------------------------------------------------
# 2018-06-01 10:34:41,277	event_handler.py	1955	request_workspace_add	DEBUG	Start: request_workspace_add
# 2018-06-01 10:34:41,291	event_handler.py	242	copy_workspace	DEBUG	Trying to copy workspace "default_workspace". Copy has alias "New test workspace"
# 2018-06-01 10:34:41,474	event_handler.py	1955	request_workspace_add	DEBUG	Start: request_workspace_add
# 2018-06-01 10:34:41,479	event_handler.py	242	copy_workspace	DEBUG	Trying to copy workspace "default_workspace". Copy has alias "Another test workspace"
# ¤ New test workspace
# ¤ Another test workspace
# --------------------------------------------------
# Time for request: 5.363000154495239

# %% [markdown]
# #### Update workspace uuid in test requests

# %%
update_workspace_uuid_in_test_requests()
# Out:
# 2018-06-01 10:35:40,340	event_handler.py	74	__init__	DEBUG	Start EventHandler: event_handler
# Updating user user_1 with uuid: 448eeeaa-50db-4873-a840-61bfba3cc719
# ----------------------------------------------------------------------
# Updating workspace_uuid in file: request_subset_add_1.txt
# Updating workspace_uuid in file: request_subset_add_2.txt
# Updating workspace_uuid in file: request_subset_info.txt
# Updating workspace_uuid in file: request_subset_info_simple.txt
# Updating workspace_uuid in file: request_subset_list.txt
# Updating workspace_uuid in file: request_workspace_data_sources_edit.txt
# Updating workspace_uuid in file: request_workspace_data_sources_list.txt
# Updating workspace_uuid in file: request_workspace_delete.txt
# Updating workspace_uuid in file: request_workspace_edit.txt
# Updating workspace_uuid in file: request_workspace_load_default_data.txt

# %% [markdown]
# ### Request subset list

# %%
t0 = time.time()
ekos = EventHandler(**paths)
request = ekos.test_requests['request_subset_list']
response_subset_list = ekos.request_subset_list(request)
ekos.write_test_response('request_subset_list', response_subset_list)
print('-'*50)
print('Time for request: {}'.format(time.time()-t0))
# Out:
# 2018-06-01 11:48:19,736	event_handler.py	74	__init__	DEBUG	Start EventHandler: event_handler
# 2018-06-01 11:48:24,366	event_handler.py	1949	request_subset_list	DEBUG	Start: request_subset_list
# 2018-06-01 11:48:24,370	event_handler.py	1657	load_workspace	DEBUG	Trying to load new workspace "448eeeaa-50db-4873-a840-61bfba3cc719" with alias "New test workspace"
# ====================================================================================================
# Initiating WorkSpace: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719
# Parent directory is: ..//workspaces
# Resource directory is: ..//resources
# === 288a1b04-952f-40e9-a4b0-e943b3821c3c
# !!! test_subset_2
# !!! 288a1b04-952f-40e9-a4b0-e943b3821c3c
# !!! ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c
# ===
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c/step_2
# === 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# !!! test_subset_1
# !!! 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# !!! ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# ===
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3/step_2
# === default_subset
# !!! default_subset
# !!! default_subset
# !!! ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset
# ===
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset/step_1
# load_water_body_station_filter
# 2018-06-01 11:48:24,877	event_handler.py	1675	load_workspace	INFO	Workspace "448eeeaa-50db-4873-a840-61bfba3cc719" with alias "New test workspace loaded."
# 2018-06-01 11:48:26,393	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 11:48:26,398	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 11:48:26,440	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 11:48:26,482	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 11:48:26,524	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 11:48:26,561	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset/step_2
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/step_0
# No data selected to be loaded!
# 2018-06-01 11:48:26,615	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 11:48:26,621	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,625	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,628	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,632	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,637	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,644	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,650	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,659	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,664	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,669	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,674	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,677	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,682	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,687	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,690	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,694	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,697	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,700	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,704	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,708	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,713	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,719	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,722	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,726	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,754	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 11:48:26,763	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 11:48:26,804	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# No data available after "merge_all_data"!
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 11:48:26,846	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 11:48:26,891	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 11:48:26,939	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 11:48:26,986	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 11:48:26,991	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,994	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:26,998	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,000	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,008	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,011	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,015	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,018	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,022	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,026	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,030	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,033	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,037	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,042	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,047	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,053	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,059	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,063	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,068	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,072	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,075	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,078	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,082	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,087	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,111	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 11:48:27,124	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# No data available after "merge_all_data"!
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 11:48:27,196	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 11:48:27,253	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 11:48:27,303	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 11:48:27,349	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 11:48:27,401	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 11:48:27,407	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,415	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,421	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,426	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,430	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,434	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,438	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,442	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,445	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,448	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,453	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,458	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,463	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,469	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,474	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,478	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,482	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,487	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,490	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,494	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,498	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,503	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,508	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,513	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,524	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,529	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,538	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,542	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,545	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,549	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,553	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,556	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,566	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,571	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,577	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,582	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,604	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# No data available after "merge_all_data"!
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 11:48:27,612	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 11:48:27,667	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 11:48:27,726	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 11:48:27,781	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 11:48:27,832	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 11:48:27,886	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 11:48:27,889	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,894	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,900	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,905	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,912	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,921	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,925	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,930	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,934	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,939	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,943	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,956	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,964	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,971	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,978	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,981	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,987	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,992	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,995	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:27,999	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,003	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,007	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,011	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,017	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,043	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 11:48:28,052	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# No data available after "merge_all_data"!
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 11:48:28,096	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 11:48:28,147	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 11:48:28,193	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 11:48:28,242	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 11:48:28,283	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 11:48:28,287	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,296	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,299	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,305	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,314	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,317	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,322	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,326	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,329	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,337	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,343	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,348	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,352	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,359	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,363	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,366	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,371	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,374	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,378	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,382	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,387	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,399	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,405	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,410	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,414	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,416	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,420	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,426	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,429	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,432	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,436	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,441	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,448	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,455	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,459	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,466	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,472	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,477	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,480	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,483	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# No data available after "merge_all_data"!
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# 2018-06-01 11:48:28,487	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,491	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,496	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,505	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,509	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,514	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,519	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,525	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,533	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,538	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,542	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,546	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,550	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,557	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,562	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,568	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,576	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,582	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,587	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,591	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,598	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,601	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,605	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,609	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,613	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,619	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,624	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,629	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,634	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,637	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,651	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,654	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,659	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,664	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,671	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,679	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,689	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# 2018-06-01 11:48:28,695	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,700	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,705	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,709	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,714	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,719	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,725	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,741	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 11:48:28,747	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 11:48:28,795	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 11:48:28,846	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 11:48:28,898	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 11:48:28,944	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 11:48:28,984	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 11:48:28,987	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,992	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:28,998	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,002	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,006	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,010	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,014	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,018	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,021	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,027	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,034	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,039	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,046	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,050	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,054	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,058	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,065	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,070	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,077	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,087	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,090	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,094	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,097	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:29,103	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# No data available after "merge_all_data"!
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# 2018-06-01 11:48:30,685	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 11:48:30,685	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 11:48:30,708	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 11:48:30,764	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 11:48:30,801	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 11:48:30,836	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 11:48:30,883	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# No data selected to be loaded!
# 2018-06-01 11:48:30,886	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,891	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,895	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,899	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,902	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,906	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,909	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,912	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,914	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,921	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,927	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,932	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,939	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,945	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,949	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,954	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,959	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,963	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,971	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,975	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,982	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,986	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,989	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:30,993	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:31,015	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 11:48:31,022	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 11:48:31,054	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# No data available after "merge_all_data"!
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# ...
# 2018-06-01 11:48:32,506	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,510	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,517	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,524	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,527	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,532	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,538	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,548	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,550	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,555	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,558	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,562	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,566	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,570	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# No data available after "merge_all_data"!
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# 2018-06-01 11:48:32,574	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,578	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,582	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,585	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,591	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,597	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,601	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,605	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,613	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,618	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,622	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,625	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,630	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,633	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,637	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,640	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,643	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,650	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,655	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,662	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,666	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,669	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,672	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,677	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,681	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,684	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,688	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,691	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,695	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,701	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,706	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,711	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,720	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,725	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,728	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,732	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,736	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,739	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,743	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,754	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,762	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,768	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:32,772	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# 2018-06-01 11:48:32,785	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 11:48:32,792	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 11:48:32,830	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 11:48:32,867	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 11:48:32,908	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 11:48:32,953	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 11:48:33,004	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 11:48:33,009	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,013	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,020	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,023	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,027	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,033	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,038	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,041	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,046	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,051	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,055	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,061	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,064	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,067	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,072	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,078	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,085	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,090	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,096	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,104	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,108	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,112	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,117	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 11:48:33,124	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# No data available after "merge_all_data"!
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# --------------------------------------------------
# Time for request: 15.343000173568726

# %% [markdown]
# ### Request workspace load default data

# %%
t0 = time.time()
ekos = EventHandler(**paths)
# When copying data the first time all sources has status=0, i.e. no data will be loaded. 
request = ekos.test_requests['request_workspace_load_default_data']
response_subset_list = ekos.request_workspace_load_default_data(request)
ekos.write_test_response('request_workspace_load_default_data', response_subset_list)
print('-'*50)
print('Time for request: {}'.format(time.time()-t0))
# Out:
# 2018-06-01 11:50:59,058	event_handler.py	74	__init__	DEBUG	Start EventHandler: event_handler
# 2018-06-01 11:51:03,871	event_handler.py	2207	request_workspace_load_default_data	DEBUG	Start: request_workspace_load_default_data
# 2018-06-01 11:51:03,884	event_handler.py	1657	load_workspace	DEBUG	Trying to load new workspace "448eeeaa-50db-4873-a840-61bfba3cc719" with alias "New test workspace"
# ====================================================================================================
# Initiating WorkSpace: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719
# Parent directory is: ..//workspaces
# Resource directory is: ..//resources
# === 288a1b04-952f-40e9-a4b0-e943b3821c3c
# !!! test_subset_2
# !!! 288a1b04-952f-40e9-a4b0-e943b3821c3c
# !!! ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c
# ===
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c/step_2
# === 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# !!! test_subset_1
# !!! 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# !!! ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# ===
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3/step_2
# === default_subset
# !!! default_subset
# !!! default_subset
# !!! ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset
# ===
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset/step_2
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/step_0
# 2018-06-01 11:51:04,312	event_handler.py	1675	load_workspace	INFO	Workspace "448eeeaa-50db-4873-a840-61bfba3cc719" with alias "New test workspace loaded."
# 2018-06-01 11:51:04,339	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: chlorophyll_integrated_2015_2016_row_format.txt
# 2018-06-01 11:51:04,391	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: chlorophyll_sharkweb_data_chlorophyll_wb_2007-2017_20180320.txt
# 2018-06-01 11:51:04,429	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: physicalchemicalmodel_110001_PROFILER_alldepths_SE652400-223501_toolbox.dat
# 2018-06-01 11:51:04,471	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: physicalchemicalmodel_120004_PROFILER_alldepths_SE612520-172080_toolbox.dat
# 2018-06-01 11:51:04,629	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: physicalchemical_sharkweb_data_fyskem_wb_2007-2017_20180320.txt
# 2018-06-01 11:51:04,729	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: phytoplankton_2016_row_format.txt
# 2018-06-01 11:51:04,869	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: phytoplankton_sharkweb_data_biovolume_wb_2007-2012_20180320.txt
# 2018-06-01 11:51:05,013	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: phytoplankton_sharkweb_data_biovolume_wb_2013-2017_20180320.txt
# 2018-06-01 11:51:05,098	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: zoobenthos_2016_row_format_2.txt
# 2018-06-01 11:51:05,147	workspaces.py	1006	import_default_data	DEBUG	Default data file has been copied to workspace raw data folder: zoobenthos_sharkweb_data_BQIm_wb_2007-2017_20180320.txt
# 2018-06-01 11:51:05,164	workspaces.py	1585	load_all_data	DEBUG	Method load_all_data is forced.
# 2018-06-01 11:51:05,176	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 11:51:05,183	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 11:51:05,231	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 11:51:05,272	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 11:51:05,311	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 11:51:05,347	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/input_data/exports\all_data.pkl
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/input_data/exports\all_data.txt
# No data selected to be loaded!
# 2018-06-01 11:51:05,388	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# No data available after "merge_all_data"!
# --------------------------------------------------
# Time for request: 6.348999738693237

# %%
ekos.workspaces.keys()
# Out:
# dict_keys(['3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f'])

# %% [markdown]
# ### Request data source list

# %%
# request = ekos.test_requests['request_workspace_data_sources_list']
# response = ekos.request_workspace_data_sources_list(request) 
# print(response)

t0 = time.time()
ekos = EventHandler(**paths)
request = ekos.test_requests['request_workspace_data_sources_list']
response = ekos.request_workspace_data_sources_list(request) 
ekos.write_test_response('request_workspace_data_sources_list', response)
print('-'*50)
print('Time for request: {}'.format(time.time()-t0))
# Out:
# 2018-05-31 08:37:36,494	event_handler.py	74	__init__	DEBUG	Start EventHandler: event_handler
# 2018-05-31 08:37:36,494	event_handler.py	75	__init__	DEBUG
# 2018-05-31 08:37:36,494	event_handler.py	76	__init__	INFO	TEST info logger
# 2018-05-31 08:37:36,494	event_handler.py	77	__init__	WARNING	TEST warning logger
# 2018-05-31 08:37:36,495	event_handler.py	78	__init__	ERROR	TEST error logger
# 2018-05-31 08:37:36,495	event_handler.py	79	__init__	DEBUG	TEST debug logger
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset', 'workspace_3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# event_handler _ main_event_handler
# 2018-05-31 08:37:41,250	event_handler.py	2127	request_workspace_data_sources_list	DEBUG	Start: request_workspace_data_sources_list
# 2018-05-31 08:37:41,251	event_handler.py	1622	load_workspace	DEBUG	Trying to load new workspace "3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f" with alias "New test workspace"
# status ['editable', 'readable', 'deleted']
#
# ====================================================================================================
# Initiating WorkSpace: ..//workspaces/3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f
# Parent directory is: ..//workspaces
# Resource directory is: ..//resources
# === default_subset
# !!! default_subset
# !!! default_subset
# !!! ..//workspaces/3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f/subsets/default_subset
# ===
# ..//workspaces/3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f/subsets/default_subset
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f/subsets/default_subset/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f/subsets/default_subset/step_2
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset', 'workspace_3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# default_subset _ main_event_handler
# default_subset _ subset_default_subset
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f/step_0
# 2018-05-31 08:37:41,654	event_handler.py	1640	load_workspace	INFO	Workspace "3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f" with alias "New test workspace loaded."
# 2018-05-31 08:37:41,654	event_handler.py	2136	request_workspace_data_sources_list	DEBUG	Time for excecuting request_workspace_data_sources_list: 0.40399765968322754
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset', 'workspace_3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# 3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f _ main_event_handler
# 3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f _ subset_default_subset
# 3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f _ workspace_3045c7c6-4a25-4e6b-aa69-cf6fe2fe1f8f
# --------------------------------------------------
# Time for request: 5.160937786102295

# %% [markdown]
# ### Request data source edit

# %%
t0 = time.time()
ekos = EventHandler(**paths)
request = ekos.test_requests['request_workspace_data_sources_edit']
response = ekos.request_workspace_data_sources_edit(request) 
ekos.write_test_response('request_workspace_data_sources_edit', response)
print('-'*50)
print('Time for request: {}'.format(time.time()-t0))
# Out:
# 2018-05-30 10:03:42,393	event_handler.py	71	__init__	DEBUG	Start EventHandler: event_handler
# 2018-05-30 10:03:42,395	event_handler.py	72	__init__	DEBUG
# 2018-05-30 10:03:42,397	event_handler.py	73	__init__	INFO	TEST info logger
# 2018-05-30 10:03:42,400	event_handler.py	74	__init__	WARNING	TEST warning logger
# 2018-05-30 10:03:42,402	event_handler.py	75	__init__	ERROR	TEST error logger
# 2018-05-30 10:03:42,405	event_handler.py	76	__init__	DEBUG	TEST debug logger
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset', 'workspace_f4a6a7da-7588-4bef-b12d-14e6d98e02a0'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# event_handler _ main_event_handler
# 2018-05-30 10:03:46,048	event_handler.py	2098	request_workspace_data_sources_edit	DEBUG	Start: request_workspace_data_sources_list
# --------------------------------------------------
# Time for request: 3.6619999408721924

# %% [markdown]
# ### Request workspace edit

# %%
t0 = time.time()
ekos = EventHandler(**paths)
request = ekos.test_requests['request_workspace_edit']
response = ekos.request_workspace_edit(request) 
ekos.write_test_response('request_workspace_edit', response)
print('-'*50)
print('Time for request: {}'.format(time.time()-t0))
# Out:
# 2018-05-31 08:54:36,390	logger.py	85	add_log	DEBUG
# 2018-05-31 08:54:36,392	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-05-31 08:54:36,393	logger.py	87	add_log	DEBUG	### Log added for log_id "event_handler" at locaton: ..\log\main_event_handler.log
# 2018-05-31 08:54:36,395	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-05-31 08:54:36,397	event_handler.py	74	__init__	DEBUG	Start EventHandler: event_handler
# 2018-05-31 08:54:36,401	event_handler.py	75	__init__	DEBUG
# 2018-05-31 08:54:36,402	event_handler.py	76	__init__	INFO	TEST info logger
# 2018-05-31 08:54:36,404	event_handler.py	77	__init__	WARNING	TEST warning logger
# 2018-05-31 08:54:36,405	event_handler.py	78	__init__	ERROR	TEST error logger
# 2018-05-31 08:54:36,408	event_handler.py	79	__init__	DEBUG	TEST debug logger
# ====================================================================================================
# event_handler
# ..//log
# main
# ----------------------------------------------------------------------------------------------------
# 2018-05-31 08:54:40,080	event_handler.py	2016	request_workspace_edit	DEBUG	Start: request_workspace_edit
# --------------------------------------------------
# Time for request: 3.691999912261963

# %% [markdown]
# ### Request workspace delete

# %%
workspace_uuid_2 = ekos.get_unique_id_for_alias(workspace_alias='Another test workspace', user_id=user_id_1) 
ekos.update_workspace_uuid_in_test_requests(workspace_uuid_2, filename='request_workspace_delete.txt')

t0 = time.time()
ekos = EventHandler(**paths)
request = ekos.test_requests['request_workspace_delete']
response = ekos.request_workspace_delete(request) 
ekos.write_test_response('request_workspace_delete', response)
print('-'*50)
print('Time for request: {}'.format(time.time()-t0))
# Out:
# 2018-05-24 15:41:20,253	event_handler.py	1925	request_workspace_delete	DEBUG	Start: request_workspace_delete
# 2018-05-24 15:41:20,265	event_handler.py	342	delete_workspace	WARNING	Removing workspace "333b38e3-2519-4f6a-8701-2285c305f261" with alias "Another test workspace".
# Updating workspace_uuid in file: request_workspace_delete.txt
# status ['editable', 'readable', 'deleted']

# %% [markdown]
# ### Request subset add

# %%
t0 = time.time()
ekos = EventHandler(**paths)
request = ekos.test_requests['request_subset_add_1']
response_subset_add = ekos.request_subset_add(request)
ekos.write_test_response('request_subset_add_1', response_subset_add)

request = ekos.test_requests['request_subset_add_2']
response_subset_add = ekos.request_subset_add(request)
ekos.write_test_response('request_subset_add_2', response_subset_add)
print('-'*50)
print('Time for request: {}'.format(time.time()-t0))
# Out:
# 2018-06-01 10:35:55,819	event_handler.py	74	__init__	DEBUG	Start EventHandler: event_handler
# 2018-06-01 10:36:00,898	event_handler.py	1702	request_subset_add	DEBUG	Start: request_subset_add
# 2018-06-01 10:36:00,917	event_handler.py	1623	load_workspace	DEBUG	Trying to load new workspace "448eeeaa-50db-4873-a840-61bfba3cc719" with alias "New test workspace"
# 2018-06-01 10:36:01,019	logger.py	85	add_log	DEBUG
# 2018-06-01 10:36:01,023	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-06-01 10:36:01,025	logger.py	87	add_log	DEBUG	### Log added for log_id "default_subset" at locaton: ..\workspaces\448eeeaa-50db-4873-a840-61bfba3cc719\log\subset_default_subset.log
# 2018-06-01 10:36:01,033	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# status ['editable', 'readable', 'deleted']
#
# ====================================================================================================
# Initiating WorkSpace: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719
# Parent directory is: ..//workspaces
# Resource directory is: ..//resources
# === default_subset
# !!! default_subset
# !!! default_subset
# !!! ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset
# ===
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset/step_2
# ====================================================================================================
# default_subset
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/log
# subset
# ----------------------------------------------------------------------------------------------------
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/step_0
# 2018-06-01 10:36:01,359	logger.py	85	add_log	DEBUG
# 2018-06-01 10:36:01,364	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-06-01 10:36:01,368	logger.py	87	add_log	DEBUG	### Log added for log_id "448eeeaa-50db-4873-a840-61bfba3cc719" at locaton: ..\workspaces\448eeeaa-50db-4873-a840-61bfba3cc719\log\workspace_448eeeaa-50db-4873-a840-61bfba3cc719.log
# 2018-06-01 10:36:01,370	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-06-01 10:36:01,373	event_handler.py	1641	load_workspace	INFO	Workspace "448eeeaa-50db-4873-a840-61bfba3cc719" with alias "New test workspace loaded."
# 2018-06-01 10:36:01,375	event_handler.py	210	copy_subset	DEBUG	Trying to copy subset "default_subset"
# ====================================================================================================
# 448eeeaa-50db-4873-a840-61bfba3cc719
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/log
# workspace
# ----------------------------------------------------------------------------------------------------
# ¤ test_subset_1
# target_uuid 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# source_subset_path: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset
# target_subset_path: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# === 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# status ['editable', 'readable', 'deleted']
# !!!
# 2018-06-01 10:36:01,641	logger.py	85	add_log	DEBUG
# 2018-06-01 10:36:01,643	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-06-01 10:36:01,650	logger.py	87	add_log	DEBUG	### Log added for log_id "86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3" at locaton: ..\workspaces\448eeeaa-50db-4873-a840-61bfba3cc719\log\subset_86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3.log
# 2018-06-01 10:36:01,655	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# test_subset_1
# !!! 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# !!! ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# ===
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3/step_2
# ====================================================================================================
# 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/log
# subset
# ----------------------------------------------------------------------------------------------------
# status ['editable', 'readable', 'deleted', 'inactive']
# 2018-06-01 10:36:03,713	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 10:36:03,727	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 10:36:03,788	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 10:36:03,841	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 10:36:03,901	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# No data selected to be loaded!
# 2018-06-01 10:36:03,962	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 10:36:04,032	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 10:36:04,037	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,047	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,052	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,057	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,061	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,067	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,074	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,079	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,083	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,090	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,094	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,099	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,107	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,111	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,114	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,120	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,124	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,128	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,133	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,138	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,144	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,148	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,155	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,159	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,176	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 10:36:04,183	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 10:36:04,228	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# No data available after "merge_all_data"!
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 10:36:04,298	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 10:36:04,362	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 10:36:04,419	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 10:36:04,480	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 10:36:04,486	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,495	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,503	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,507	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,512	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,517	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,525	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,536	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,538	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,548	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,552	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,558	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,563	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,566	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,571	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,574	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,578	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,583	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,589	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,593	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,598	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,602	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,609	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,615	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,639	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 10:36:04,649	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# No data available after "merge_all_data"!
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 10:36:04,705	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 10:36:04,747	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 10:36:04,794	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 10:36:04,838	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 10:36:04,882	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 10:36:04,887	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,893	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,897	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,908	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,916	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,920	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,925	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,930	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,934	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,938	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,944	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,949	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,953	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,960	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,963	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,967	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,973	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,977	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,983	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:04,991	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,001	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,005	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,009	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,017	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,023	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,027	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,030	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,034	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,041	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,047	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,056	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,060	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,064	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,067	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,074	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,082	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# No data available after "merge_all_data"!
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# 2018-06-01 10:36:05,108	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 10:36:05,115	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 10:36:05,154	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 10:36:05,200	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 10:36:05,244	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 10:36:05,291	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 10:36:05,340	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 10:36:05,343	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,348	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,351	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,356	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,360	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,364	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,371	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,374	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,377	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,382	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,388	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,403	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,407	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,415	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,422	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,427	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,432	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,438	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,442	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,447	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,455	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,461	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,466	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,473	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,488	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 10:36:05,494	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 10:36:05,536	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# No data available after "merge_all_data"!
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 10:36:05,576	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 10:36:05,624	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 10:36:05,665	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 10:36:05,713	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 10:36:05,718	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,724	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,732	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,741	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,744	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,747	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,751	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,756	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,759	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,762	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,766	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,769	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,775	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,782	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,785	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,790	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,797	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,807	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,811	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,815	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,819	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,825	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,829	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,835	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,843	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,848	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,851	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,856	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,859	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,862	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,868	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,872	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,875	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,880	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,885	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,889	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,893	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,897	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,903	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,912	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# No data available after "merge_all_data"!
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# 2018-06-01 10:36:05,915	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,923	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,931	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,935	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,939	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,944	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,947	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,951	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,961	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,963	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,968	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,972	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,975	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,979	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,984	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,989	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:05,994	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,000	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,008	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,012	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,017	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,021	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,026	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,032	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,035	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,040	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,043	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,047	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,050	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,055	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,061	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,070	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,079	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,083	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,091	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,099	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,102	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,108	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,111	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,119	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# 2018-06-01 10:36:06,126	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,131	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,134	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,142	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,161	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 10:36:06,169	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 10:36:06,218	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# 2018-06-01 10:36:06,266	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 10:36:06,309	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 10:36:06,374	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 10:36:06,417	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 10:36:06,430	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,434	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,447	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,452	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,455	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,461	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,466	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,472	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,480	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,485	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,489	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,499	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,505	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,508	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,515	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,524	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,529	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,533	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,540	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,547	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,551	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,555	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,562	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,567	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:06,572	event_handler.py	1724	request_subset_add	DEBUG	Time for excecuting request_subset_add: 5.673999786376953
# No data available after "merge_all_data"!
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DIN' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['NTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PHOS' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['PTOT' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BQIm'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['DOXY'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 86e52d04-7ddc-4c28-9cc8-eb0a9779e1e3
# "['SECCHI' 'SALT'] not in index"
# 2018-06-01 10:36:06,729	event_handler.py	1702	request_subset_add	DEBUG	Start: request_subset_add
# 2018-06-01 10:36:06,740	event_handler.py	1634	load_workspace	DEBUG	Workspace "448eeeaa-50db-4873-a840-61bfba3cc719" with alias "New test workspace" is already loaded. Set reload=True if you want to reload the workspace.
# 2018-06-01 10:36:06,740	event_handler.py	1641	load_workspace	INFO	Workspace "448eeeaa-50db-4873-a840-61bfba3cc719" with alias "New test workspace loaded."
# 2018-06-01 10:36:06,741	event_handler.py	210	copy_subset	DEBUG	Trying to copy subset "default_subset"
# 2018-06-01 10:36:06,881	logger.py	85	add_log	DEBUG
# 2018-06-01 10:36:06,891	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-06-01 10:36:06,891	logger.py	87	add_log	DEBUG	### Log added for log_id "288a1b04-952f-40e9-a4b0-e943b3821c3c" at locaton: ..\workspaces\448eeeaa-50db-4873-a840-61bfba3cc719\log\subset_288a1b04-952f-40e9-a4b0-e943b3821c3c.log
# 2018-06-01 10:36:06,891	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# status ['editable', 'readable', 'deleted']
# ¤ test_subset_2
# target_uuid 288a1b04-952f-40e9-a4b0-e943b3821c3c
# source_subset_path: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/default_subset
# target_subset_path: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c
# === 288a1b04-952f-40e9-a4b0-e943b3821c3c
# status ['editable', 'readable', 'deleted']
# !!! test_subset_2
# !!! 288a1b04-952f-40e9-a4b0-e943b3821c3c
# !!! ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c
# ===
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/subsets/288a1b04-952f-40e9-a4b0-e943b3821c3c/step_2
# ====================================================================================================
# 288a1b04-952f-40e9-a4b0-e943b3821c3c
# ..//workspaces/448eeeaa-50db-4873-a840-61bfba3cc719/log
# subset
# ...
# 2018-06-01 10:36:11,304	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,308	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,312	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,321	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,326	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,330	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,339	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# No data available after "merge_all_data"!
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# 2018-06-01 10:36:11,343	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,352	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,358	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,366	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,375	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,384	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,387	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,395	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,405	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,416	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,422	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,426	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,430	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,437	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,442	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,447	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,451	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,455	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,460	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,467	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,470	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,475	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,478	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,483	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,488	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,493	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,497	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,501	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,509	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,514	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,521	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,526	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,530	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,536	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,539	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,544	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# 2018-06-01 10:36:11,552	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,557	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,562	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,566	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,570	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,574	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,578	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,587	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,593	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,600	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,608	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,617	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,624	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,645	workspaces.py	1593	load_all_data	DEBUG	No data to load.
# 2018-06-01 10:36:11,654	workspaces.py	1255	delete_all_export_data	DEBUG	All files in export directory are deleted and all "loaded" in datatype_settings is 0.
# 2018-06-01 10:36:11,715	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemical
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# No data selected to be loaded!
# 2018-06-01 10:36:11,759	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: physicalchemicalmodel
# 2018-06-01 10:36:11,810	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: chlorophyll
# 2018-06-01 10:36:11,858	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: phytoplankton
# 2018-06-01 10:36:11,905	workspaces.py	1661	load_datatype_data	DEBUG	New data files has been loaded for datatype: zoobenthos
# 2018-06-01 10:36:11,911	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,917	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,925	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,931	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,937	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,946	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,955	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,958	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,964	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,968	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,974	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,983	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,990	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:11,994	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,003	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,013	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,017	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,023	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,030	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,036	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,043	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,048	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,054	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,058	workspaces.py	1410	get_filtered_data	DEBUG	STEP: step_1
# 2018-06-01 10:36:12,063	event_handler.py	1724	request_subset_add	DEBUG	Time for excecuting request_subset_add: 5.334000110626221
# No data available after "merge_all_data"!
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DIN' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['NTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PHOS' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['PTOT' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BQIm'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['DOXY'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['BIOV_CONC_ALL' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['CPHL_INTEG' 'CPHL_INTEG_CALC' 'SALT'] not in index"
# subset 288a1b04-952f-40e9-a4b0-e943b3821c3c
# "['SECCHI' 'SALT'] not in index"
# --------------------------------------------------
# Time for request: 16.3989999294281

# %% [markdown]
# ### Request subset edit

# %%
update_workspace_uuid_in_test_requests()
request = ekos.test_requests['request_subset_edit']
response_subset_edit = ekos.request_subset_edit(request)
ekos.write_test_response('request_subset_edit', response_subset_edit)

# %%
# Edit subset 
request = ekos.test_requests['request_subset_edit']
response_subset_edit = ekos.request_subset_edit(request)
ekos.write_test_response('request_subset_edit', response_subset_edit)
# Out:
# 2018-05-24 16:14:41,179	event_handler.py	1702	request_subset_edit	DEBUG	Start: request_subset_edit
# 2018-05-24 16:14:41,185	event_handler.py	965	get_workspace	DEBUG	Getting workspace "f4a6a7da-7588-4bef-b12d-14e6d98e02a0" with alias "None"

# %%
w_id = '1a77220d-e76a-4224-a98c-8c0c234150d9'
s_id = 'fa499f4c-ad1e-4978-b38a-510b672d5a7e'

# %%
w = ekos.get_workspace(user_id=user_id_1, unique_id=w_id)
# Out:
# 2018-05-24 16:14:41,464	event_handler.py	965	get_workspace	DEBUG	Getting workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "None"

# %%
w.index_handler.data_handler_object.all_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-71c6b3c00950> in <module>()
# ----> 1 w.index_handler.data_handler_object.all_data.head()
#
# AttributeError: 'NoneType' object has no attribute 'index_handler'

# %%
# w.index_handler.booleans

# %%
# Apply data filter step_0
ekos.apply_data_filter(user_id=user_id_1,  
                           workspace_uuid=w_id,
                           step='step_0')
# Out:
# step step_0

# %%
# Apply data filter step_1
ekos.apply_data_filter(user_id=user_id_1,  
                           workspace_uuid=w_id,
                           subset_uuid=s_id, 
                           step='step_1')
# Out:
# step step_1

# %%
# Apply indicator data filter (step_2) 
indicator = 'din_winter'
water_body_1 = 'SE575340-113000' # Marstrandsfjorden, type_area=3
water_body_2 = 'SE572072-115880' # Varren, type_area=1s
water_body_3 = 'SE582000-112350' # Yttre Brofjorden, type_area=1n
ekos.apply_indicator_data_filter(user_id=user_id_1,  
                                 workspace_uuid=w_id,
                                 subset_uuid=s_id, 
                                 indicator=indicator, 
                                 water_body=water_body_3)
# Out:
# step step_2
# WWW SE582000-112350
# ===
# water_body SE582000-112350
# type_area 1-n
# RESULT [[0, 10]]

# %%
directory = 'D:/temp_ekostat'
data_step_0 = w.get_filtered_data(step=0)
data_step_0.to_csv('{}/data_step_0.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# 2018-03-23 10:33:03,469	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_0
# water_body None

# %%
directory = 'D:/temp_ekostat'
data_step_1 = w.get_filtered_data(step=1, subset=s_id)
data_step_1.to_csv('{}/data_step_1.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# 2018-03-23 10:33:09,968	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None

# %%
directory = 'D:/temp_ekostat'
data_step_2 = w.get_filtered_data(step=2, subset=s_id, indicator=indicator, water_body=water_body_3)
data_step_2.to_csv('{}/data_step_2.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# 2018-03-23 10:33:13,908	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_2
# water_body SE582000-112350

# %%
w.index_handler.data_handler_object.all_data.columns
# Out:
# Index(['Unnamed: 0', 'AMON', 'BIOV_CONC_ALL', 'BQIm', 'CPHL_INTEG', 'DEPH',
#        'DIN', 'DOXY_BTL', 'DOXY_CTD', 'LATIT_DD', 'LONGI_DD', 'MNDEP', 'MXDEP',
#        'MYEAR', 'NTOT', 'NTRA', 'NTRI', 'NTRZ', 'PHOS', 'PTOT', 'Q_AMON',
#        'Q_BIOV_CONC_ALL', 'Q_BQIm', 'Q_CPHL_INTEG', 'Q_DOXY_BTL', 'Q_DOXY_CTD',
#        'Q_NTOT', 'Q_NTRA', 'Q_NTRI', 'Q_NTRZ', 'Q_PHOS', 'Q_PTOT',
#        'Q_SALT_BTL', 'Q_SALT_CTD', 'Q_SECCHI', 'Q_TEMP_BTL', 'Q_TEMP_CTD',
#        'SALT_BTL', 'SALT_CTD', 'SDATE', 'SEA_BASIN', 'SECCHI', 'SERNO',
#        'SHARKID_MD5', 'SHIPC', 'STATN', 'STIME', 'TEMP_BTL', 'TEMP_CTD',
#        'VISS_EU_CD', 'WATER_BODY_NAME', 'WATER_DISTRICT', 'WATER_TYPE_AREA',
#        'WLTYP', 'MONTH'],
#       dtype='object')

# %%
din_winter = w.get_indicator_settings_data_filter_object(subset=s_id, indicator=indicator)
boolean = din_winter.get_filter_boolean_for_df(w.index_handler.data_handler_object.all_data, water_body=water_body_3) 
w.index_handler.data_handler_object.all_data.loc[boolean, :].to_csv('{}/test_data.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# WWW SE582000-112350
# ===
# water_body SE582000-112350
# type_area 1-n
# 1-n
# type_area_type_area 1-n
# 1-n
# 1
# n
# Index(['TYPE_AREA_NUMBER', 'TYPE_AREA_SUFFIX', 'DEPH_INTERVAL', 'MIN_NR_YEARS',
#        'MIN_NR_VALUES', 'TIME_DELTA_TOLERANCE', 'POS_RADIUS_TOLERANCE',
#        'DEPH_TOLERANCE', 'MONTH_LIST', 'EKV REF', 'EKV H/G', 'EKV G/M',
#        'EKV M/O', 'EKV O/D', 'EK H/G', 'EK G/M', 'EK M/O', 'EK O/D',
#        'SALINITY MAX'],
#       dtype='object')
# ----
# 0    0-10
# Name: DEPH_INTERVAL, dtype: object <class 'pandas.core.series.Series'>
# ['0-10'] <class 'numpy.ndarray'>
# 0-10
# 0-10
# DEPH_INTERVAL
# = [0, 10] <class 'int'>
# RESULT [[0, 10]]
# 1-n
# type_area_type_area 1-n
# 1-n
# 1
# n
# Index(['TYPE_AREA_NUMBER', 'TYPE_AREA_SUFFIX', 'DEPH_INTERVAL', 'MIN_NR_YEARS',
#        'MIN_NR_VALUES', 'TIME_DELTA_TOLERANCE', 'POS_RADIUS_TOLERANCE',
#        'DEPH_TOLERANCE', 'MONTH_LIST', 'EKV REF', 'EKV H/G', 'EKV G/M',
#        'EKV M/O', 'EKV O/D', 'EK H/G', 'EK G/M', 'EK M/O', 'EK O/D',
#        'SALINITY MAX'],
#       dtype='object')
# ----
# 0    12;1;2;3
# Name: MONTH_LIST, dtype: object <class 'pandas.core.series.Series'>
# ['12;1;2;3'] <class 'numpy.ndarray'>
# 12;1;2;3
# 12;1;2;3
# MONTH_LIST
# = [12, 1, 2, 3] <class 'int'>

# %%
# all_data = w.index_handler.data_handler_object.all_data 
# boolean = din_winter.get_filter_boolean_for_df(df=all_data, water_body=water_body_3)
# din_winter_data = all_data.loc[boolean, :]
# din_winter_data.to_csv('{}/din_winter_data.txt'.format(directory), sep='\t', index=False, encoding='cp1252')

# %%
# np.where(din_winter.settings.temp_boolean_list)

# %%
type_area = ekos.mapping_objects['water_body'].get_list('type_area', water_body='SE'+water_body_3)
print(type_area)
indicator_settings_response = ekos.dict_indicator_settings(workspace_unique_id=w_id, 
                                                           subset_unique_id=s_id,
                                                           indicator=indicator, 
                                                           type_area=type_area)
# Out:
# []
# ==================================================
# 1a77220d-e76a-4224-a98c-8c0c234150d9
# fa499f4c-ad1e-4978-b38a-510b672d5a7e
# din_winter
# ==================================================

# %%
indicator_settings_response
# Out:
# {}

# %%
# Subset info  
ekos.load_test_requests()
request = ekos.test_requests['request_subset_info_simple']
response_subset_info = ekos.request_subset_info(request)
ekos.write_test_response('request_subset_info', response_subset_info)
# Out:
# 2018-03-26 11:33:26,758	event_handler.py	1600	request_subset_info	DEBUG	Start: request_subset_info
# 2018-03-26 11:33:26,759	event_handler.py	919	get_workspace	DEBUG	Getting workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "None"
# status ['editable', 'readable', 'deleted', 'inactive']
# 2018-03-26 11:33:28,681	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,692	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,701	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,716	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,853	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,863	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,864	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,873	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset
# 2018-03-26 11:33:28,886	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,905	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,921	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,937	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,959	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,969	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,979	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:28,990	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:29,132	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,139	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,146	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,163	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,184	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,196	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,215	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,234	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area
# 2018-03-26 11:33:29,411	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,429	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,440	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,450	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  11
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 1
# type_area_type_area 1
# type_area_type_area 1
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 12
# type_area_type_area 12
# type_area_type_area 12
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 16
# type_area_type_area 16
# type_area_type_area 16
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 11:33:29,623	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,634	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,637	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,667	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,681	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,694	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,715	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,734	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,753	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,768	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,781	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,795	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:29,918	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,932	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,940	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,953	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,971	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:29,987	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,005	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,019	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,043	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,056	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,065	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,080	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:30,210	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,222	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,227	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,240	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,263	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,285	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,303	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,322	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,336	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,354	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,367	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,383	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:30,512	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,525	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,531	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,545	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,566	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,579	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,595	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,615	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,631	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,645	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,660	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,672	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:30,807	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,822	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,828	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,846	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,866	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,883	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,900	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,916	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,933	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,950	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,962	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:30,978	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:31,113	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,121	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,131	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,168	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,185	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,205	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,222	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,235	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,248	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,258	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,274	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,286	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:31,422	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,435	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,443	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,460	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,484	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,497	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,515	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,535	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,554	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,566	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,582	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,593	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:31,717	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,729	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,734	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,757	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,775	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,790	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,808	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,822	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,844	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,855	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,865	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:31,880	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:32,008	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,012	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,021	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,040	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,062	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,075	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,090	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,113	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 13
# 2018-03-26 11:33:32,301	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,321	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,322	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,326	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 16
# type_area_type_area 16
# type_area_type_area 16
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:32,448	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,461	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,465	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,479	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,495	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,505	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,531	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,550	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 12n
# 2018-03-26 11:33:32,721	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,742	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,752	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,767	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,902	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 16
# type_area_type_area 16
# type_area_type_area 16
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:32,912	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,912	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,914	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,931	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,942	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,958	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:32,977	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 6
# type_area_type_area 6
# 2018-03-26 11:33:33,196	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,216	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,217	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,228	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# type_area_type_area 6
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 16
# type_area_type_area 16
# type_area_type_area 16
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:33,378	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,394	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,401	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,422	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,441	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,457	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,472	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,494	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area
# 2018-03-26 11:33:33,717	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,727	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,728	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,736	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  20
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 16
# type_area_type_area 16
# type_area_type_area 16
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:33,885	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,896	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,903	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,920	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,940	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,956	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,972	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:33,995	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area
# 2018-03-26 11:33:34,204	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,224	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,225	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,233	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  1s
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 16
# type_area_type_area 16
# type_area_type_area 16
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:34,374	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,391	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,400	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,420	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,439	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,455	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,470	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,493	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 10
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 18
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 7
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 23
# type_area_type_area 1s
# type_area_type_area 1s
# type_area_type_area 1s
# 2018-03-26 11:33:34,749	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,750	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,753	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,768	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 20
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 22
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 12n
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 13
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 14
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 11
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 6
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 8
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 25
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 1n
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 12s
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 15
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 24
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 2
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 17
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 9
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 5
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 4
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 3
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 19
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 21
# type_area_type_area 16
# type_area_type_area 16
# type_area_type_area 16
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:34,927	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,939	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,942	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,961	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,979	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:34,994	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,012	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,030	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,045	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,061	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,074	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,090	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 11:33:35,244	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,253	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,260	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,276	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,295	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,328	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,344	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 11:33:35,362	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None

# %%
ekos.request
# Out:
# {'active': True,
#  'alias': 'test_subset_1',
#  'areas': [{'active': False,
#    'children': [{'active': False,
#      'children': [{'active': False,
#        'label': 'Örefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE633000-195000',
#        'value': 'SE633000-195000'},
#       {'active': False,
#        'label': 'Mjölefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE633710-200500',
#        'value': 'SE633710-200500'},
#       {'active': False,
#        'label': 'Österfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634200-202033',
#        'value': 'SE634200-202033'},
#       {'active': False,
#        'label': 'Västerfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634230-201605',
#        'value': 'SE634230-201605'},
#       {'active': False,
#        'label': 'Ytterbodafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634640-203710',
#        'value': 'SE634640-203710'},
#       {'active': False,
#        'label': 'Täftefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634740-203020',
#        'value': 'SE634740-203020'},
#       {'active': False,
#        'label': 'Lillfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634950-202940',
#        'value': 'SE634950-202940'},
#       {'active': False,
#        'label': 'Ostnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE635040-204196',
#        'value': 'SE635040-204196'},
#       {'active': False,
#        'label': 'Hörnefors området sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE635660-199490',
#        'value': 'SE635660-199490'},
#       {'active': False,
#        'label': 'Megrundsområdet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE636150-199220',
#        'value': 'SE636150-199220'},
#       {'active': False,
#        'label': 'Fjärdgrundsområdet sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE636570-203590',
#        'value': 'SE636570-203590'},
#       {'active': False,
#        'label': 'Österlångslädan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE636910-204040',
#        'value': 'SE636910-204040'},
#       {'active': False,
#        'label': 'Raggavaviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE637070-204260',
#        'value': 'SE637070-204260'},
#       {'active': False,
#        'label': 'Yttre Täftefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE637310-204860',
#        'value': 'SE637310-204860'},
#       {'active': False,
#        'label': 'Tavlefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE637640-204160',
#        'value': 'SE637640-204160'}],
#      'label': '20 - Norra Kvarkens inre kustvatten',
#      'status': 'selectable',
#      'type': 'value',
#      'value': '20'},
#     {'active': False,
#      'children': [{'active': False,
#        'label': 'S n Kvarkens kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE633550-200700',
#        'value': 'SE633550-200700'},
#       {'active': False,
#        'label': 'N n Kvarkens kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE635300-205251',
#        'value': 'SE635300-205251'}],
#      'label': '21 - Norra Kvarkens yttre kustvatten',
#      'status': 'selectable',
#      'type': 'value',
#      'value': '21'},
#     {'active': False,
#      'children': [{'active': False,
#        'label': 'Bygdefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640240-205500',
#        'value': 'SE640240-205500'},
#       {'active': False,
#        'label': 'Ricklefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640400-205770',
#        'value': 'SE640400-205770'},
#       {'active': False,
#        'label': 'Sikeåfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640900-205935',
#        'value': 'SE640900-205935'},
#       {'active': False,
#        'label': 'Vändskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641000-210500',
#        'value': 'SE641000-210500'},
#       {'active': False,
#        'label': 'Gumbodafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641250-210560',
#        'value': 'SE641250-210560'},
#       {'active': False,
#        'label': 'Lövselefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641745-211570',
#        'value': 'SE641745-211570'},
#       {'active': False,
#        'label': 'Kallviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641875-212250',
#        'value': 'SE641875-212250'},
#       {'active': False,
#        'label': 'Blackefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE642035-212600',
#        'value': 'SE642035-212600'},
#       {'active': False,
#        'label': 'Bjuröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE642950-213400',
#        'value': 'SE642950-213400'},
#       {'active': False,
#        'label': 'Bäckfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643160-212730',
#        'value': 'SE643160-212730'},
#       {'active': False,
#        'label': 'Storsladan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643550-211920',
#        'value': 'SE643550-211920'},
#       {'active': False,
#        'label': 'Burefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643700-211940',
#        'value': 'SE643700-211940'},
#       {'active': False,
#        'label': 'Simpan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643920-211500',
#        'value': 'SE643920-211500'},
#       {'active': False,
#        'label': 'Ytterviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644030-218500',
#        'value': 'SE644030-218500'},
#       {'active': False,
#        'label': 'Sörfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644040-211260',
#        'value': 'SE644040-211260'},
#       {'active': False,
#        'label': 'Skelleftehamnsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644070-211650',
#        'value': 'SE644070-211650'},
#       {'active': False,
#        'label': 'Ursviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644150-211000',
#        'value': 'SE644150-211000'},
#       {'active': False,
#        'label': 'Boviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644730-210650',
#        'value': 'SE644730-210650'},
#       {'active': False,
#        'label': 'Inre Kågefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645000-212100',
#        'value': 'SE645000-212100'},
#       {'active': False,
#        'label': 'Kågefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645000-213500',
#        'value': 'SE645000-213500'},
#       {'active': False,
#        'label': 'Bredviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645130-211040',
#        'value': 'SE645130-211040'},
#       {'active': False,
#        'label': 'Rösnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645340-211330',
#        'value': 'SE645340-211330'},
#       {'active': False,
#        'label': 'Byskefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645500-212000',
#        'value': 'SE645500-212000'},
#       {'active': False,
#        'label': 'Sandvikssundet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645670-214290',
#        'value': 'SE645670-214290'},
#       {'active': False,
#        'label': 'Tåmfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645830-212300',
#        'value': 'SE645830-212300'},
#       {'active': False,
#        'label': 'Åbyfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645950-212650',
#        'value': 'SE645950-212650'},
#       {'active': False,
#        'label': 'Hålfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE647260-212660',
#        'value': 'SE647260-212660'},
#       {'active': False,
#        'label': 'Kinnbäcksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650280-213110',
#        'value': 'SE650280-213110'},
#       {'active': False,
#        'label': 'Bursfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650460-213400',
#        'value': 'SE650460-213400'},
#       {'active': False,
#        'label': 'Jävrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650750-213500',
#        'value': 'SE650750-213500'},
#       {'active': False,
#        'label': 'Bondöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651075-213700',
#        'value': 'SE651075-213700'},
#       {'active': False,
#        'label': 'Vargödraget',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651475-214300',
#        'value': 'SE651475-214300'},
#       {'active': False,
#        'label': 'Yttrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651500-213108',
#        'value': 'SE651500-213108'},
#       {'active': False,
#        'label': 'Baggholmsdraget',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651800-214740',
#        'value': 'SE651800-214740'},
#       {'active': False,
#        'label': 'Inrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651818-212790',
#        'value': 'SE651818-212790'},
#       {'active': False,
#        'label': 'Haraholmsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651940-213930',
#        'value': 'SE651940-213930'},
#       {'active': False,
#        'label': 'Nördfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652000-213210',
#        'value': 'SE652000-213210'},
#       {'active': False,
#        'label': 'Mjoöfjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652000-214000',
#        'value': 'SE652000-214000'},
#       {'active': False,
#        'label': 'Storfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652066-214400',
#        'value': 'SE652066-214400'},
#       {'active': False,
#        'label': 'Davids stenar',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652075-213500',
#        'value': 'SE652075-213500'},
#       {'active': False,
#        'label': 'Rävahavet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652150-213000',
#        'value': 'SE652150-213000'},
#       {'active': False,
#        'label': 'Bärtnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652250-213000',
#        'value': 'SE652250-213000'},
#       {'active': False,
#        'label': 'Håkansöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652250-213430',
#        'value': 'SE652250-213430'},
#       {'active': False,
#        'label': 'Brändöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652385-214180',
#        'value': 'SE652385-214180'},
#       {'active': False,
#        'label': 'Mannöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652400-220070',
#        'value': 'SE652400-220070'},
#       {'active': False,
#        'label': 'Sandgrönnfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652450-222116',
#        'value': 'SE652450-222116'},
#       {'active': False,
#        'label': 'Bastafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652465-214080',
#        'value': 'SE652465-214080'},
#       {'active': False,
#        'label': 'Holfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652475-215750',
#        'value': 'SE652475-215750'},
#       {'active': False,
#        'label': 'Harrbäcksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652500-213500',
#        'value': 'SE652500-213500'},
#       {'active': False,
#        'label': 'Germandöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652686-221500',
#        'value': 'SE652686-221500'},
#       {'active': False,
#        'label': 'Västantillfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652830-222116',
#        'value': 'SE652830-222116'},
#       {'active': False,
#        'label': 'Bastaskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652855-224000',
#        'value': 'SE652855-224000'},
#       {'active': False,
#        'label': 'Sörbrändöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652920-222650',
#        'value': 'SE652920-222650'},
#       {'active': False,
#        'label': 'Saxskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653116-224623',
#        'value': 'SE653116-224623'},
#       {'active': False,
#        'label': 'Degeröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653140-224000',
#        'value': 'SE653140-224000'},
#       {'active': False,
#        'label': 'Sandöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653176-222000',
#        'value': 'SE653176-222000'},
#       {'active': False,
#        'label': 'Hindersöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653303-222900',
#        'value': 'SE653303-222900'},
#       {'active': False,
#        'label': 'Hamnöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653740-222800',
#        'value': 'SE653740-222800'},
#       {'active': False,
#        'label': 'Fjuksöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653900-223280',
#        'value': 'SE653900-223280'},
#       {'active': False,
#        'label': 'S. Sigfridsöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654000-222430',
#        'value': 'SE654000-222430'},
#       {'active': False,
#        'label': 'Båtöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654110-224850',
#        'value': 'SE654110-224850'},
#       {'active': False,
#        'label': 'Tistersöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654200-222920',
#        'value': 'SE654200-222920'},
#       {'active': False,
#        'label': 'Bergöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654291-224000',
#        'value': 'SE654291-224000'},
#       {'active': False,
#        'label': 'N. Sigfridsöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654330-222200',
#        'value': 'SE654330-222200'},
#       {'active': False,
#        'label': 'Skomakarfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654360-235780',
#        'value': 'SE654360-235780'},
#       {'active': False,
#        'label': 'Gussöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654470-222700',
#        'value': 'SE654470-222700'},
#       {'active': False,
#        'label': 'Börstskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654490-220870',
#        'value': 'SE654490-220870'},
#       {'active': False,
#        'label': 'Repskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654500-232000',
#        'value': 'SE654500-232000'},
#       {'active': False,
#        'label': 'Haparandafjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654560-246250',
#        'value': 'SE654560-246250'},
#       {'active': False,
#        'label': 'Rånöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654570-225230',
#        'value': 'SE654570-225230'},
#       {'active': False,
#        'label': 'Seskaröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654575-234250',
#        'value': 'SE654575-234250'},
#       {'active': False,
#        'label': 'Rånefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654820-222660',
#        'value': 'SE654820-222660'},
#       {'active': False,
#        'label': 'Ersnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654860-219880',
#        'value': 'SE654860-219880'},
#       {'active': False,
#        'label': 'Siknäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654990-224540',
#        'value': 'SE654990-224540'},
#       {'active': False,
#        'label': 'Måttsundsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655120-220380',
#        'value': 'SE655120-220380'},
#       {'active': False,
#        'label': 'Möröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655180-218660',
#        'value': 'SE655180-218660'},
#       {'active': False,
#        'label': 'Törefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655260-224280',
#        'value': 'SE655260-224280'},
#       {'active': False,
#        'label': 'Mulöviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656300-222750',
#        'value': 'SE656300-222750'},
#       {'active': False,
#        'label': 'Granöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656620-222480',
#        'value': 'SE656620-222480'},
#       {'active': False,
#        'label': 'Bergnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656840-222800',
#        'value': 'SE656840-222800'},
#       {'active': False,
#        'label': 'Yttre Lulefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE728806-179329',
#        'value': 'SE728806-179329'},
#       {'active': False,
#        'label': 'Inre Lulefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE729159-179002',
#        'value': 'SE729159-179002'},
#       {'active': False,
#        'label': 'Björköfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE729849-180191',
#        'value': 'SE729849-180191'},
#       {'active': False,
#        'label': 'Storöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE731175-867144',
#        'value': 'SE731175-867144'},
#       {'active': False,
#        'label': 'Slumpfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE731734-867204',
#        'value': 'SE731734-867204'},
#       {'active': False,
#        'label': 'Bodöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE732081-888706',
#        'value': 'SE732081-888706'},
#       {'active': False,
#        'label': 'Kroksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE732410-884539',
#        'value': 'SE732410-884539'}],
#      'label': '22 - Bottenviken, inre kustvatten',
#      'status': 'selectable',
#      'type': 'value',
#      'value': '22'},
#     {'active': False,
#      'children': [{'active': False,
#        'label': 'S Bottenvikens kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641250-211751',
#        'value': 'SE641250-211751'},
#       {'active': False,
#        'label': 'Skelleftebukten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE646360-213700',
#        'value': 'SE646360-213700'},
#       {'active': False,
#        'label': 'N m Bottenvikens kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE648760-213140',
#        'value': 'SE648760-213140'},
#       {'active': False,
#        'label': 'Norrbottens skärgårds kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652400-223501',
#        'value': 'SE652400-223501'},
#       {'active': False,
#        'label': 'Knivskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653840-247900',
#        'value': 'SE653840-247900'},
#       {'active': False,
#        'label': 'Enskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653870-235570',
#        'value': 'SE653870-235570'},
#       {'active': False,
#        'label': 'S. Seskaröfjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654100-234100',
#        'value': 'SE654100-234100'},
#       {'active': False,
#        'label': 'Katajafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654130-249500',
#        'value': 'SE654130-249500'},
#       {'active': False,
#        'label': 'Hamnskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654150-240380',
#        'value': 'SE654150-240380'}],
#      'label': '23 - Bottenviken, yttre kustvatten',
#      'status': 'selectable',
#      'type': 'value',
#      'value': '23'}],
#    'label': 'SE1',
#    'status': 'selectable',
#    'type': 'water_district',
#    'value': 'SE1'},
#   {'active': False,
#    'children': [{'active': False,
#      'children': [{'active': False,
#        'label': 'Bygdefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640240-205500',
#        'value': 'SE640240-205500'},
#       {'active': False,
#        'label': 'Ricklefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640400-205770',
#        'value': 'SE640400-205770'},
#       {'active': False,
#        'label': 'Sikeåfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640900-205935',
#        'value': 'SE640900-205935'},
#       {'active': False,
#        'label': 'Vändskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641000-210500',
#        'value': 'SE641000-210500'},
#       {'active': False,
#        'label': 'Gumbodafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641250-210560',
#        'value': 'SE641250-210560'},
#       {'active': False,
#        'label': 'Lövselefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641745-211570',
#        'value': 'SE641745-211570'},
#       {'active': False,
#        'label': 'Kallviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641875-212250',
#        'value': 'SE641875-212250'},
#       {'active': False,
#        'label': 'Blackefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE642035-212600',
#        'value': 'SE642035-212600'},
#       {'active': False,
#        'label': 'Bjuröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE642950-213400',
#        'value': 'SE642950-213400'},
#       {'active': False,
#        'label': 'Bäckfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643160-212730',
#        'value': 'SE643160-212730'},
#       {'active': False,
#        'label': 'Storsladan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643550-211920',
#        'value': 'SE643550-211920'},
#       {'active': False,
#        'label': 'Burefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643700-211940',
#        'value': 'SE643700-211940'},
#       {'active': False,
#        'label': 'Simpan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643920-211500',
#        'value': 'SE643920-211500'},
#       {'active': False,
#        'label': 'Ytterviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644030-218500',
#        'value': 'SE644030-218500'},
#       {'active': False,
#        'label': 'Sörfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644040-211260',
#        'value': 'SE644040-211260'},
#       {'active': False,
#        'label': 'Skelleftehamnsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644070-211650',
#        'value': 'SE644070-211650'},
#       {'active': False,
#        'label': 'Ursviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644150-211000',
#        'value': 'SE644150-211000'},
#       {'active': False,
#        'label': 'Boviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644730-210650',
#        'value': 'SE644730-210650'},
#       {'active': False,
#        'label': 'Inre Kågefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645000-212100',
#        'value': 'SE645000-212100'},
#       {'active': False,
#        'label': 'Kågefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645000-213500',
#        'value': 'SE645000-213500'},
#       {'active': False,
#        'label': 'Bredviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645130-211040',
#        'value': 'SE645130-211040'},
#       {'active': False,
#        'label': 'Rösnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645340-211330',
#        'value': 'SE645340-211330'},
#       {'active': False,
#        'label': 'Byskefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645500-212000',
#        'value': 'SE645500-212000'},
#       {'active': False,
#        'label': 'Sandvikssundet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645670-214290',
#        'value': 'SE645670-214290'},
#       {'active': False,
#        'label': 'Tåmfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645830-212300',
#        'value': 'SE645830-212300'},
#       {'active': False,
#        'label': 'Åbyfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645950-212650',
#        'value': 'SE645950-212650'},
#       {'active': False,
#        'label': 'Hålfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE647260-212660',
#        'value': 'SE647260-212660'},
#       {'active': False,
#        'label': 'Kinnbäcksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650280-213110',
#        'value': 'SE650280-213110'},
#       {'active': False,
#        'label': 'Bursfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650460-213400',
#        'value': 'SE650460-213400'},
#       {'active': False,
#        'label': 'Jävrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650750-213500',
#        'value': 'SE650750-213500'},
#       {'active': False,
#        'label': 'Bondöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651075-213700',
#        'value': 'SE651075-213700'},
#       {'active': False,
#        'label': 'Vargödraget',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651475-214300',
#        'value': 'SE651475-214300'},
#       {'active': False,
#        'label': 'Yttrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651500-213108',
#        'value': 'SE651500-213108'},
#       {'active': False,
#        'label': 'Baggholmsdraget',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651800-214740',
#        'value': 'SE651800-214740'},
#       {'active': False,
#        'label': 'Inrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651818-212790',
#        'value': 'SE651818-212790'},
#       {'active': False,
#        'label': 'Haraholmsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651940-213930',
#        'value': 'SE651940-213930'},
#       {'active': False,
#        'label': 'Nördfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652000-213210',
#        'value': 'SE652000-213210'},
#       {'active': False,
#        'label': 'Mjoöfjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652000-214000',
#        'value': 'SE652000-214000'},
#       {'active': False,
#        'label': 'Storfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652066-214400',
#        'value': 'SE652066-214400'},
#       {'active': False,
#        'label': 'Davids stenar',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652075-213500',
#        'value': 'SE652075-213500'},
#       {'active': False,
#        'label': 'Rävahavet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652150-213000',
#        'value': 'SE652150-213000'},
#       {'active': False,
#        'label': 'Bärtnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652250-213000',
#        'value': 'SE652250-213000'},
#       {'active': False,
#        'label': 'Håkansöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652250-213430',
#        'value': 'SE652250-213430'},
#       {'active': False,
#        'label': 'Brändöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652385-214180',
#        'value': 'SE652385-214180'},
#       {'active': False,
#        'label': 'Mannöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652400-220070',
#        'value': 'SE652400-220070'},
#       {'active': False,
#        'label': 'Sandgrönnfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652450-222116',
#        'value': 'SE652450-222116'},
#       {'active': False,
#        'label': 'Bastafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652465-214080',
#        'value': 'SE652465-214080'},
#       {'active': False,
#        'label': 'Holfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652475-215750',
#        'value': 'SE652475-215750'},
#       {'active': False,
#        'label': 'Harrbäcksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652500-213500',
#        'value': 'SE652500-213500'},
#       {'active': False,
#        'label': 'Germandöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652686-221500',
#        'value': 'SE652686-221500'},
#       {'active': False,
#        'label': 'Västantillfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652830-222116',
#        'value': 'SE652830-222116'},
#       {'active': False,
#        'label': 'Bastaskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652855-224000',
#        'value': 'SE652855-224000'},
#       {'active': False,
#        'label': 'Sörbrändöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652920-222650',
#        'value': 'SE652920-222650'},
#       {'active': False,
#        'label': 'Saxskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653116-224623',
#        'value': 'SE653116-224623'},
#       {'active': False,
#        'label': 'Degeröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653140-224000',
#        'value': 'SE653140-224000'},
#       {'active': False,
#        'label': 'Sandöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653176-222000',
#        'value': 'SE653176-222000'},
#       {'active': False,
#        'label': 'Hindersöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653303-222900',
#        'value': 'SE653303-222900'},
#       {'active': False,
#        'label': 'Hamnöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653740-222800',
#        'value': 'SE653740-222800'},
#       {'active': False,
#        'label': 'Fjuksöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653900-223280',
#        'value': 'SE653900-223280'},
#       {'active': False,
#        'label': 'S. Sigfridsöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654000-222430',
#        'value': 'SE654000-222430'},
#       {'active': False,
#        'label': 'Båtöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654110-224850',
#        'value': 'SE654110-224850'},
#       {'active': False,
#        'label': 'Tistersöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654200-222920',
#        'value': 'SE654200-222920'},
#       {'active': False,
#        'label': 'Bergöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654291-224000',
#        'value': 'SE654291-224000'},
#       {'active': False,
#        'label': 'N. Sigfridsöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654330-222200',
#        'value': 'SE654330-222200'},
#       {'active': False,
#        'label': 'Skomakarfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654360-235780',
#        'value': 'SE654360-235780'},
#       {'active': False,
#        'label': 'Gussöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654470-222700',
#        'value': 'SE654470-222700'},
#       {'active': False,
#        'label': 'Börstskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654490-220870',
#        'value': 'SE654490-220870'},
#       {'active': False,
#        'label': 'Repskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654500-232000',
#        'value': 'SE654500-232000'},
#       {'active': False,
#        'label': 'Haparandafjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654560-246250',
#        'value': 'SE654560-246250'},
#       {'active': False,
#        'label': 'Rånöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654570-225230',
#        'value': 'SE654570-225230'},
#       {'active': False,
#        'label': 'Seskaröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654575-234250',
#        'value': 'SE654575-234250'},
#       {'active': False,
#        'label': 'Rånefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654820-222660',
#        'value': 'SE654820-222660'},
#       {'active': False,
#        'label': 'Ersnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654860-219880',
#        'value': 'SE654860-219880'},
#       {'active': False,
#        'label': 'Siknäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654990-224540',
#        'value': 'SE654990-224540'},
#       {'active': False,
#        'label': 'Måttsundsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655120-220380',
#        'value': 'SE655120-220380'},
#       {'active': False,
#        'label': 'Möröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655180-218660',
#        'value': 'SE655180-218660'},
#       {'active': False,
#        'label': 'Törefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655260-224280',
#        'value': 'SE655260-224280'},
#       {'active': False,
#        'label': 'Mulöviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656300-222750',
#        'value': 'SE656300-222750'},
#       {'active': False,
#        'label': 'Granöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656620-222480',
#        'value': 'SE656620-222480'},
#       {'active': False,
#        'label': 'Bergnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656840-222800',
#        'value': 'SE656840-222800'},
#       {'active': False,
#        'label': 'Yttre Lulefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE728806-179329',
# ...
#        'value': '13'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '1n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '7'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '12n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '5'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '14'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '9'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '10'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '17'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '24'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '25'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '22'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '19'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '1s'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '4'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '6'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '12s'}],
#      'status': 'selectable',
#      'value': 'ntot_summer'},
#     {'label': 'Ntot winter',
#      'selected': True,
#      'settings': [{'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '21'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '15'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '11'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '3'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '16'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '20'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '2'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '18'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '23'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '8'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '13'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '1n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '7'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '12n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '5'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '14'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '9'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '10'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '17'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '24'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '25'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '22'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '19'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '1s'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '4'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '6'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '12s'}],
#      'status': 'selectable',
#      'value': 'ntot_winter'},
#     {'label': 'Ptot summer',
#      'selected': True,
#      'settings': [{'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '21'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '15'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '11'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '3'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '16'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '20'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '2'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '18'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '23'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '8'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '13'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '1n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '7'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '12n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '5'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '14'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '9'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '10'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '17'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '24'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '25'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '22'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '19'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '1s'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '4'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '6'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '12s'}],
#      'status': 'selectable',
#      'value': 'ptot_summer'},
#     {'label': 'Ptot winter',
#      'selected': True,
#      'settings': [{'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '21'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '15'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '11'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '3'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '16'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '20'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '2'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '18'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '23'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '8'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '13'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '1n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '7'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '12n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '5'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '14'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '9'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '10'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '17'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '24'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '25'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '22'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '19'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '1s'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '4'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '6'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '12s'}],
#      'status': 'selectable',
#      'value': 'ptot_winter'}],
#    'label': 'nutrients'},
#   {'children': [{'label': 'Oxygen',
#      'selected': True,
#      'settings': [],
#      'status': 'selectable',
#      'value': 'o2'}],
#    'label': 'oxygen balance'}],
#  'time': {'year_interval': [2013, 2015]},
#  'uuid': 'fa499f4c-ad1e-4978-b38a-510b672d5a7e'}

# %%
ekos.subset_dict
# Out:
# {'active': True,
#  'alias': 'test_subset_1',
#  'status': 'editable',
#  'uuid': 'fa499f4c-ad1e-4978-b38a-510b672d5a7e'}

# %%
sorted(ekos.mapping_objects['water_body'].get_list('type_area'))
# Out:
# ['10',
#  '11',
#  '12n',
#  '12s',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '1n',
#  '1s',
#  '2',
#  '20',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  '9']

# %%
indicator_settings_object = w.get_indicator_settings_data_filter_object(subset=s_id, 
                                                                                               step='step_2', 
                                                                                               indicator='bqi')

# %%
indicator_settings_object.get_value(type_area='1', variable='DEPH_INTERVAL')
# Out:
# 1
# Index(['INDICATOR', 'TYPE_AREA_NUMBER', 'TYPE_AREA_SUFFIX', 'DEPH_INTERVAL',
#        'MIN_NR_YEARS', 'MIN_NR_VALUES', 'MONTH_LIST', 'HG', 'GM', 'MP', 'PB',
#        'MAX BQIM', 'EK H/G', 'EK G/M', 'EK M/P', 'EK P/B', 'PARAM',
#        'QUALITYELEMENT'],
#       dtype='object')
# type_area_type_area 1
# [[5, 20], [20, 500]]

# %%
file_path = 'D:/Utveckling/git/ekostat_calculator/workspaces/default_workspace/subsets/default_subset/step_2/settings/indicator_settings/din_winter.set'
df = pd.read_csv(file_path, sep='\t', encoding='cp1252')

# %%
df.head()
# Out:
#    Type_Area_number Type_Area_suffix filter_DEPH_INTERVAL_int  \
# 0                 1                n                     0-10
# 1                 1                s                     0-10
# 2                 2              NaN                     0-10
# 3                 3              NaN                     0-10
# 4                 4              NaN                     0-10
#
#    tolerance_MIN_NR_YEARS_int  tolerance_MIN_NR_VALUES_int  \
# 0                           3                            3
# 1                           3                            3
# 2                           3                            3
# 3                           3                            3
# 4                           3                            3
#
#    tolerance_TIME_DELTA_TOLERANCE  tolerance_POS_RADIUS_TOLERANCE  \
# 0                               3                             0.1
# 1                               3                             0.1
# 2                               3                             0.1
# 3                               3                             0.1
# 4                               3                             0.1
#
#    tolerance_DEPH_TOLERANCE_int filter_MONTH_LIST_int    ref_EKV Ref  \
# 0                             5              12;1;2;3  -0.51852*s+20
# 1                             5              12;1;2;3    -0.525*s+15
# 2                             5              12;1;2;3  -0.51852*s+20
# 3                             5              12;1;2;3  -0.51852*s+20
# 4                             5              12;1;2;3    -0.525*s+15
#
#       ref_EKV H/G     ref_EKV G/M      ref_EKV M/O    ref_EKV O/D  ref_EK H/G  \
# 0   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 1  -0.656*s+18.75  -0.7875*s+22.5  -1.1813*s+33.75  -1.838*s+52.5         0.8
# 2   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 3   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 4  -0.656*s+18.75  -0.7875*s+22.5  -1.1813*s+33.75  -1.838*s+52.5         0.8
#
#    ref_EK G/M  ref_EK M/O  ref_EK O/D  ref_Salinity max
# 0        0.66        0.44        0.28                27
# 1        0.67        0.44        0.29                20
# 2        0.66        0.44        0.28                27
# 3        0.66        0.44        0.28                27
# 4        0.67        0.44        0.29                20

# %%
df.loc[df['Type_Area_number']==2, 'tolerance_MIN_NR_YEARS_int']=[9]

# %%
df.head()
# Out:
#    Type_Area_number Type_Area_suffix filter_DEPH_INTERVAL_int  \
# 0                 1                n                     0-10
# 1                 1                s                     0-10
# 2                 2              NaN                     0-10
# 3                 3              NaN                     0-10
# 4                 4              NaN                     0-10
#
#    tolerance_MIN_NR_YEARS_int  tolerance_MIN_NR_VALUES_int  \
# 0                           1                            3
# 1                           9                            3
# 2                           3                            3
# 3                           3                            3
# 4                           3                            3
#
#    tolerance_TIME_DELTA_TOLERANCE  tolerance_POS_RADIUS_TOLERANCE  \
# 0                               3                             0.1
# 1                               3                             0.1
# 2                               3                             0.1
# 3                               3                             0.1
# 4                               3                             0.1
#
#    tolerance_DEPH_TOLERANCE_int filter_MONTH_LIST_int    ref_EKV Ref  \
# 0                             5              12;1;2;3  -0.51852*s+20
# 1                             5              12;1;2;3    -0.525*s+15
# 2                             5              12;1;2;3  -0.51852*s+20
# 3                             5              12;1;2;3  -0.51852*s+20
# 4                             5              12;1;2;3    -0.525*s+15
#
#       ref_EKV H/G     ref_EKV G/M      ref_EKV M/O    ref_EKV O/D  ref_EK H/G  \
# 0   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 1  -0.656*s+18.75  -0.7875*s+22.5  -1.1813*s+33.75  -1.838*s+52.5         0.8
# 2   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 3   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 4  -0.656*s+18.75  -0.7875*s+22.5  -1.1813*s+33.75  -1.838*s+52.5         0.8
#
#    ref_EK G/M  ref_EK M/O  ref_EK O/D  ref_Salinity max
# 0        0.66        0.44        0.28                27
# 1        0.67        0.44        0.29                20
# 2        0.66        0.44        0.28                27
# 3        0.66        0.44        0.28                27
# 4        0.67        0.44        0.29                20

# %%
for item in sorted(ekos.test_requests.keys()):
    print(item)
# Out:
# request_areas
# request_subset_add
# request_subset_edit
# request_subset_info
# request_subset_info_simple
# request_subset_list
# request_workspace_add
# request_workspace_delete
# request_workspace_edit
# request_workspace_list
# request_workspace_load_default_data

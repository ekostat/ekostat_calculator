# %%
# Reload when code changed:
# %load_ext autoreload
# %autoreload 2
# %pwd
import sys
import os
path = "../"
sys.path.append(path)
#os.path.abspath("../")
print(os.path.abspath(path))
# Out:
# D:\Utveckling\git\ekostat_calculator

# %%
import os 
import core
import logging
import importlib
importlib.reload(core) 
try:
    logging.shutdown()
    importlib.reload(logging)
except:
    pass
import pandas as pd
import numpy as np
import json

from event_handler import EventHandler
print(core.__file__)
pd.__version__
# Out:
# ..\core\__init__.py
# '0.19.2'

# %%
user_id_1 = 'user_1'
user_id_2 = 'user_2'
ekos = EventHandler(path)
user_1_ws_1 = 'mw1'
# Out:
# 2018-03-26 08:57:28,860	logger.py	85	add_log	DEBUG
# 2018-03-26 08:57:28,860	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-26 08:57:28,860	logger.py	87	add_log	DEBUG	### Log added for log_id "event_handler" at locaton: ..\log\main_event_handler.log
# 2018-03-26 08:57:28,860	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-03-26 08:57:28,860	event_handler.py	64	__init__	DEBUG	Start EventHandler: event_handler
# 2018-03-26 08:57:28,861	event_handler.py	65	__init__	DEBUG
# 2018-03-26 08:57:28,861	event_handler.py	66	__init__	INFO	TEST info logger
# 2018-03-26 08:57:28,861	event_handler.py	67	__init__	WARNING	TEST warning logger
# 2018-03-26 08:57:28,861	event_handler.py	68	__init__	ERROR	TEST error logger
# 2018-03-26 08:57:28,865	event_handler.py	69	__init__	DEBUG	TEST debug logger
# ====================================================================================================
# event_handler
# ..//log
# main
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# event_handler _ main_event_handler

# %%
ekos.copy_workspace(user_id_1, source_alias='default_workspace', target_alias=user_1_ws_1)
ekos.copy_workspace(user_id_1, source_alias='default_workspace', target_alias='mw2')

ekos.copy_workspace(user_id_2, source_alias='default_workspace', target_alias='test1')
ekos.copy_workspace(user_id_2, source_alias='default_workspace', target_alias='test2')
# Out:
# 2018-03-23 15:19:07,852	event_handler.py	229	copy_workspace	DEBUG	Could not add workspace with alias "mw1". Workspace already exists!
# 2018-03-23 15:19:07,862	event_handler.py	229	copy_workspace	DEBUG	Could not add workspace with alias "mw2". Workspace already exists!
# 2018-03-23 15:19:07,863	event_handler.py	229	copy_workspace	DEBUG	Could not add workspace with alias "test1". Workspace already exists!
# 2018-03-23 15:19:07,879	event_handler.py	229	copy_workspace	DEBUG	Could not add workspace with alias "test2". Workspace already exists!
# ¤ mw1
# ¤ user_1
# ¤ mw2
# ¤ user_1
# ¤ test1
# ¤ user_2
# ¤ test2
# ¤ user_2
# False

# %%
ekos.load_test_requests()

# %%
# Request workspace list 
request = ekos.test_requests['request_workspace_list']
response = ekos.request_workspace_list(request) 
ekos.write_test_response('request_workspace_list', response)
# Out:
# 2018-03-26 08:58:02,348	event_handler.py	1880	request_workspace_list	DEBUG	Start: request_workspace_list
# status ['editable', 'readable', 'deleted', 'inactive']
# status ['editable', 'readable', 'deleted', 'inactive']
# status ['editable', 'readable', 'deleted', 'inactive']
# status ['editable', 'readable', 'deleted', 'inactive']

# %%
# Request subset list 
request = ekos.test_requests['request_subset_list']
response_subset_list = ekos.request_subset_list(request)
ekos.write_test_response('request_subset_list', response_subset_list)
# Out:
# 2018-03-26 08:58:04,228	event_handler.py	1729	request_subset_list	DEBUG	Start: request_subset_list
# 2018-03-26 08:58:04,229	event_handler.py	1483	load_workspace	DEBUG	Trying to load workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "mw1"
# workspace_uuid 1a77220d-e76a-4224-a98c-8c0c234150d9
# status ['editable', 'readable', 'deleted']
# ¤¤¤ alias mw1
# ¤¤¤ unique_id 1a77220d-e76a-4224-a98c-8c0c234150d9
# ¤¤¤ user_id user_1
#
# ====================================================================================================
# Initiating WorkSpace: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9
# Parent directory is: ..//workspaces
# Resource directory is: ..//resources
# ===
# 2018-03-26 08:58:04,499	logger.py	85	add_log	DEBUG
# 2018-03-26 08:58:04,499	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-26 08:58:04,499	logger.py	87	add_log	DEBUG	### Log added for log_id "default_subset" at locaton: ..\workspaces\1a77220d-e76a-4224-a98c-8c0c234150d9\log\subset_default_subset.log
# 2018-03-26 08:58:04,499	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-03-26 08:58:04,582	logger.py	85	add_log	DEBUG
# 2018-03-26 08:58:04,582	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-26 08:58:04,582	logger.py	87	add_log	DEBUG	### Log added for log_id "fa499f4c-ad1e-4978-b38a-510b672d5a7e" at locaton: ..\workspaces\1a77220d-e76a-4224-a98c-8c0c234150d9\log\subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e.log
# 2018-03-26 08:58:04,582	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
#  default_subset
# !!! default_subset
# !!! default_subset
# !!! ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/default_subset
# ===
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/default_subset
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/default_subset/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/default_subset/step_2
# ====================================================================================================
# default_subset
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/log
# subset
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# default_subset _ main_event_handler
# default_subset _ subset_default_subset
# === fa499f4c-ad1e-4978-b38a-510b672d5a7e
# status ['editable', 'readable', 'deleted']
# !!! test_subset_1
# !!! fa499f4c-ad1e-4978-b38a-510b672d5a7e
# !!! ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/fa499f4c-ad1e-4978-b38a-510b672d5a7e
# ===
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/fa499f4c-ad1e-4978-b38a-510b672d5a7e
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/fa499f4c-ad1e-4978-b38a-510b672d5a7e/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/fa499f4c-ad1e-4978-b38a-510b672d5a7e/step_2
# ====================================================================================================
# fa499f4c-ad1e-4978-b38a-510b672d5a7e
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/log
# subset
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset', 'subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# fa499f4c-ad1e-4978-b38a-510b672d5a7e _ main_event_handler
# fa499f4c-ad1e-4978-b38a-510b672d5a7e _ subset_default_subset
# fa499f4c-ad1e-4978-b38a-510b672d5a7e _ subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/step_0
# 2018-03-26 08:58:04,823	logger.py	85	add_log	DEBUG
# 2018-03-26 08:58:04,823	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-26 08:58:04,833	logger.py	87	add_log	DEBUG	### Log added for log_id "1a77220d-e76a-4224-a98c-8c0c234150d9" at locaton: ..\workspaces\1a77220d-e76a-4224-a98c-8c0c234150d9\log\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log
# 2018-03-26 08:58:04,833	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# ====================================================================================================
# 1a77220d-e76a-4224-a98c-8c0c234150d9
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/log
# workspace
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset', 'subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e', 'workspace_1a77220d-e76a-4224-a98c-8c0c234150d9'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# 1a77220d-e76a-4224-a98c-8c0c234150d9 _ main_event_handler
# 1a77220d-e76a-4224-a98c-8c0c234150d9 _ subset_default_subset
# 1a77220d-e76a-4224-a98c-8c0c234150d9 _ subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 1a77220d-e76a-4224-a98c-8c0c234150d9 _ workspace_1a77220d-e76a-4224-a98c-8c0c234150d9
# 2018-03-26 08:58:08,515	workspaces.py	1381	load_all_data	DEBUG	data has been loaded from existing all_data.txt file.
# status ['editable', 'readable', 'deleted', 'inactive']
# =====SUBSET_UUID "default_subset"
# status ['editable', 'readable', 'deleted', 'inactive']
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# list_quality_elements []
# list_supporting_elements []
# request []
# =====SUBSET_UUID "fa499f4c-ad1e-4978-b38a-510b672d5a7e"
# status ['editable', 'readable', 'deleted', 'inactive']
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:11,904	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:11,915	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# list_quality_elements []
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:11,925	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:11,938	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,038	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,048	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,049	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,054	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,067	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,080	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,094	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,107	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,118	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 08:58:12,131	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,139	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,152	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,248	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,258	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,258	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,264	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,276	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,287	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,301	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,310	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,325	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset
# 2018-03-26 08:58:12,336	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,345	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,358	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,459	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,469	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,469	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,472	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,483	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,495	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,506	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,519	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,528	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,539	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:12,548	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,559	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,669	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,670	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,670	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,679	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,689	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,701	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,716	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,726	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,740	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset
# 2018-03-26 08:58:12,751	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,763	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,773	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,873	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,883	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,884	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,888	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,901	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,914	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,927	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,942	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 08:58:12,953	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,963	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,971	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:12,984	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,083	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,093	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,093	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,094	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,105	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,117	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,130	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,142	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:13,153	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,162	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,169	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,183	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,279	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,280	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,280	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,287	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,301	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,312	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,324	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,336	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,350	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,359	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# list_supporting_elements []
# request []
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:13,373	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,384	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,484	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,494	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,494	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,498	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,511	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,523	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,537	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,547	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,559	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset
# 2018-03-26 08:58:13,571	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,581	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,593	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,694	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,694	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,695	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,701	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,713	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,726	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,737	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,751	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,763	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,771	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset
# 2018-03-26 08:58:13,778	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,792	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,894	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,904	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,904	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,906	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,918	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,928	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,943	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,957	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,968	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,978	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:13,987	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:14,001	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,095	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,105	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,106	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,112	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,124	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,134	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,145	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,159	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,174	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,185	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 08:58:14,194	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,206	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,302	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,312	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,312	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,319	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,328	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,340	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,352	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,365	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,379	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,389	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:14,402	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,415	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,509	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,519	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,520	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,527	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,540	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,553	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,566	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,578	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,592	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:14,602	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,612	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,628	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,729	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,739	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,739	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,744	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,756	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,768	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,781	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,793	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,805	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:14,816	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,826	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,838	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,936	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,946	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,946	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,948	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,960	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,974	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:14,989	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,000	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset
# 2018-03-26 08:58:15,013	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,026	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,035	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,044	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,166	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,167	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,167	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,179	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,196	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,211	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 08:58:15,228	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,243	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,256	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,267	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,277	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,288	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,427	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,428	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 08:58:15,431	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,446	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,464	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,479	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,493	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,510	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,525	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,538	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,549	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,560	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 08:58:15,686	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,698	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,702	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,720	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,735	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,749	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,764	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 08:58:15,781	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None

# %%
# Load default data
request = ekos.test_requests['request_workspace_load_default_data']
response = ekos.request_workspace_load_default_data(request) 
print(response)
# Out:
# 2018-03-23 14:55:44,380	event_handler.py	1894	request_workspace_load_default_data	DEBUG	Start: request_workspace_load_default_data
# user_id user_1
# 1a77220d-e76a-4224-a98c-8c0c234150d9
# ['1a77220d-e76a-4224-a98c-8c0c234150d9', '2e12443d-2537-450f-ba4f-d5a13a0db247', 'f1fb96b8-8b08-4075-b53d-89471c15a429']
# 2018-03-23 14:55:45,401	workspaces.py	944	import_default_data	DEBUG	Default data has been copied to workspace raw data folder.
# 2018-03-23 14:55:48,797	workspaces.py	1381	load_all_data	DEBUG	data has been loaded from existing all_data.txt file.
# {'all_ok': True, 'message': ''}

# %%
# Edit workspace
request = ekos.test_requests['request_workspace_edit']
response = ekos.request_workspace_edit(request)
# Out:
# 2018-03-23 14:55:49,006	event_handler.py	1829	request_workspace_edit	DEBUG	Start: request_workspace_edit

# %%
# Delete workspace
request = ekos.test_requests['request_workspace_delete']
response = ekos.request_workspace_delete(request)
# Out:
# 2018-03-23 14:55:49,208	event_handler.py	1788	request_workspace_delete	DEBUG	Start: request_workspace_delete
# 2018-03-23 14:55:49,222	event_handler.py	334	delete_workspace	WARNING	Removing workspace "433942c2-38db-4463-9925-b0135c0b7482" with alias "test2".
# status ['editable', 'readable', 'deleted']

# %%
# Add new subset 
request = ekos.test_requests['request_subset_add']
response_subset_add = ekos.request_subset_add(request)
ekos.write_test_response('request_subset_add', response_subset_add)
# Out:
# 2018-03-23 14:55:49,423	event_handler.py	1506	request_subset_add	DEBUG	Start: request_subset_add
# 2018-03-23 14:55:49,429	event_handler.py	201	copy_subset	DEBUG	Trying to copy subset "default_subset". Copy has alias "test_subset_1"
# 2018-03-23 14:55:49,438	workspaces.py	1078	copy_subset	DEBUG	Could not add subset with alias "test_subset_1". Subset already exists!
# 2018-03-23 14:55:49,453	event_handler.py	416	dict_time	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,455	event_handler.py	788	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,459	event_handler.py	788	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,461	event_handler.py	788	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,464	event_handler.py	788	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,466	event_handler.py	788	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,470	event_handler.py	788	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,472	event_handler.py	578	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,475	event_handler.py	578	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,478	event_handler.py	578	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,484	event_handler.py	578	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,487	event_handler.py	578	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 14:55:49,489	event_handler.py	578	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# SUBSET_SOURCE_UUID default_subset
# status ['editable', 'readable', 'deleted']
# SUBSET_SOURCE_ALIAS default_subset
# default_subset test_subset_1
# self.user_id user_1
# ¤ test_subset_1
# ¤ user_1
# target_uuid False
# RETURN_DICT False
# test_subset_1 user_1
# status ['editable', 'readable', 'deleted', 'inactive']
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# list_quality_elements []
# list_supporting_elements []
# request []

# %%
ekos.temp_return_dict
# Out:
# False

# %%
# Edit subset 
request = ekos.test_requests['request_subset_edit']
response_subset_edit = ekos.request_subset_edit(request)
ekos.write_test_response('request_subset_edit', response_subset_edit)
# Out:
# 2018-03-23 10:30:22,755	event_handler.py	1556	request_subset_edit	DEBUG	Start: request_subset_edit
# 2018-03-23 10:30:22,760	event_handler.py	908	get_workspace	DEBUG	Getting workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "None"

# %%
w_id = '1a77220d-e76a-4224-a98c-8c0c234150d9'
s_id = 'fa499f4c-ad1e-4978-b38a-510b672d5a7e'

# %%
w = ekos.get_workspace(user_id=user_id_1, unique_id=w_id)
# Out:
# 2018-03-23 14:55:50,068	event_handler.py	908	get_workspace	DEBUG	Getting workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "None"

# %%
w.index_handler.data_handler_object.all_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-71c6b3c00950> in <module>()
# ----> 1 w.index_handler.data_handler_object.all_data.head()
#
# AttributeError: 'NoneType' object has no attribute 'index_handler'

# %%
# w.index_handler.booleans

# %%
# Apply data filter step_0
ekos.apply_data_filter(user_id=user_id_1,  
                           workspace_uuid=w_id,
                           step='step_0')
# Out:
# step step_0

# %%
# Apply data filter step_1
ekos.apply_data_filter(user_id=user_id_1,  
                           workspace_uuid=w_id,
                           subset_uuid=s_id, 
                           step='step_1')
# Out:
# step step_1

# %%
# Apply indicator data filter (step_2) 
indicator = 'din_winter'
water_body_1 = 'SE575340-113000' # Marstrandsfjorden, type_area=3
water_body_2 = 'SE572072-115880' # Varren, type_area=1s
water_body_3 = 'SE582000-112350' # Yttre Brofjorden, type_area=1n
ekos.apply_indicator_data_filter(user_id=user_id_1,  
                                 workspace_uuid=w_id,
                                 subset_uuid=s_id, 
                                 indicator=indicator, 
                                 water_body=water_body_3)
# Out:
# step step_2
# WWW SE582000-112350
# ===
# water_body SE582000-112350
# type_area 1-n
# RESULT [[0, 10]]

# %%
directory = 'D:/temp_ekostat'
data_step_0 = w.get_filtered_data(step=0)
data_step_0.to_csv('{}/data_step_0.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# 2018-03-23 10:33:03,469	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_0
# water_body None

# %%
directory = 'D:/temp_ekostat'
data_step_1 = w.get_filtered_data(step=1, subset=s_id)
data_step_1.to_csv('{}/data_step_1.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# 2018-03-23 10:33:09,968	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None

# %%
directory = 'D:/temp_ekostat'
data_step_2 = w.get_filtered_data(step=2, subset=s_id, indicator=indicator, water_body=water_body_3)
data_step_2.to_csv('{}/data_step_2.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# 2018-03-23 10:33:13,908	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_2
# water_body SE582000-112350

# %%
w.index_handler.data_handler_object.all_data.columns
# Out:
# Index(['Unnamed: 0', 'AMON', 'BIOV_CONC_ALL', 'BQIm', 'CPHL_INTEG', 'DEPH',
#        'DIN', 'DOXY_BTL', 'DOXY_CTD', 'LATIT_DD', 'LONGI_DD', 'MNDEP', 'MXDEP',
#        'MYEAR', 'NTOT', 'NTRA', 'NTRI', 'NTRZ', 'PHOS', 'PTOT', 'Q_AMON',
#        'Q_BIOV_CONC_ALL', 'Q_BQIm', 'Q_CPHL_INTEG', 'Q_DOXY_BTL', 'Q_DOXY_CTD',
#        'Q_NTOT', 'Q_NTRA', 'Q_NTRI', 'Q_NTRZ', 'Q_PHOS', 'Q_PTOT',
#        'Q_SALT_BTL', 'Q_SALT_CTD', 'Q_SECCHI', 'Q_TEMP_BTL', 'Q_TEMP_CTD',
#        'SALT_BTL', 'SALT_CTD', 'SDATE', 'SEA_BASIN', 'SECCHI', 'SERNO',
#        'SHARKID_MD5', 'SHIPC', 'STATN', 'STIME', 'TEMP_BTL', 'TEMP_CTD',
#        'VISS_EU_CD', 'WATER_BODY_NAME', 'WATER_DISTRICT', 'WATER_TYPE_AREA',
#        'WLTYP', 'MONTH'],
#       dtype='object')

# %%
din_winter = w.get_indicator_settings_data_filter_object(subset=s_id, indicator=indicator)
boolean = din_winter.get_filter_boolean_for_df(w.index_handler.data_handler_object.all_data, water_body=water_body_3) 
w.index_handler.data_handler_object.all_data.loc[boolean, :].to_csv('{}/test_data.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# WWW SE582000-112350
# ===
# water_body SE582000-112350
# type_area 1-n
# 1-n
# type_area_type_area 1-n
# 1-n
# 1
# n
# Index(['TYPE_AREA_NUMBER', 'TYPE_AREA_SUFFIX', 'DEPH_INTERVAL', 'MIN_NR_YEARS',
#        'MIN_NR_VALUES', 'TIME_DELTA_TOLERANCE', 'POS_RADIUS_TOLERANCE',
#        'DEPH_TOLERANCE', 'MONTH_LIST', 'EKV REF', 'EKV H/G', 'EKV G/M',
#        'EKV M/O', 'EKV O/D', 'EK H/G', 'EK G/M', 'EK M/O', 'EK O/D',
#        'SALINITY MAX'],
#       dtype='object')
# ----
# 0    0-10
# Name: DEPH_INTERVAL, dtype: object <class 'pandas.core.series.Series'>
# ['0-10'] <class 'numpy.ndarray'>
# 0-10
# 0-10
# DEPH_INTERVAL
# = [0, 10] <class 'int'>
# RESULT [[0, 10]]
# 1-n
# type_area_type_area 1-n
# 1-n
# 1
# n
# Index(['TYPE_AREA_NUMBER', 'TYPE_AREA_SUFFIX', 'DEPH_INTERVAL', 'MIN_NR_YEARS',
#        'MIN_NR_VALUES', 'TIME_DELTA_TOLERANCE', 'POS_RADIUS_TOLERANCE',
#        'DEPH_TOLERANCE', 'MONTH_LIST', 'EKV REF', 'EKV H/G', 'EKV G/M',
#        'EKV M/O', 'EKV O/D', 'EK H/G', 'EK G/M', 'EK M/O', 'EK O/D',
#        'SALINITY MAX'],
#       dtype='object')
# ----
# 0    12;1;2;3
# Name: MONTH_LIST, dtype: object <class 'pandas.core.series.Series'>
# ['12;1;2;3'] <class 'numpy.ndarray'>
# 12;1;2;3
# 12;1;2;3
# MONTH_LIST
# = [12, 1, 2, 3] <class 'int'>

# %%
# all_data = w.index_handler.data_handler_object.all_data 
# boolean = din_winter.get_filter_boolean_for_df(df=all_data, water_body=water_body_3)
# din_winter_data = all_data.loc[boolean, :]
# din_winter_data.to_csv('{}/din_winter_data.txt'.format(directory), sep='\t', index=False, encoding='cp1252')

# %%
# np.where(din_winter.settings.temp_boolean_list)

# %%
type_area = ekos.mapping_objects['water_body'].get_list('type_area', water_body='SE'+water_body_3)
print(type_area)
indicator_settings_response = ekos.dict_indicator_settings(workspace_unique_id=w_id, 
                                                           subset_unique_id=s_id,
                                                           indicator=indicator, 
                                                           type_area=type_area)
# Out:
# []
# ==================================================
# 1a77220d-e76a-4224-a98c-8c0c234150d9
# fa499f4c-ad1e-4978-b38a-510b672d5a7e
# din_winter
# ==================================================

# %%
indicator_settings_response
# Out:
# {}

# %%
# Subset info  
ekos.load_test_requests()
request = ekos.test_requests['request_subset_info_simple']
response_subset_info = ekos.request_subset_info(request)
ekos.write_test_response('request_subset_info_simple', response_subset_info)
# Out:
# 2018-03-26 09:24:11,636	event_handler.py	1600	request_subset_info	DEBUG	Start: request_subset_info
# 2018-03-26 09:24:11,646	event_handler.py	919	get_workspace	DEBUG	Getting workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "None"
# 2018-03-26 09:24:11,724	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,741	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,742	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,752	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# status ['editable', 'readable', 'deleted', 'inactive']
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 09:24:11,871	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,874	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,879	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,891	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,910	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,921	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,933	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,946	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,959	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,971	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,979	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:11,990	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 09:24:12,119	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,120	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,126	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,138	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,149	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,162	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,175	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,189	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# Interval column
# Value to set for type_area "10" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 10
# List column
# Value to set for type_area "10" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 10
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "10" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 10
# Interval column
# Value to set for type_area "18" and variable "DEPH_INTERVAL": ['5-500']
# type_area_type_area 18
# List column
# Value to set for type_area "18" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 18
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "18" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 18
# Interval column
# Value to set for type_area "7" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 7
# List column
# Value to set for type_area "7" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 7
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "7" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 7
# Interval column
# Value to set for type_area "23" and variable "DEPH_INTERVAL": ['5-500']
# type_area_type_area 23
# List column
# Value to set for type_area "23" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 23
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "23" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 23
# Interval column
# Value to set for type_area "20" and variable "DEPH_INTERVAL": ['5-500']
# type_area_type_area 20
# List column
# Value to set for type_area "20" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 20
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "20" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 20
# Interval column
# Value to set for type_area "22" and variable "DEPH_INTERVAL": ['5-500']
# type_area_type_area 22
# List column
# Value to set for type_area "22" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 22
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "22" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 22
# Interval column
# Value to set for type_area "13" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 13
# List column
# Value to set for type_area "13" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 13
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "13" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 13
# Interval column
# Value to set for type_area "14" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 14
# List column
# Value to set for type_area "14" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 14
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "14" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 14
# Interval column
# Value to set for type_area "11" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 11
# List column
# Value to set for type_area "11" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 11
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "11" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 11
# Interval column
# Interval column
# Value to set for type_area "6" and variable "DEPH_INTERVAL": ['5-20', '20-500']
# type_area_type_area 6
# List column
# List column
# Value to set for type_area "6" and variable "MONTH_LIST": ['5;6', '5;6']
# type_area_type_area 6
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Tolerance column
# Value to set for type_area "6" and variable "MIN_NR_YEARS": ['3', '3']
# type_area_type_area 6
# Interval column
# Value to set for type_area "8" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 8
# List column
# Value to set for type_area "8" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 8
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "8" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 8
# Interval column
# Interval column
# Value to set for type_area "1" and variable "DEPH_INTERVAL": ['1-20', '20-500']
# type_area_type_area 1
# List column
# List column
# Value to set for type_area "1" and variable "MONTH_LIST": ['5;6', '5;6']
# type_area_type_area 1
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Tolerance column
# Value to set for type_area "1" and variable "MIN_NR_YEARS": ['3', '3']
# type_area_type_area 1
# Interval column
# Interval column
# Value to set for type_area "25" and variable "DEPH_INTERVAL": ['5-20', '20-500']
# type_area_type_area 25
# List column
# List column
# Value to set for type_area "25" and variable "MONTH_LIST": ['5;6', '5;6']
# type_area_type_area 25
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Tolerance column
# Value to set for type_area "25" and variable "MIN_NR_YEARS": ['3', '3']
# type_area_type_area 25
# Interval column
# Value to set for type_area "15" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 15
# List column
# Value to set for type_area "15" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 15
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "15" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 15
# Interval column
# Value to set for type_area "24" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 24
# List column
# Value to set for type_area "24" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 24
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "24" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 24
# Interval column
# Interval column
# Value to set for type_area "2" and variable "DEPH_INTERVAL": ['5-20', '20-500']
# type_area_type_area 2
# List column
# List column
# Value to set for type_area "2" and variable "MONTH_LIST": ['5;6', '5;6']
# type_area_type_area 2
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Tolerance column
# Value to set for type_area "2" and variable "MIN_NR_YEARS": ['3', '3']
# type_area_type_area 2
# Interval column
# Value to set for type_area "17" and variable "DEPH_INTERVAL": ['5-500']
# type_area_type_area 17
# List column
# Value to set for type_area "17" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 17
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "17" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 17
# Interval column
# Value to set for type_area "9" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 9
# List column
# Value to set for type_area "9" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 9
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "9" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 9
# Interval column
# Interval column
# Value to set for type_area "5" and variable "DEPH_INTERVAL": ['5-20', '20-500']
# type_area_type_area 5
# List column
# List column
# Value to set for type_area "5" and variable "MONTH_LIST": ['5;6', '5;6']
# type_area_type_area 5
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Tolerance column
# Value to set for type_area "5" and variable "MIN_NR_YEARS": ['3', '3']
# type_area_type_area 5
# Interval column
# Value to set for type_area "12" and variable "DEPH_INTERVAL": ['5-60']
# type_area_type_area 12
# List column
# Value to set for type_area "12" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 12
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "12" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 12
# Interval column
# Interval column
# Value to set for type_area "4" and variable "DEPH_INTERVAL": ['5-20', '20-500']
# type_area_type_area 4
# List column
# List column
# Value to set for type_area "4" and variable "MONTH_LIST": ['5;6', '5;6']
# type_area_type_area 4
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Tolerance column
# Value to set for type_area "4" and variable "MIN_NR_YEARS": ['3', '3']
# type_area_type_area 4
# Interval column
# Interval column
# Value to set for type_area "3" and variable "DEPH_INTERVAL": ['5-20', '20-500']
# 2018-03-26 09:24:12,592	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,602	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,609	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,617	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,718	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,728	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,728	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,733	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,744	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# type_area_type_area 3
# List column
# List column
# Value to set for type_area "3" and variable "MONTH_LIST": ['5;6', '5;6']
# type_area_type_area 3
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Tolerance column
# Value to set for type_area "3" and variable "MIN_NR_YEARS": ['3', '3']
# type_area_type_area 3
# Interval column
# Value to set for type_area "19" and variable "DEPH_INTERVAL": ['5-500']
# type_area_type_area 19
# List column
# Value to set for type_area "19" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 19
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "19" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 19
# Interval column
# Value to set for type_area "21" and variable "DEPH_INTERVAL": ['5-500']
# type_area_type_area 21
# List column
# Value to set for type_area "21" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 21
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "21" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 21
# Interval column
# Value to set for type_area "16" and variable "DEPH_INTERVAL": ['5-500']
# type_area_type_area 16
# List column
# Value to set for type_area "16" and variable "MONTH_LIST": ['5;6']
# type_area_type_area 16
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
#
# Tolerance column
# Value to set for type_area "16" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 16
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 09:24:12,758	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,771	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,783	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,795	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,805	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,816	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,829	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,932	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,933	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,933	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,941	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,955	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 09:24:12,966	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,980	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:12,991	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,005	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,015	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,025	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,038	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,139	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,149	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,149	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,150	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 09:24:13,162	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,175	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,190	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,203	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,213	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,225	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,232	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,245	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,331	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,341	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,343	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,353	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,363	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset
# 2018-03-26 09:24:13,374	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,391	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,403	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,415	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,424	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,437	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,446	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,532	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,541	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,543	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,554	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,564	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,575	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 09:24:13,590	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,601	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,613	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,622	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,630	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,643	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,737	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,747	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,747	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,749	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,762	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,773	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,783	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 09:24:13,799	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,813	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,822	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,830	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,843	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,935	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,944	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,946	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,958	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,970	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,978	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:13,992	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# 2018-03-26 09:24:14,006	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,016	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,027	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,036	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,048	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,130	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,140	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,143	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,152	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,163	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,175	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,187	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,201	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 09:24:14,217	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,230	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,239	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,251	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,336	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,347	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,350	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,361	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,374	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,384	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:14,400	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset
# 2018-03-26 09:24:14,415	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# Interval column
# Value to set for type_area "10" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 10
# List column
# Value to set for type_area "10" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 10
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "10" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 10
# Interval column
# Value to set for type_area "18" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 18
# List column
# Value to set for type_area "18" and variable "MONTH_LIST": ['11;12;1;2']
# type_area_type_area 18
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "18" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 18
# Interval column
# Value to set for type_area "7" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 7
# List column
# Value to set for type_area "7" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 7
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "7" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 7
# Interval column
# Value to set for type_area "23" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 23
# List column
# Value to set for type_area "23" and variable "MONTH_LIST": ['11;12;1;2']
# type_area_type_area 23
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "23" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 23
# Interval column
# Value to set for type_area "1s" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 1s
# List column
# Value to set for type_area "1s" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 1s
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "1s" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 1s
# Interval column
# Value to set for type_area "20" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 20
# List column
# Value to set for type_area "20" and variable "MONTH_LIST": ['11;12;1;2']
# type_area_type_area 20
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "20" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 20
# Interval column
# Value to set for type_area "22" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 22
# List column
# Value to set for type_area "22" and variable "MONTH_LIST": ['11;12;1;2']
# type_area_type_area 22
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "22" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 22
# Interval column
# Value to set for type_area "12n" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 12n
# List column
# Value to set for type_area "12n" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 12n
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "12n" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 12n
# Interval column
# Value to set for type_area "13" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 13
# List column
# Value to set for type_area "13" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 13
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "13" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 13
# Interval column
# Value to set for type_area "14" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 14
# List column
# Value to set for type_area "14" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 14
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "14" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 14
# Interval column
# Value to set for type_area "11" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 11
# List column
# Value to set for type_area "11" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 11
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "11" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 11
# Interval column
# Value to set for type_area "6" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 6
# List column
# Value to set for type_area "6" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 6
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "6" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 6
# Interval column
# Value to set for type_area "8" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 8
# List column
# Value to set for type_area "8" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 8
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "8" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 8
# Interval column
# Value to set for type_area "25" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 25
# List column
# Value to set for type_area "25" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 25
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "25" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 25
# Interval column
# Value to set for type_area "1n" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 1n
# List column
# Value to set for type_area "1n" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 1n
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "1n" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 1n
# Interval column
# Value to set for type_area "12s" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 12s
# List column
# Value to set for type_area "12s" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 12s
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "12s" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 12s
# Interval column
# Value to set for type_area "15" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 15
# List column
# Value to set for type_area "15" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 15
# ...
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "11" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 11
# Interval column
# Value to set for type_area "6" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 6
# List column
# Value to set for type_area "6" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 6
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "6" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 6
# Interval column
# Value to set for type_area "8" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 8
# List column
# Value to set for type_area "8" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 8
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "8" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 8
# Interval column
# Value to set for type_area "25" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 25
# List column
# Value to set for type_area "25" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 25
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "25" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 25
# Interval column
# Value to set for type_area "1n" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 1n
# List column
# Value to set for type_area "1n" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 1n
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "1n" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 1n
# Interval column
# Value to set for type_area "12s" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 12s
# List column
# Value to set for type_area "12s" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 12s
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "12s" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 12s
# Interval column
# Value to set for type_area "15" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 15
# List column
# Value to set for type_area "15" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 15
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "15" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 15
# Interval column
# Value to set for type_area "24" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 24
# List column
# Value to set for type_area "24" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 24
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "24" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 24
# Interval column
# Value to set for type_area "2" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 2
# List column
# Value to set for type_area "2" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 2
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "2" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 2
# Interval column
# Value to set for type_area "17" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 17
# List column
# Value to set for type_area "17" and variable "MONTH_LIST": ['11;12;1;2']
# type_area_type_area 17
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "17" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 17
# Interval column
# Value to set for type_area "9" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 9
# List column
# Value to set for type_area "9" and variable "MONTH_LIST": ['12;1;2']
# type_area_type_area 9
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "9" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 9
# Interval column
# Value to set for type_area "5" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 5
# List column
# Value to set for type_area "5" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 5
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "5" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 5
# Interval column
# Value to set for type_area "4" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 4
# List column
# Value to set for type_area "4" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 4
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "4" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 4
# Interval column
# Value to set for type_area "3" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 3
# List column
# Value to set for type_area "3" and variable "MONTH_LIST": ['12;1;2;3']
# type_area_type_area 3
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "3" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 3
# Interval column
# Value to set for type_area "19" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 19
# List column
# Value to set for type_area "19" and variable "MONTH_LIST": ['11;12;1;2']
# type_area_type_area 19
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "19" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 19
# 2018-03-26 09:24:17,823	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:17,830	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:17,838	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:17,850	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:17,954	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:17,964	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:17,964	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:17,965	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:17,975	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:17,988	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# Interval column
# Value to set for type_area "21" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 21
# List column
# Value to set for type_area "21" and variable "MONTH_LIST": ['11;12;1;2']
# type_area_type_area 21
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "21" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 21
# Interval column
# Value to set for type_area "16" and variable "DEPH_INTERVAL": ['0-10']
# type_area_type_area 16
# List column
# Value to set for type_area "16" and variable "MONTH_LIST": ['11;12;1;2']
# type_area_type_area 16
# Not allowed to change variable "MIN_NR_YEARS". Allowed variables to change are:
# DEPH_INTERVAL
# MONTH_LIST
#
# Not allowed to change variable "DEPH_INTERVAL". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Not allowed to change variable "MONTH_LIST". Allowed variables to change are:
# MIN_NR_YEARS
# MIN_NR_VALUES
# TIME_DELTA_TOLERANCE
# POS_RADIUS_TOLERANCE
# DEPH_TOLERANCE
#
# Tolerance column
# Value to set for type_area "16" and variable "MIN_NR_YEARS": ['3']
# type_area_type_area 16
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-26 09:24:18,001	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,015	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,028	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,036	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,047	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,060	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,158	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,168	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,168	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,169	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,182	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,193	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset
# 2018-03-26 09:24:18,206	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-26 09:24:18,220	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None

# %%
ekos.request
# Out:
# {'active': True,
#  'alias': 'test_subset_1',
#  'areas': [{'active': False,
#    'children': [{'active': False,
#      'children': [{'active': False,
#        'label': 'Örefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE633000-195000',
#        'value': 'SE633000-195000'},
#       {'active': False,
#        'label': 'Mjölefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE633710-200500',
#        'value': 'SE633710-200500'},
#       {'active': False,
#        'label': 'Österfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634200-202033',
#        'value': 'SE634200-202033'},
#       {'active': False,
#        'label': 'Västerfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634230-201605',
#        'value': 'SE634230-201605'},
#       {'active': False,
#        'label': 'Ytterbodafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634640-203710',
#        'value': 'SE634640-203710'},
#       {'active': False,
#        'label': 'Täftefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634740-203020',
#        'value': 'SE634740-203020'},
#       {'active': False,
#        'label': 'Lillfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE634950-202940',
#        'value': 'SE634950-202940'},
#       {'active': False,
#        'label': 'Ostnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE635040-204196',
#        'value': 'SE635040-204196'},
#       {'active': False,
#        'label': 'Hörnefors området sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE635660-199490',
#        'value': 'SE635660-199490'},
#       {'active': False,
#        'label': 'Megrundsområdet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE636150-199220',
#        'value': 'SE636150-199220'},
#       {'active': False,
#        'label': 'Fjärdgrundsområdet sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE636570-203590',
#        'value': 'SE636570-203590'},
#       {'active': False,
#        'label': 'Österlångslädan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE636910-204040',
#        'value': 'SE636910-204040'},
#       {'active': False,
#        'label': 'Raggavaviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE637070-204260',
#        'value': 'SE637070-204260'},
#       {'active': False,
#        'label': 'Yttre Täftefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE637310-204860',
#        'value': 'SE637310-204860'},
#       {'active': False,
#        'label': 'Tavlefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE637640-204160',
#        'value': 'SE637640-204160'}],
#      'label': '20 - Norra Kvarkens inre kustvatten',
#      'status': 'selectable',
#      'type': 'value',
#      'value': '20'},
#     {'active': False,
#      'children': [{'active': False,
#        'label': 'S n Kvarkens kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE633550-200700',
#        'value': 'SE633550-200700'},
#       {'active': False,
#        'label': 'N n Kvarkens kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE635300-205251',
#        'value': 'SE635300-205251'}],
#      'label': '21 - Norra Kvarkens yttre kustvatten',
#      'status': 'selectable',
#      'type': 'value',
#      'value': '21'},
#     {'active': False,
#      'children': [{'active': False,
#        'label': 'Bygdefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640240-205500',
#        'value': 'SE640240-205500'},
#       {'active': False,
#        'label': 'Ricklefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640400-205770',
#        'value': 'SE640400-205770'},
#       {'active': False,
#        'label': 'Sikeåfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640900-205935',
#        'value': 'SE640900-205935'},
#       {'active': False,
#        'label': 'Vändskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641000-210500',
#        'value': 'SE641000-210500'},
#       {'active': False,
#        'label': 'Gumbodafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641250-210560',
#        'value': 'SE641250-210560'},
#       {'active': False,
#        'label': 'Lövselefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641745-211570',
#        'value': 'SE641745-211570'},
#       {'active': False,
#        'label': 'Kallviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641875-212250',
#        'value': 'SE641875-212250'},
#       {'active': False,
#        'label': 'Blackefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE642035-212600',
#        'value': 'SE642035-212600'},
#       {'active': False,
#        'label': 'Bjuröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE642950-213400',
#        'value': 'SE642950-213400'},
#       {'active': False,
#        'label': 'Bäckfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643160-212730',
#        'value': 'SE643160-212730'},
#       {'active': False,
#        'label': 'Storsladan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643550-211920',
#        'value': 'SE643550-211920'},
#       {'active': False,
#        'label': 'Burefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643700-211940',
#        'value': 'SE643700-211940'},
#       {'active': False,
#        'label': 'Simpan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643920-211500',
#        'value': 'SE643920-211500'},
#       {'active': False,
#        'label': 'Ytterviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644030-218500',
#        'value': 'SE644030-218500'},
#       {'active': False,
#        'label': 'Sörfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644040-211260',
#        'value': 'SE644040-211260'},
#       {'active': False,
#        'label': 'Skelleftehamnsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644070-211650',
#        'value': 'SE644070-211650'},
#       {'active': False,
#        'label': 'Ursviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644150-211000',
#        'value': 'SE644150-211000'},
#       {'active': False,
#        'label': 'Boviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644730-210650',
#        'value': 'SE644730-210650'},
#       {'active': False,
#        'label': 'Inre Kågefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645000-212100',
#        'value': 'SE645000-212100'},
#       {'active': False,
#        'label': 'Kågefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645000-213500',
#        'value': 'SE645000-213500'},
#       {'active': False,
#        'label': 'Bredviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645130-211040',
#        'value': 'SE645130-211040'},
#       {'active': False,
#        'label': 'Rösnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645340-211330',
#        'value': 'SE645340-211330'},
#       {'active': False,
#        'label': 'Byskefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645500-212000',
#        'value': 'SE645500-212000'},
#       {'active': False,
#        'label': 'Sandvikssundet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645670-214290',
#        'value': 'SE645670-214290'},
#       {'active': False,
#        'label': 'Tåmfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645830-212300',
#        'value': 'SE645830-212300'},
#       {'active': False,
#        'label': 'Åbyfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645950-212650',
#        'value': 'SE645950-212650'},
#       {'active': False,
#        'label': 'Hålfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE647260-212660',
#        'value': 'SE647260-212660'},
#       {'active': False,
#        'label': 'Kinnbäcksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650280-213110',
#        'value': 'SE650280-213110'},
#       {'active': False,
#        'label': 'Bursfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650460-213400',
#        'value': 'SE650460-213400'},
#       {'active': False,
#        'label': 'Jävrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650750-213500',
#        'value': 'SE650750-213500'},
#       {'active': False,
#        'label': 'Bondöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651075-213700',
#        'value': 'SE651075-213700'},
#       {'active': False,
#        'label': 'Vargödraget',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651475-214300',
#        'value': 'SE651475-214300'},
#       {'active': False,
#        'label': 'Yttrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651500-213108',
#        'value': 'SE651500-213108'},
#       {'active': False,
#        'label': 'Baggholmsdraget',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651800-214740',
#        'value': 'SE651800-214740'},
#       {'active': False,
#        'label': 'Inrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651818-212790',
#        'value': 'SE651818-212790'},
#       {'active': False,
#        'label': 'Haraholmsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651940-213930',
#        'value': 'SE651940-213930'},
#       {'active': False,
#        'label': 'Nördfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652000-213210',
#        'value': 'SE652000-213210'},
#       {'active': False,
#        'label': 'Mjoöfjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652000-214000',
#        'value': 'SE652000-214000'},
#       {'active': False,
#        'label': 'Storfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652066-214400',
#        'value': 'SE652066-214400'},
#       {'active': False,
#        'label': 'Davids stenar',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652075-213500',
#        'value': 'SE652075-213500'},
#       {'active': False,
#        'label': 'Rävahavet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652150-213000',
#        'value': 'SE652150-213000'},
#       {'active': False,
#        'label': 'Bärtnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652250-213000',
#        'value': 'SE652250-213000'},
#       {'active': False,
#        'label': 'Håkansöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652250-213430',
#        'value': 'SE652250-213430'},
#       {'active': False,
#        'label': 'Brändöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652385-214180',
#        'value': 'SE652385-214180'},
#       {'active': False,
#        'label': 'Mannöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652400-220070',
#        'value': 'SE652400-220070'},
#       {'active': False,
#        'label': 'Sandgrönnfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652450-222116',
#        'value': 'SE652450-222116'},
#       {'active': False,
#        'label': 'Bastafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652465-214080',
#        'value': 'SE652465-214080'},
#       {'active': False,
#        'label': 'Holfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652475-215750',
#        'value': 'SE652475-215750'},
#       {'active': False,
#        'label': 'Harrbäcksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652500-213500',
#        'value': 'SE652500-213500'},
#       {'active': False,
#        'label': 'Germandöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652686-221500',
#        'value': 'SE652686-221500'},
#       {'active': False,
#        'label': 'Västantillfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652830-222116',
#        'value': 'SE652830-222116'},
#       {'active': False,
#        'label': 'Bastaskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652855-224000',
#        'value': 'SE652855-224000'},
#       {'active': False,
#        'label': 'Sörbrändöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652920-222650',
#        'value': 'SE652920-222650'},
#       {'active': False,
#        'label': 'Saxskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653116-224623',
#        'value': 'SE653116-224623'},
#       {'active': False,
#        'label': 'Degeröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653140-224000',
#        'value': 'SE653140-224000'},
#       {'active': False,
#        'label': 'Sandöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653176-222000',
#        'value': 'SE653176-222000'},
#       {'active': False,
#        'label': 'Hindersöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653303-222900',
#        'value': 'SE653303-222900'},
#       {'active': False,
#        'label': 'Hamnöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653740-222800',
#        'value': 'SE653740-222800'},
#       {'active': False,
#        'label': 'Fjuksöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653900-223280',
#        'value': 'SE653900-223280'},
#       {'active': False,
#        'label': 'S. Sigfridsöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654000-222430',
#        'value': 'SE654000-222430'},
#       {'active': False,
#        'label': 'Båtöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654110-224850',
#        'value': 'SE654110-224850'},
#       {'active': False,
#        'label': 'Tistersöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654200-222920',
#        'value': 'SE654200-222920'},
#       {'active': False,
#        'label': 'Bergöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654291-224000',
#        'value': 'SE654291-224000'},
#       {'active': False,
#        'label': 'N. Sigfridsöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654330-222200',
#        'value': 'SE654330-222200'},
#       {'active': False,
#        'label': 'Skomakarfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654360-235780',
#        'value': 'SE654360-235780'},
#       {'active': False,
#        'label': 'Gussöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654470-222700',
#        'value': 'SE654470-222700'},
#       {'active': False,
#        'label': 'Börstskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654490-220870',
#        'value': 'SE654490-220870'},
#       {'active': False,
#        'label': 'Repskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654500-232000',
#        'value': 'SE654500-232000'},
#       {'active': False,
#        'label': 'Haparandafjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654560-246250',
#        'value': 'SE654560-246250'},
#       {'active': False,
#        'label': 'Rånöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654570-225230',
#        'value': 'SE654570-225230'},
#       {'active': False,
#        'label': 'Seskaröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654575-234250',
#        'value': 'SE654575-234250'},
#       {'active': False,
#        'label': 'Rånefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654820-222660',
#        'value': 'SE654820-222660'},
#       {'active': False,
#        'label': 'Ersnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654860-219880',
#        'value': 'SE654860-219880'},
#       {'active': False,
#        'label': 'Siknäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654990-224540',
#        'value': 'SE654990-224540'},
#       {'active': False,
#        'label': 'Måttsundsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655120-220380',
#        'value': 'SE655120-220380'},
#       {'active': False,
#        'label': 'Möröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655180-218660',
#        'value': 'SE655180-218660'},
#       {'active': False,
#        'label': 'Törefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655260-224280',
#        'value': 'SE655260-224280'},
#       {'active': False,
#        'label': 'Mulöviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656300-222750',
#        'value': 'SE656300-222750'},
#       {'active': False,
#        'label': 'Granöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656620-222480',
#        'value': 'SE656620-222480'},
#       {'active': False,
#        'label': 'Bergnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656840-222800',
#        'value': 'SE656840-222800'},
#       {'active': False,
#        'label': 'Yttre Lulefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE728806-179329',
#        'value': 'SE728806-179329'},
#       {'active': False,
#        'label': 'Inre Lulefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE729159-179002',
#        'value': 'SE729159-179002'},
#       {'active': False,
#        'label': 'Björköfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE729849-180191',
#        'value': 'SE729849-180191'},
#       {'active': False,
#        'label': 'Storöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE731175-867144',
#        'value': 'SE731175-867144'},
#       {'active': False,
#        'label': 'Slumpfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE731734-867204',
#        'value': 'SE731734-867204'},
#       {'active': False,
#        'label': 'Bodöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE732081-888706',
#        'value': 'SE732081-888706'},
#       {'active': False,
#        'label': 'Kroksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE732410-884539',
#        'value': 'SE732410-884539'}],
#      'label': '22 - Bottenviken, inre kustvatten',
#      'status': 'selectable',
#      'type': 'value',
#      'value': '22'},
#     {'active': False,
#      'children': [{'active': False,
#        'label': 'S Bottenvikens kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641250-211751',
#        'value': 'SE641250-211751'},
#       {'active': False,
#        'label': 'Skelleftebukten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE646360-213700',
#        'value': 'SE646360-213700'},
#       {'active': False,
#        'label': 'N m Bottenvikens kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE648760-213140',
#        'value': 'SE648760-213140'},
#       {'active': False,
#        'label': 'Norrbottens skärgårds kustvatten',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652400-223501',
#        'value': 'SE652400-223501'},
#       {'active': False,
#        'label': 'Knivskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653840-247900',
#        'value': 'SE653840-247900'},
#       {'active': False,
#        'label': 'Enskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653870-235570',
#        'value': 'SE653870-235570'},
#       {'active': False,
#        'label': 'S. Seskaröfjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654100-234100',
#        'value': 'SE654100-234100'},
#       {'active': False,
#        'label': 'Katajafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654130-249500',
#        'value': 'SE654130-249500'},
#       {'active': False,
#        'label': 'Hamnskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654150-240380',
#        'value': 'SE654150-240380'}],
#      'label': '23 - Bottenviken, yttre kustvatten',
#      'status': 'selectable',
#      'type': 'value',
#      'value': '23'}],
#    'label': 'SE1',
#    'status': 'selectable',
#    'type': 'water_district',
#    'value': 'SE1'},
#   {'active': False,
#    'children': [{'active': False,
#      'children': [{'active': False,
#        'label': 'Bygdefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640240-205500',
#        'value': 'SE640240-205500'},
#       {'active': False,
#        'label': 'Ricklefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640400-205770',
#        'value': 'SE640400-205770'},
#       {'active': False,
#        'label': 'Sikeåfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE640900-205935',
#        'value': 'SE640900-205935'},
#       {'active': False,
#        'label': 'Vändskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641000-210500',
#        'value': 'SE641000-210500'},
#       {'active': False,
#        'label': 'Gumbodafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641250-210560',
#        'value': 'SE641250-210560'},
#       {'active': False,
#        'label': 'Lövselefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641745-211570',
#        'value': 'SE641745-211570'},
#       {'active': False,
#        'label': 'Kallviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE641875-212250',
#        'value': 'SE641875-212250'},
#       {'active': False,
#        'label': 'Blackefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE642035-212600',
#        'value': 'SE642035-212600'},
#       {'active': False,
#        'label': 'Bjuröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE642950-213400',
#        'value': 'SE642950-213400'},
#       {'active': False,
#        'label': 'Bäckfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643160-212730',
#        'value': 'SE643160-212730'},
#       {'active': False,
#        'label': 'Storsladan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643550-211920',
#        'value': 'SE643550-211920'},
#       {'active': False,
#        'label': 'Burefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643700-211940',
#        'value': 'SE643700-211940'},
#       {'active': False,
#        'label': 'Simpan',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE643920-211500',
#        'value': 'SE643920-211500'},
#       {'active': False,
#        'label': 'Ytterviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644030-218500',
#        'value': 'SE644030-218500'},
#       {'active': False,
#        'label': 'Sörfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644040-211260',
#        'value': 'SE644040-211260'},
#       {'active': False,
#        'label': 'Skelleftehamnsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644070-211650',
#        'value': 'SE644070-211650'},
#       {'active': False,
#        'label': 'Ursviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644150-211000',
#        'value': 'SE644150-211000'},
#       {'active': False,
#        'label': 'Boviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE644730-210650',
#        'value': 'SE644730-210650'},
#       {'active': False,
#        'label': 'Inre Kågefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645000-212100',
#        'value': 'SE645000-212100'},
#       {'active': False,
#        'label': 'Kågefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645000-213500',
#        'value': 'SE645000-213500'},
#       {'active': False,
#        'label': 'Bredviksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645130-211040',
#        'value': 'SE645130-211040'},
#       {'active': False,
#        'label': 'Rösnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645340-211330',
#        'value': 'SE645340-211330'},
#       {'active': False,
#        'label': 'Byskefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645500-212000',
#        'value': 'SE645500-212000'},
#       {'active': False,
#        'label': 'Sandvikssundet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645670-214290',
#        'value': 'SE645670-214290'},
#       {'active': False,
#        'label': 'Tåmfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645830-212300',
#        'value': 'SE645830-212300'},
#       {'active': False,
#        'label': 'Åbyfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE645950-212650',
#        'value': 'SE645950-212650'},
#       {'active': False,
#        'label': 'Hålfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE647260-212660',
#        'value': 'SE647260-212660'},
#       {'active': False,
#        'label': 'Kinnbäcksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650280-213110',
#        'value': 'SE650280-213110'},
#       {'active': False,
#        'label': 'Bursfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650460-213400',
#        'value': 'SE650460-213400'},
#       {'active': False,
#        'label': 'Jävrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE650750-213500',
#        'value': 'SE650750-213500'},
#       {'active': False,
#        'label': 'Bondöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651075-213700',
#        'value': 'SE651075-213700'},
#       {'active': False,
#        'label': 'Vargödraget',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651475-214300',
#        'value': 'SE651475-214300'},
#       {'active': False,
#        'label': 'Yttrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651500-213108',
#        'value': 'SE651500-213108'},
#       {'active': False,
#        'label': 'Baggholmsdraget',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651800-214740',
#        'value': 'SE651800-214740'},
#       {'active': False,
#        'label': 'Inrefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651818-212790',
#        'value': 'SE651818-212790'},
#       {'active': False,
#        'label': 'Haraholmsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE651940-213930',
#        'value': 'SE651940-213930'},
#       {'active': False,
#        'label': 'Nördfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652000-213210',
#        'value': 'SE652000-213210'},
#       {'active': False,
#        'label': 'Mjoöfjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652000-214000',
#        'value': 'SE652000-214000'},
#       {'active': False,
#        'label': 'Storfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652066-214400',
#        'value': 'SE652066-214400'},
#       {'active': False,
#        'label': 'Davids stenar',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652075-213500',
#        'value': 'SE652075-213500'},
#       {'active': False,
#        'label': 'Rävahavet',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652150-213000',
#        'value': 'SE652150-213000'},
#       {'active': False,
#        'label': 'Bärtnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652250-213000',
#        'value': 'SE652250-213000'},
#       {'active': False,
#        'label': 'Håkansöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652250-213430',
#        'value': 'SE652250-213430'},
#       {'active': False,
#        'label': 'Brändöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652385-214180',
#        'value': 'SE652385-214180'},
#       {'active': False,
#        'label': 'Mannöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652400-220070',
#        'value': 'SE652400-220070'},
#       {'active': False,
#        'label': 'Sandgrönnfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652450-222116',
#        'value': 'SE652450-222116'},
#       {'active': False,
#        'label': 'Bastafjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652465-214080',
#        'value': 'SE652465-214080'},
#       {'active': False,
#        'label': 'Holfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652475-215750',
#        'value': 'SE652475-215750'},
#       {'active': False,
#        'label': 'Harrbäcksfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652500-213500',
#        'value': 'SE652500-213500'},
#       {'active': False,
#        'label': 'Germandöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652686-221500',
#        'value': 'SE652686-221500'},
#       {'active': False,
#        'label': 'Västantillfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652830-222116',
#        'value': 'SE652830-222116'},
#       {'active': False,
#        'label': 'Bastaskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652855-224000',
#        'value': 'SE652855-224000'},
#       {'active': False,
#        'label': 'Sörbrändöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE652920-222650',
#        'value': 'SE652920-222650'},
#       {'active': False,
#        'label': 'Saxskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653116-224623',
#        'value': 'SE653116-224623'},
#       {'active': False,
#        'label': 'Degeröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653140-224000',
#        'value': 'SE653140-224000'},
#       {'active': False,
#        'label': 'Sandöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653176-222000',
#        'value': 'SE653176-222000'},
#       {'active': False,
#        'label': 'Hindersöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653303-222900',
#        'value': 'SE653303-222900'},
#       {'active': False,
#        'label': 'Hamnöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653740-222800',
#        'value': 'SE653740-222800'},
#       {'active': False,
#        'label': 'Fjuksöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE653900-223280',
#        'value': 'SE653900-223280'},
#       {'active': False,
#        'label': 'S. Sigfridsöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654000-222430',
#        'value': 'SE654000-222430'},
#       {'active': False,
#        'label': 'Båtöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654110-224850',
#        'value': 'SE654110-224850'},
#       {'active': False,
#        'label': 'Tistersöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654200-222920',
#        'value': 'SE654200-222920'},
#       {'active': False,
#        'label': 'Bergöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654291-224000',
#        'value': 'SE654291-224000'},
#       {'active': False,
#        'label': 'N. Sigfridsöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654330-222200',
#        'value': 'SE654330-222200'},
#       {'active': False,
#        'label': 'Skomakarfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654360-235780',
#        'value': 'SE654360-235780'},
#       {'active': False,
#        'label': 'Gussöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654470-222700',
#        'value': 'SE654470-222700'},
#       {'active': False,
#        'label': 'Börstskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654490-220870',
#        'value': 'SE654490-220870'},
#       {'active': False,
#        'label': 'Repskärsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654500-232000',
#        'value': 'SE654500-232000'},
#       {'active': False,
#        'label': 'Haparandafjärden sek namn',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654560-246250',
#        'value': 'SE654560-246250'},
#       {'active': False,
#        'label': 'Rånöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654570-225230',
#        'value': 'SE654570-225230'},
#       {'active': False,
#        'label': 'Seskaröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654575-234250',
#        'value': 'SE654575-234250'},
#       {'active': False,
#        'label': 'Rånefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654820-222660',
#        'value': 'SE654820-222660'},
#       {'active': False,
#        'label': 'Ersnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654860-219880',
#        'value': 'SE654860-219880'},
#       {'active': False,
#        'label': 'Siknäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE654990-224540',
#        'value': 'SE654990-224540'},
#       {'active': False,
#        'label': 'Måttsundsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655120-220380',
#        'value': 'SE655120-220380'},
#       {'active': False,
#        'label': 'Möröfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655180-218660',
#        'value': 'SE655180-218660'},
#       {'active': False,
#        'label': 'Törefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE655260-224280',
#        'value': 'SE655260-224280'},
#       {'active': False,
#        'label': 'Mulöviken',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656300-222750',
#        'value': 'SE656300-222750'},
#       {'active': False,
#        'label': 'Granöfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656620-222480',
#        'value': 'SE656620-222480'},
#       {'active': False,
#        'label': 'Bergnäsfjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE656840-222800',
#        'value': 'SE656840-222800'},
#       {'active': False,
#        'label': 'Yttre Lulefjärden',
#        'status': 'selectable',
#        'type': 'water_body',
#        'url': ' http://www.viss.lansstyrelsen.se/waters.aspx?waterEUID=SE728806-179329',
# ...
#        'value': '13'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '1n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '7'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '12n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '5'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '14'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '9'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '10'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '17'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '24'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '25'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '22'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '19'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '1s'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '4'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '6'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '12s'}],
#      'status': 'selectable',
#      'value': 'ntot_summer'},
#     {'label': 'Ntot winter',
#      'selected': True,
#      'settings': [{'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '21'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '15'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '11'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '3'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '16'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '20'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '2'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '18'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '23'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '8'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '13'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '1n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '7'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '12n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '5'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '14'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '9'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '10'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '17'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '24'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '25'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '22'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '19'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '1s'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '4'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '6'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ntot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '12s'}],
#      'status': 'selectable',
#      'value': 'ntot_winter'},
#     {'label': 'Ptot summer',
#      'selected': True,
#      'settings': [{'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '21'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '15'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '11'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '3'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '16'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '20'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '2'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '18'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '23'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '8'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '13'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '1n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '7'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '12n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '5'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '14'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '9'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '10'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '17'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '24'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '25'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '22'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '19'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '1s'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '4'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '6'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_summer',
#        'min_no_years': [3],
#        'month_interval': [[6, 8]],
#        'value': '12s'}],
#      'status': 'selectable',
#      'value': 'ptot_summer'},
#     {'label': 'Ptot winter',
#      'selected': True,
#      'settings': [{'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '21'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '15'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '11'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '3'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '16'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '20'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '2'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '18'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '23'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '8'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '13'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '1n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '7'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '12n'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '5'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '14'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '9'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '10'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '17'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '24'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '25'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '22'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[11, 2]],
#        'value': '19'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '1s'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '4'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 3]],
#        'value': '6'},
#       {'depth_interval': [[0, 10]],
#        'indicator': 'ptot_winter',
#        'min_no_years': [3],
#        'month_interval': [[12, 2]],
#        'value': '12s'}],
#      'status': 'selectable',
#      'value': 'ptot_winter'}],
#    'label': 'nutrients'},
#   {'children': [{'label': 'Oxygen',
#      'selected': True,
#      'settings': [],
#      'status': 'selectable',
#      'value': 'o2'}],
#    'label': 'oxygen balance'}],
#  'time': {'year_interval': [2013, 2015]},
#  'uuid': 'fa499f4c-ad1e-4978-b38a-510b672d5a7e'}

# %%
ekos.subset_dict
# Out:
# {'active': True,
#  'alias': 'test_subset_1',
#  'status': 'editable',
#  'uuid': 'fa499f4c-ad1e-4978-b38a-510b672d5a7e'}

# %%
sorted(ekos.mapping_objects['water_body'].get_list('type_area'))
# Out:
# ['10',
#  '11',
#  '12n',
#  '12s',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '1n',
#  '1s',
#  '2',
#  '20',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  '9']

# %%
indicator_settings_object = w.get_indicator_settings_data_filter_object(subset=s_id, 
                                                                                               step='step_2', 
                                                                                               indicator='bqi')

# %%
indicator_settings_object.get_value(type_area='1', variable='DEPH_INTERVAL')
# Out:
# 1
# Index(['INDICATOR', 'TYPE_AREA_NUMBER', 'TYPE_AREA_SUFFIX', 'DEPH_INTERVAL',
#        'MIN_NR_YEARS', 'MIN_NR_VALUES', 'MONTH_LIST', 'HG', 'GM', 'MP', 'PB',
#        'MAX BQIM', 'EK H/G', 'EK G/M', 'EK M/P', 'EK P/B', 'PARAM',
#        'QUALITYELEMENT'],
#       dtype='object')
# type_area_type_area 1
# [[5, 20], [20, 500]]

# %%
file_path = 'D:/Utveckling/git/ekostat_calculator/workspaces/default_workspace/subsets/default_subset/step_2/settings/indicator_settings/din_winter.set'
df = pd.read_csv(file_path, sep='\t', encoding='cp1252')

# %%
df.head()
# Out:
#    Type_Area_number Type_Area_suffix filter_DEPH_INTERVAL_int  \
# 0                 1                n                     0-10
# 1                 1                s                     0-10
# 2                 2              NaN                     0-10
# 3                 3              NaN                     0-10
# 4                 4              NaN                     0-10
#
#    tolerance_MIN_NR_YEARS_int  tolerance_MIN_NR_VALUES_int  \
# 0                           3                            3
# 1                           3                            3
# 2                           3                            3
# 3                           3                            3
# 4                           3                            3
#
#    tolerance_TIME_DELTA_TOLERANCE  tolerance_POS_RADIUS_TOLERANCE  \
# 0                               3                             0.1
# 1                               3                             0.1
# 2                               3                             0.1
# 3                               3                             0.1
# 4                               3                             0.1
#
#    tolerance_DEPH_TOLERANCE_int filter_MONTH_LIST_int    ref_EKV Ref  \
# 0                             5              12;1;2;3  -0.51852*s+20
# 1                             5              12;1;2;3    -0.525*s+15
# 2                             5              12;1;2;3  -0.51852*s+20
# 3                             5              12;1;2;3  -0.51852*s+20
# 4                             5              12;1;2;3    -0.525*s+15
#
#       ref_EKV H/G     ref_EKV G/M      ref_EKV M/O    ref_EKV O/D  ref_EK H/G  \
# 0   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 1  -0.656*s+18.75  -0.7875*s+22.5  -1.1813*s+33.75  -1.838*s+52.5         0.8
# 2   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 3   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 4  -0.656*s+18.75  -0.7875*s+22.5  -1.1813*s+33.75  -1.838*s+52.5         0.8
#
#    ref_EK G/M  ref_EK M/O  ref_EK O/D  ref_Salinity max
# 0        0.66        0.44        0.28                27
# 1        0.67        0.44        0.29                20
# 2        0.66        0.44        0.28                27
# 3        0.66        0.44        0.28                27
# 4        0.67        0.44        0.29                20

# %%
df.loc[df['Type_Area_number']==2, 'tolerance_MIN_NR_YEARS_int']=[9]

# %%
df.head()
# Out:
#    Type_Area_number Type_Area_suffix filter_DEPH_INTERVAL_int  \
# 0                 1                n                     0-10
# 1                 1                s                     0-10
# 2                 2              NaN                     0-10
# 3                 3              NaN                     0-10
# 4                 4              NaN                     0-10
#
#    tolerance_MIN_NR_YEARS_int  tolerance_MIN_NR_VALUES_int  \
# 0                           1                            3
# 1                           9                            3
# 2                           3                            3
# 3                           3                            3
# 4                           3                            3
#
#    tolerance_TIME_DELTA_TOLERANCE  tolerance_POS_RADIUS_TOLERANCE  \
# 0                               3                             0.1
# 1                               3                             0.1
# 2                               3                             0.1
# 3                               3                             0.1
# 4                               3                             0.1
#
#    tolerance_DEPH_TOLERANCE_int filter_MONTH_LIST_int    ref_EKV Ref  \
# 0                             5              12;1;2;3  -0.51852*s+20
# 1                             5              12;1;2;3    -0.525*s+15
# 2                             5              12;1;2;3  -0.51852*s+20
# 3                             5              12;1;2;3  -0.51852*s+20
# 4                             5              12;1;2;3    -0.525*s+15
#
#       ref_EKV H/G     ref_EKV G/M      ref_EKV M/O    ref_EKV O/D  ref_EK H/G  \
# 0   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 1  -0.656*s+18.75  -0.7875*s+22.5  -1.1813*s+33.75  -1.838*s+52.5         0.8
# 2   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 3   -0.64815*s+25   -0.77778*s+30     -1.1667*s+45   -1.8148*s+70         0.8
# 4  -0.656*s+18.75  -0.7875*s+22.5  -1.1813*s+33.75  -1.838*s+52.5         0.8
#
#    ref_EK G/M  ref_EK M/O  ref_EK O/D  ref_Salinity max
# 0        0.66        0.44        0.28                27
# 1        0.67        0.44        0.29                20
# 2        0.66        0.44        0.28                27
# 3        0.66        0.44        0.28                27
# 4        0.67        0.44        0.29                20

# %%
# Reload when code changed:
# %load_ext autoreload
# %autoreload 2
# %pwd
import sys
import os
path = "../"
sys.path.append(path)
#os.path.abspath("../")
print(os.path.abspath(path))
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# D:\Utveckling\git\ekostat_calculator

# %%
import os 
import core
import logging
import importlib
importlib.reload(core) 
try:
    logging.shutdown()
    importlib.reload(logging)
except:
    pass
import pandas as pd
import numpy as np
import json

from event_handler import EventHandler
print(core.__file__)
pd.__version__
# Out:
# ..\core\__init__.py
# '0.19.2'

# %%
user_id_1 = 'user_1'
user_id_2 = 'user_2'
ekos = EventHandler(path)
user_1_ws_1 = 'mw1'
# Out:
# 2018-03-23 10:32:01,441	logger.py	85	add_log	DEBUG
# 2018-03-23 10:32:01,443	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-23 10:32:01,445	logger.py	87	add_log	DEBUG	### Log added for log_id "event_handler" at locaton: ..\log\main_event_handler.log
# 2018-03-23 10:32:01,447	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-03-23 10:32:01,451	event_handler.py	64	__init__	DEBUG	Start EventHandler: event_handler
# 2018-03-23 10:32:01,455	event_handler.py	65	__init__	DEBUG
# 2018-03-23 10:32:01,458	event_handler.py	66	__init__	INFO	TEST info logger
# 2018-03-23 10:32:01,460	event_handler.py	67	__init__	WARNING	TEST warning logger
# 2018-03-23 10:32:01,463	event_handler.py	68	__init__	ERROR	TEST error logger
# 2018-03-23 10:32:01,465	event_handler.py	69	__init__	DEBUG	TEST debug logger
# ====================================================================================================
# event_handler
# ..//log
# main
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# event_handler _ main_event_handler

# %%
ekos.copy_workspace(user_id_1, source_alias='default_workspace', target_alias=user_1_ws_1)
ekos.copy_workspace(user_id_1, source_alias='default_workspace', target_alias='mw2')

ekos.copy_workspace(user_id_2, source_alias='default_workspace', target_alias='test1')
ekos.copy_workspace(user_id_2, source_alias='default_workspace', target_alias='test2')
# Out:
# 2018-03-23 10:32:02,010	event_handler.py	229	copy_workspace	DEBUG	Could not add workspace with alias "mw1". Workspace already exists!
# 2018-03-23 10:32:02,024	event_handler.py	229	copy_workspace	DEBUG	Could not add workspace with alias "mw2". Workspace already exists!
# 2018-03-23 10:32:02,036	event_handler.py	229	copy_workspace	DEBUG	Could not add workspace with alias "test1". Workspace already exists!
# 2018-03-23 10:32:02,051	event_handler.py	229	copy_workspace	DEBUG	Could not add workspace with alias "test2". Workspace already exists!
# ¤ mw1
# ¤ user_1
# ¤ mw2
# ¤ user_1
# ¤ test1
# ¤ user_2
# ¤ test2
# ¤ user_2
# False

# %%
ekos.load_test_requests()

# %%
# Request workspace list 
request = ekos.test_requests['request_workspace_list']
response = ekos.request_workspace_list(request) 
ekos.write_test_response('request_workspace_list', response)
# Out:
# 2018-03-23 10:32:03,501	event_handler.py	1860	request_workspace_list	DEBUG	Start: request_workspace_list
# status ['editable', 'readable', 'deleted', 'inactive']
# status ['editable', 'readable', 'deleted', 'inactive']
# status ['editable', 'readable', 'deleted', 'inactive']
# status ['editable', 'readable', 'deleted', 'inactive']

# %%
# Request subset list 
request = ekos.test_requests['request_subset_list']
response_subset_list = ekos.request_subset_list(request)
ekos.write_test_response('request_subset_list', response_subset_list)
# Out:
# 2018-03-23 10:32:04,565	event_handler.py	1709	request_subset_list	DEBUG	Start: request_subset_list
# 2018-03-23 10:32:04,574	event_handler.py	1463	load_workspace	DEBUG	Trying to load workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "mw1"
# workspace_uuid 1a77220d-e76a-4224-a98c-8c0c234150d9
# status ['editable', 'readable', 'deleted']
# ¤¤¤ alias mw1
# ¤¤¤ unique_id 1a77220d-e76a-4224-a98c-8c0c234150d9
# ¤¤¤ user_id user_1
#
# ====================================================================================================
# Initiating WorkSpace: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9
# Parent directory is: ..//workspaces
# Resource directory is: ..//resources
# 2018-03-23 10:32:04,852	logger.py	85	add_log	DEBUG
# 2018-03-23 10:32:04,854	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-23 10:32:04,856	logger.py	87	add_log	DEBUG	### Log added for log_id "default_subset" at locaton: ..\workspaces\1a77220d-e76a-4224-a98c-8c0c234150d9\log\subset_default_subset.log
# 2018-03-23 10:32:04,859	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# 2018-03-23 10:32:04,907	logger.py	85	add_log	DEBUG
# 2018-03-23 10:32:04,908	logger.py	86	add_log	DEBUG	========================================================================================================================
# 2018-03-23 10:32:04,911	logger.py	87	add_log	DEBUG	### Log added for log_id "fa499f4c-ad1e-4978-b38a-510b672d5a7e" at locaton: ..\workspaces\1a77220d-e76a-4224-a98c-8c0c234150d9\log\subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e.log
# 2018-03-23 10:32:04,914	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# === default_subset
# !!! default_subset
# !!! default_subset
# !!! ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/default_subset
# ===
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/default_subset
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/default_subset/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/default_subset/step_2
# ====================================================================================================
# default_subset
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/log
# subset
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# default_subset _ main_event_handler
# default_subset _ subset_default_subset
# === fa499f4c-ad1e-4978-b38a-510b672d5a7e
# status ['editable', 'readable', 'deleted']
# !!! test_subset_1
# !!! fa499f4c-ad1e-4978-b38a-510b672d5a7e
# !!! ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets
# ----------------------------------------------------------------------------------------------------
# Initiating Subset: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/fa499f4c-ad1e-4978-b38a-510b672d5a7e
# ===
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/fa499f4c-ad1e-4978-b38a-510b672d5a7e
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/fa499f4c-ad1e-4978-b38a-510b672d5a7e/step_1
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/subsets/fa499f4c-ad1e-4978-b38a-510b672d5a7e/step_2
# ====================================================================================================
# fa499f4c-ad1e-4978-b38a-510b672d5a7e
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/log
# subset
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset', 'subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# fa499f4c-ad1e-4978-b38a-510b672d5a7e _ main_event_handler
# fa499f4c-ad1e-4978-b38a-510b672d5a7e _ subset_default_subset
# fa499f4c-ad1e-4978-b38a-510b672d5a7e _ subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e
# load_water_body_station_filter
# Initiating WorkStep: ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/step_0
# 2018-03-23 10:32:05,131	logger.py	85	add_log	DEBUG
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1719, in request_subset_list
#     self.assure_data_is_loaded(user_id=user_id, workspace_uuid=workspace_uuid)
#   File "..\event_handler.py", line 1390, in assure_data_is_loaded
#     self.assure_workspace_is_loaded(user_id=user_id, workspace_uuid=workspace_uuid)
#   File "..\event_handler.py", line 1406, in assure_workspace_is_loaded
#     self.load_workspace(user_id=user_id, unique_id=workspace_uuid)
#   File "..\event_handler.py", line 1468, in load_workspace
#     user_id=user_id)
#   File "..\core\workspaces.py", line 736, in __init__
#     self._set_logger(self.unique_id)
#   File "..\core\workspaces.py", line 838, in _set_logger
#     prefix='workspace')
#   File "..\core\logger.py", line 86, in add_log
#     log.debug('='*120)
# Message: '========================================================================================================================'
# Arguments: ()
# 2018-03-23 10:32:05,133	logger.py	86	add_log	DEBUG	========================================================================================================================
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1719, in request_subset_list
#     self.assure_data_is_loaded(user_id=user_id, workspace_uuid=workspace_uuid)
#   File "..\event_handler.py", line 1390, in assure_data_is_loaded
#     self.assure_workspace_is_loaded(user_id=user_id, workspace_uuid=workspace_uuid)
#   File "..\event_handler.py", line 1406, in assure_workspace_is_loaded
#     self.load_workspace(user_id=user_id, unique_id=workspace_uuid)
#   File "..\event_handler.py", line 1468, in load_workspace
#     user_id=user_id)
#   File "..\core\workspaces.py", line 736, in __init__
#     self._set_logger(self.unique_id)
#   File "..\core\workspaces.py", line 838, in _set_logger
#     prefix='workspace')
#   File "..\core\logger.py", line 87, in add_log
#     log.debug('### Log added for log_id "{}" at locaton: {}'.format(log_id, str(log_path)))
# Message: '### Log added for log_id "1a77220d-e76a-4224-a98c-8c0c234150d9" at locaton: ..\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log'
# Arguments: ()
# 2018-03-23 10:32:05,146	logger.py	87	add_log	DEBUG	### Log added for log_id "1a77220d-e76a-4224-a98c-8c0c234150d9" at locaton: ..\workspaces\1a77220d-e76a-4224-a98c-8c0c234150d9\log\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1719, in request_subset_list
#     self.assure_data_is_loaded(user_id=user_id, workspace_uuid=workspace_uuid)
#   File "..\event_handler.py", line 1390, in assure_data_is_loaded
#     self.assure_workspace_is_loaded(user_id=user_id, workspace_uuid=workspace_uuid)
#   File "..\event_handler.py", line 1406, in assure_workspace_is_loaded
#     self.load_workspace(user_id=user_id, unique_id=workspace_uuid)
#   File "..\event_handler.py", line 1468, in load_workspace
#     user_id=user_id)
#   File "..\core\workspaces.py", line 736, in __init__
#     self._set_logger(self.unique_id)
#   File "..\core\workspaces.py", line 838, in _set_logger
#     prefix='workspace')
#   File "..\core\logger.py", line 88, in add_log
#     log.debug('-'*120)
# Message: '------------------------------------------------------------------------------------------------------------------------'
# Arguments: ()
# 2018-03-23 10:32:05,160	logger.py	88	add_log	DEBUG	------------------------------------------------------------------------------------------------------------------------
# ====================================================================================================
# 1a77220d-e76a-4224-a98c-8c0c234150d9
# ..//workspaces/1a77220d-e76a-4224-a98c-8c0c234150d9/log
# workspace
# ----------------------------------------------------------------------------------------------------
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# dict_keys(['main_event_handler', 'subset_default_subset', 'subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e', 'workspace_1a77220d-e76a-4224-a98c-8c0c234150d9'])
# ¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤¤
# 1a77220d-e76a-4224-a98c-8c0c234150d9 _ main_event_handler
# 1a77220d-e76a-4224-a98c-8c0c234150d9 _ subset_default_subset
# 1a77220d-e76a-4224-a98c-8c0c234150d9 _ subset_fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 1a77220d-e76a-4224-a98c-8c0c234150d9 _ workspace_1a77220d-e76a-4224-a98c-8c0c234150d9
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1719, in request_subset_list
#     self.assure_data_is_loaded(user_id=user_id, workspace_uuid=workspace_uuid)
#   File "..\event_handler.py", line 1394, in assure_data_is_loaded
#     workspace_object.load_all_data()
#   File "..\core\workspaces.py", line 1381, in load_all_data
#     self._logger.debug('data has been loaded from existing all_data.txt file.')
# Message: 'data has been loaded from existing all_data.txt file.'
# Arguments: ()
# 2018-03-23 10:32:09,044	workspaces.py	1381	load_all_data	DEBUG	data has been loaded from existing all_data.txt file.
# status ['editable', 'readable', 'deleted', 'inactive']
# =====SUBSET_UUID "default_subset"
# status ['editable', 'readable', 'deleted', 'inactive']
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# subset_unique_id default_subset
# SUBSET_UNIQUE_ID default_subset
# list_quality_elements []
# list_supporting_elements []
# request []
# =====SUBSET_UUID "fa499f4c-ad1e-4978-b38a-510b672d5a7e"
# status ['editable', 'readable', 'deleted', 'inactive']
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1724, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 1137, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 659, in dict_subset
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 1089, in list_quality_elements
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 593, in dict_quality_element
#     include_indicator_settings=include_indicator_settings)}
#   File "..\event_handler.py", line 958, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1273, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1250, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-23 10:32:12,087	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# list_quality_elements []
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1724, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 1137, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 659, in dict_subset
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 1089, in list_quality_elements
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 593, in dict_quality_element
#     include_indicator_settings=include_indicator_settings)}
#   File "..\event_handler.py", line 958, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1273, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1250, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-23 10:32:12,121	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1724, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 1137, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 659, in dict_subset
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 1089, in list_quality_elements
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 593, in dict_quality_element
#     include_indicator_settings=include_indicator_settings)}
#   File "..\event_handler.py", line 958, in list_indicators
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1273, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1250, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-23 10:32:12,141	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
# ...
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1724, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 1137, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 665, in dict_subset
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 1178, in list_supporting_elements
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 593, in dict_quality_element
#     include_indicator_settings=include_indicator_settings)}
#   File "..\event_handler.py", line 975, in list_indicators
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 375, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1273, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1250, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-23 10:32:17,581	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1724, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 1137, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 665, in dict_subset
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 1178, in list_supporting_elements
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 593, in dict_quality_element
#     include_indicator_settings=include_indicator_settings)}
#   File "..\event_handler.py", line 975, in list_indicators
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 375, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1273, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1250, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-23 10:32:17,599	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# --- Logging error ---
# Traceback (most recent call last):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 72, in emit
#     self.doRollover()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 173, in doRollover
#     self.rotate(self.baseFilename, dfn)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\logging\handlers.py", line 113, in rotate
#     os.rename(source, dest)
# PermissionError: [WinError 32] Det går inte att komma åt filen eftersom den
# används av en annan process: 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log' -> 'D:\\Utveckling\\git\\ekostat_calculator\\workspaces\\1a77220d-e76a-4224-a98c-8c0c234150d9\\log\\workspace_1a77220d-e76a-4224-a98c-8c0c234150d9.log.1'
# Call stack:
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 193, in _run_module_as_main
#     "__main__", mod_spec)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\runpy.py", line 85, in _run_code
#     exec(code, run_globals)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel_launcher.py", line 16, in <module>
#     app.launch_new_instance()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\traitlets\config\application.py", line 658, in launch_instance
#     app.start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelapp.py", line 477, in start
#     ioloop.IOLoop.instance().start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\ioloop.py", line 177, in start
#     super(ZMQIOLoop, self).start()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\ioloop.py", line 888, in start
#     handler_func(fd_obj, events)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 440, in _handle_events
#     self._handle_recv()
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 472, in _handle_recv
#     self._run_callback(callback, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\zmq\eventloop\zmqstream.py", line 414, in _run_callback
#     callback(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\tornado\stack_context.py", line 277, in null_wrapper
#     return fn(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 283, in dispatcher
#     return self.dispatch_shell(stream, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 235, in dispatch_shell
#     handler(stream, idents, msg)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\kernelbase.py", line 399, in execute_request
#     user_expressions, allow_stdin)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\ipkernel.py", line 196, in do_execute
#     res = shell.run_cell(code, store_history=store_history, silent=silent)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\ipykernel\zmqshell.py", line 533, in run_cell
#     return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2698, in run_cell
#     interactivity=interactivity, compiler=compiler, result=result)
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2802, in run_ast_nodes
#     if self.run_code(code, result):
#   File "C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py", line 2862, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-213-351be3f19541>", line 3, in <module>
#     response_subset_list = ekos.request_subset_list(request)
#   File "..\event_handler.py", line 1724, in request_subset_list
#     subset_list = self.list_subsets(workspace_unique_id=workspace_uuid, user_id=user_id)
#   File "..\event_handler.py", line 1137, in list_subsets
#     request=sub_request)
#   File "..\event_handler.py", line 665, in dict_subset
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 1178, in list_supporting_elements
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 593, in dict_quality_element
#     include_indicator_settings=include_indicator_settings)}
#   File "..\event_handler.py", line 975, in list_indicators
#     include_indicator_settings=include_indicator_settings)
#   File "..\event_handler.py", line 375, in dict_indicator
#     available_indicators = workspace_object.get_available_indicators(subset=subset_unique_id, step='step_1')
#   File "..\core\workspaces.py", line 1273, in get_available_indicators
#     self.get_filtered_data(step = step, subset = subset)[parameter_list].apply(pd.to_numeric).dropna(thresh = len(parameter_list))
#   File "..\core\workspaces.py", line 1250, in get_filtered_data
#     self._logger.debug('STEP: {}'.format(step))
# Message: 'STEP: step_1'
# Arguments: ()
# 2018-03-23 10:32:17,621	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None

# %%
# Load default data
request = ekos.test_requests['request_workspace_load_default_data']
response = ekos.request_workspace_load_default_data(request) 
print(response)
# Out:
# 2018-03-23 08:38:26,081	event_handler.py	1821	request_workspace_load_default_data	DEBUG	Start: request_workspace_load_default_data
# user_id user_1
# 1a77220d-e76a-4224-a98c-8c0c234150d9
# ['1a77220d-e76a-4224-a98c-8c0c234150d9', '2e12443d-2537-450f-ba4f-d5a13a0db247', 'f1fb96b8-8b08-4075-b53d-89471c15a429']
# 2018-03-23 08:38:26,661	workspaces.py	944	import_default_data	DEBUG	Default data has been copied to workspace raw data folder.
# 2018-03-23 08:38:30,137	workspaces.py	1381	load_all_data	DEBUG	data has been loaded from existing all_data.txt file.
# {'all_ok': True, 'message': ''}

# %%
# Edit workspace
request = ekos.test_requests['request_workspace_edit']
response = ekos.request_workspace_edit(request)
# Out:
# 2018-03-23 08:38:30,341	event_handler.py	1756	request_workspace_edit	DEBUG	Start: request_workspace_edit

# %%
# Delete workspace
request = ekos.test_requests['request_workspace_delete']
response = ekos.request_workspace_delete(request)
# Out:
# 2018-03-23 08:38:30,518	event_handler.py	1715	request_workspace_delete	DEBUG	Start: request_workspace_delete
# 2018-03-23 08:38:30,529	event_handler.py	334	delete_workspace	WARNING	Removing workspace "433942c2-38db-4463-9925-b0135c0b7482" with alias "test2".
# status ['editable', 'readable', 'deleted']

# %%
# Add new subset 
request = ekos.test_requests['request_subset_add']
response_subset_add = ekos.request_subset_add(request)
ekos.write_test_response('request_subset_add', response_subset_add)
# Out:
# 2018-03-23 08:38:30,705	event_handler.py	1438	request_subset_add	DEBUG	Start: request_subset_add
# 2018-03-23 08:38:30,705	event_handler.py	201	copy_subset	DEBUG	Trying to copy subset "default_subset". Copy has alias "test_subset_1"
# 2018-03-23 08:38:30,706	workspaces.py	1078	copy_subset	DEBUG	Could not add subset with alias "test_subset_1". Subset already exists!
# 2018-03-23 08:38:30,720	event_handler.py	414	dict_time	WARNING	Could not find subset object False. Subset is probably not loaded.
# SUBSET_SOURCE_UUID default_subset
# status ['editable', 'readable', 'deleted']
# SUBSET_SOURCE_ALIAS default_subset
# default_subset test_subset_1
# self.user_id user_1
# ¤ test_subset_1
# ¤ user_1
# target_uuid False
# RETURN_DICT False
# test_subset_1 user_1
# status ['editable', 'readable', 'deleted', 'inactive']
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# 2018-03-23 08:38:30,725	event_handler.py	767	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,730	event_handler.py	767	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,733	event_handler.py	767	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,736	event_handler.py	767	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,738	event_handler.py	767	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,741	event_handler.py	767	dict_water_district	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,743	event_handler.py	557	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,745	event_handler.py	557	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,747	event_handler.py	557	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,749	event_handler.py	557	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,752	event_handler.py	557	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# 2018-03-23 08:38:30,754	event_handler.py	557	dict_quality_element	WARNING	Could not find subset object False. Subset is probably not loaded.
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# subset_unique_id False
# SUBSET_UNIQUE_ID False
# list_quality_elements []
# list_supporting_elements []
# request []

# %%
ekos.temp_return_dict
# Out:
# False

# %%
# Edit subset 
request = ekos.test_requests['request_subset_edit']
response_subset_edit = ekos.request_subset_edit(request)
ekos.write_test_response('request_subset_edit', response_subset_edit)
# Out:
# 2018-03-23 10:30:22,755	event_handler.py	1556	request_subset_edit	DEBUG	Start: request_subset_edit
# 2018-03-23 10:30:22,760	event_handler.py	908	get_workspace	DEBUG	Getting workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "None"

# %%
w_id = '1a77220d-e76a-4224-a98c-8c0c234150d9'
s_id = 'fa499f4c-ad1e-4978-b38a-510b672d5a7e'

# %%
w = ekos.get_workspace(user_id=user_id_1, unique_id=w_id)
# Out:
# 2018-03-23 10:26:35,074	event_handler.py	908	get_workspace	DEBUG	Getting workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "None"

# %%
w.index_handler.data_handler_object.all_data.head()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-71c6b3c00950> in <module>()
# ----> 1 w.index_handler.data_handler_object.all_data.head()
#
# AttributeError: 'NoneType' object has no attribute 'index_handler'

# %%
# w.index_handler.booleans

# %%
# Apply data filter step_0
ekos.apply_data_filter(user_id=user_id_1,  
                           workspace_uuid=w_id,
                           step='step_0')
# Out:
# step step_0

# %%
# Apply data filter step_1
ekos.apply_data_filter(user_id=user_id_1,  
                           workspace_uuid=w_id,
                           subset_uuid=s_id, 
                           step='step_1')
# Out:
# step step_1

# %%
# Apply indicator data filter (step_2) 
indicator = 'din_winter'
water_body_1 = 'SE575340-113000' # Marstrandsfjorden, type_area=3
water_body_2 = 'SE572072-115880' # Varren, type_area=1s
water_body_3 = 'SE582000-112350' # Yttre Brofjorden, type_area=1n
ekos.apply_indicator_data_filter(user_id=user_id_1,  
                                 workspace_uuid=w_id,
                                 subset_uuid=s_id, 
                                 indicator=indicator, 
                                 water_body=water_body_3)
# Out:
# step step_2
# WWW SE582000-112350
# ===
# water_body SE582000-112350
# type_area 1-n
# RESULT [[0, 10]]

# %%
directory = 'D:/temp_ekostat'
data_step_0 = w.get_filtered_data(step=0)
data_step_0.to_csv('{}/data_step_0.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# 2018-03-23 10:33:03,469	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_0
# water_body None

# %%
directory = 'D:/temp_ekostat'
data_step_1 = w.get_filtered_data(step=1, subset=s_id)
data_step_1.to_csv('{}/data_step_1.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# 2018-03-23 10:33:09,968	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# water_body None

# %%
directory = 'D:/temp_ekostat'
data_step_2 = w.get_filtered_data(step=2, subset=s_id, indicator=indicator, water_body=water_body_3)
data_step_2.to_csv('{}/data_step_2.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# 2018-03-23 10:33:13,908	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_2
# water_body SE582000-112350

# %%
w.index_handler.data_handler_object.all_data.columns
# Out:
# Index(['Unnamed: 0', 'AMON', 'BIOV_CONC_ALL', 'BQIm', 'CPHL_INTEG', 'DEPH',
#        'DIN', 'DOXY_BTL', 'DOXY_CTD', 'LATIT_DD', 'LONGI_DD', 'MNDEP', 'MXDEP',
#        'MYEAR', 'NTOT', 'NTRA', 'NTRI', 'NTRZ', 'PHOS', 'PTOT', 'Q_AMON',
#        'Q_BIOV_CONC_ALL', 'Q_BQIm', 'Q_CPHL_INTEG', 'Q_DOXY_BTL', 'Q_DOXY_CTD',
#        'Q_NTOT', 'Q_NTRA', 'Q_NTRI', 'Q_NTRZ', 'Q_PHOS', 'Q_PTOT',
#        'Q_SALT_BTL', 'Q_SALT_CTD', 'Q_SECCHI', 'Q_TEMP_BTL', 'Q_TEMP_CTD',
#        'SALT_BTL', 'SALT_CTD', 'SDATE', 'SEA_BASIN', 'SECCHI', 'SERNO',
#        'SHARKID_MD5', 'SHIPC', 'STATN', 'STIME', 'TEMP_BTL', 'TEMP_CTD',
#        'VISS_EU_CD', 'WATER_BODY_NAME', 'WATER_DISTRICT', 'WATER_TYPE_AREA',
#        'WLTYP', 'MONTH'],
#       dtype='object')

# %%
din_winter = w.get_indicator_settings_data_filter_object(subset=s_id, indicator=indicator)
boolean = din_winter.get_filter_boolean_for_df(w.index_handler.data_handler_object.all_data, water_body=water_body_3) 
w.index_handler.data_handler_object.all_data.loc[boolean, :].to_csv('{}/test_data.txt'.format(directory), sep='\t', index=False, encoding='cp1252')
# Out:
# WWW SE582000-112350
# ===
# water_body SE582000-112350
# type_area 1-n
# 1-n
# type_area_type_area 1-n
# 1-n
# 1
# n
# Index(['TYPE_AREA_NUMBER', 'TYPE_AREA_SUFFIX', 'DEPH_INTERVAL', 'MIN_NR_YEARS',
#        'MIN_NR_VALUES', 'TIME_DELTA_TOLERANCE', 'POS_RADIUS_TOLERANCE',
#        'DEPH_TOLERANCE', 'MONTH_LIST', 'EKV REF', 'EKV H/G', 'EKV G/M',
#        'EKV M/O', 'EKV O/D', 'EK H/G', 'EK G/M', 'EK M/O', 'EK O/D',
#        'SALINITY MAX'],
#       dtype='object')
# ----
# 0    0-10
# Name: DEPH_INTERVAL, dtype: object <class 'pandas.core.series.Series'>
# ['0-10'] <class 'numpy.ndarray'>
# 0-10
# 0-10
# DEPH_INTERVAL
# = [0, 10] <class 'int'>
# RESULT [[0, 10]]
# 1-n
# type_area_type_area 1-n
# 1-n
# 1
# n
# Index(['TYPE_AREA_NUMBER', 'TYPE_AREA_SUFFIX', 'DEPH_INTERVAL', 'MIN_NR_YEARS',
#        'MIN_NR_VALUES', 'TIME_DELTA_TOLERANCE', 'POS_RADIUS_TOLERANCE',
#        'DEPH_TOLERANCE', 'MONTH_LIST', 'EKV REF', 'EKV H/G', 'EKV G/M',
#        'EKV M/O', 'EKV O/D', 'EK H/G', 'EK G/M', 'EK M/O', 'EK O/D',
#        'SALINITY MAX'],
#       dtype='object')
# ----
# 0    12;1;2;3
# Name: MONTH_LIST, dtype: object <class 'pandas.core.series.Series'>
# ['12;1;2;3'] <class 'numpy.ndarray'>
# 12;1;2;3
# 12;1;2;3
# MONTH_LIST
# = [12, 1, 2, 3] <class 'int'>

# %%
# all_data = w.index_handler.data_handler_object.all_data 
# boolean = din_winter.get_filter_boolean_for_df(df=all_data, water_body=water_body_3)
# din_winter_data = all_data.loc[boolean, :]
# din_winter_data.to_csv('{}/din_winter_data.txt'.format(directory), sep='\t', index=False, encoding='cp1252')

# %%
# np.where(din_winter.settings.temp_boolean_list)

# %%
type_area = ekos.mapping_objects['water_body'].get_list('type_area', water_body='SE'+water_body_3)
print(type_area)
indicator_settings_response = ekos.dict_indicator_settings(workspace_unique_id=w_id, 
                                                           subset_unique_id=s_id,
                                                           indicator=indicator, 
                                                           type_area=type_area)
# Out:
# []
# ==================================================
# 1a77220d-e76a-4224-a98c-8c0c234150d9
# fa499f4c-ad1e-4978-b38a-510b672d5a7e
# din_winter
# ==================================================

# %%
indicator_settings_response
# Out:
# {}

# %%
# Subset info  
ekos.load_test_requests()
request = ekos.test_requests['request_subset_info']
response_subset_info = ekos.request_subset_info(request)
ekos.write_test_response('request_subset_info', response_subset_info)
# Out:
# 2018-03-23 10:38:32,120	event_handler.py	1580	request_subset_info	DEBUG	Start: request_subset_info
# 2018-03-23 10:38:32,126	event_handler.py	908	get_workspace	DEBUG	Getting workspace "1a77220d-e76a-4224-a98c-8c0c234150d9" with alias "None"
# status ['editable', 'readable', 'deleted', 'inactive']
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# 2018-03-23 10:38:33,772	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,779	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# subset_unique_id fa499f4c-ad1e-4978-b38a-510b672d5a7e
# SUBSET_UNIQUE_ID fa499f4c-ad1e-4978-b38a-510b672d5a7e
# list_quality_elements []
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body
# 2018-03-23 10:38:33,787	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,795	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,803	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,811	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,817	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,831	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,838	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,849	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,856	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,863	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,872	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,883	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,889	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,900	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,915	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,923	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,930	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,938	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,948	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,959	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,969	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
# 2018-03-23 10:38:33,979	workspaces.py	1250	get_filtered_data	DEBUG	STEP: step_1
#  None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# "['TOT_COVER_ALL' 'SALT'] not in index"
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# subset fa499f4c-ad1e-4978-b38a-510b672d5a7e
# water_body None
# nan
# Index(['INDICATOR', 'TYPE_AREA_NUMBER', 'TYPE_AREA_SUFFIX', 'DEPH_INTERVAL',
#        'MIN_NR_YEARS', 'MIN_NR_VALUES', 'MONTH_LIST', 'HG', 'GM', 'MP', 'PB',
#        'MAX BQIM', 'EK H/G', 'EK G/M', 'EK M/P', 'EK P/B', 'PARAM',
#        'QUALITYELEMENT'],
#       dtype='object')
# type_area_type_area nan
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-227-f6c462a7ff27> in <module>()
#       2 ekos.load_test_requests()
#       3 request = ekos.test_requests['request_subset_info']
# ----> 4 response_subset_info = ekos.request_subset_info(request)
#       5 ekos.write_test_response('request_subset_info', response_subset_info)
#
# D:\Utveckling\git\ekostat_calculator\event_handler.py in request_subset_info(self, request)
#    1588
#    1589                                     request=request_subset_dict,
# -> 1590                                     include_indicator_settings=True)
#    1591         request['subset'] = response
#    1592
#
# D:\Utveckling\git\ekostat_calculator\event_handler.py in dict_subset(self, workspace_unique_id, subset_unique_id, request, include_indicator_settings)
#     657                                                                      subset_unique_id=subset_unique_id,
#     658                                                                      request=request.get('quality_elements', []),
# --> 659                                                                      include_indicator_settings=include_indicator_settings)
#     660
#     661         # Quality elements
#
# D:\Utveckling\git\ekostat_calculator\event_handler.py in list_quality_elements(self, workspace_unique_id, subset_unique_id, request, include_indicator_settings)
#    1087                                                              quality_element=quality_element,
#    1088                                                              request=request,
# -> 1089                                                              include_indicator_settings=include_indicator_settings)
#    1090
#    1091             return_list.append(quality_element_dict)
#
# D:\Utveckling\git\ekostat_calculator\event_handler.py in dict_quality_element(self, workspace_unique_id, subset_unique_id, quality_element, request, include_indicator_settings)
#     591                                                         quality_element=quality_element,
#     592                                                         request=request_dict,
# --> 593                                                         include_indicator_settings=include_indicator_settings)}
#     594
#     595         return return_dict
#
# D:\Utveckling\git\ekostat_calculator\event_handler.py in list_indicators(self, workspace_unique_id, subset_unique_id, quality_element, request, include_indicator_settings)
#     973                                                  available_indicators=available_indicators,
#     974                                                  request=request_dict,
# --> 975                                                  include_indicator_settings=include_indicator_settings)
#     976
#     977             return_list.append(indicator_dict)
#
# D:\Utveckling\git\ekostat_calculator\event_handler.py in dict_indicator(self, workspace_unique_id, subset_unique_id, indicator, available_indicators, request, include_indicator_settings)
#     400                                                                     subset_unique_id=subset_unique_id,
#     401                                                                     indicator=indicator,
# --> 402                                                                     request=request_list)
#     403 #            if indicator == 'din_winter':
#     404 #                dgfs
#
# D:\Utveckling\git\ekostat_calculator\event_handler.py in list_indicator_settings(self, workspace_unique_id, subset_unique_id, indicator, request)
#    1016                                                                   indicator=indicator,
#    1017                                                                   type_area=type_area,
# -> 1018                                                                   request=request_dict)
#    1019             return_list.append(indicator_settings_dict)
#    1020
#
# D:\Utveckling\git\ekostat_calculator\event_handler.py in dict_indicator_settings(self, workspace_unique_id, subset_unique_id, indicator, type_area, request)
#     510
#     511             # Depth
# --> 512             return_dict['depth_interval'] = settings_data_filter_object.get_value(type_area=type_area, variable='DEPH_INTERVAL')
#     513
#     514             # Month
#
# D:\Utveckling\git\ekostat_calculator\core\filters.py in get_value(self, type_area, variable)
#     795         """
#     796
# --> 797         return self.settings.get_value(variable=variable, type_area=type_area)
#     798
#     799     #==========================================================================
#
# D:\Utveckling\git\ekostat_calculator\core\filters.py in get_value(self, variable, type_area, level)
#     536         print(type_area)
#     537         print(self.df.columns)
# --> 538         num, suf = get_type_area_parts(type_area)
#     539
#     540         if suf:
#
# D:\Utveckling\git\ekostat_calculator\core\filters.py in get_type_area_parts(type_area)
#    1120         suf = ''
#    1121     print('type_area_type_area', type_area)
# -> 1122     return re.findall('\d+', type_area)[0], suf
#    1123
#    1124 ###############################################################################
#
# IndexError: list index out of range

# %%
ekos.return_dict
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-224-f983b827782f> in <module>()
# ----> 1 ekos.return_dict
#
# AttributeError: 'EventHandler' object has no attribute 'return_dict'

# %%
ekos.return_dict
# Out:
# {'depth_interval': [[0, 10]],
#  'min_no_years': ['3'],
#  'month_interval': [[1, 12]]}

# %%
sorted(ekos.mapping_objects['water_body'].get_list('type_area'))
# Out:
# ['10',
#  '11',
#  '12n',
#  '12s',
#  '13',
#  '14',
#  '15',
#  '16',
#  '17',
#  '18',
#  '19',
#  '1n',
#  '1s',
#  '2',
#  '20',
#  '21',
#  '22',
#  '23',
#  '24',
#  '25',
#  '3',
#  '4',
#  '5',
#  '6',
#  '7',
#  '8',
#  '9']

# %%
indicator_settings_object = w.get_indicator_settings_data_filter_object(subset=s_id, 
                                                                                               step='step_2', 
                                                                                               indicator=indicator)

# %%
indicator_settings_object.setting.df
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-231-ab9421e67191> in <module>()
# ----> 1 indicator_settings_object.df
#
# AttributeError: 'SettingsDataFilter' object has no attribute 'df'

# %%
import pandas as pd

# %%
file_path = 'D:/Utveckling/git/ekostat_calculator/workspaces/5cf3719a-9d44-48e0-b228-496a6894d263/input_data/raw_data/physicalchemical_sharkweb_data_None_None-None_20180829.txt'

# %%
df = pd.read_csv(file_path, sep='\t', encoding='cp1252')
# Out:
# C:\Continuum\Anaconda3\envs\EKOSTAT_tool\lib\site-packages\IPython\core\interactiveshell.py:2698: DtypeWarning: Columns (65,83,87,91,95,103) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df.head()
# Out:
#        delivery_datatype check_status_sv       data_checked_by_sv  visit_year  \
# 0  Physical and Chemical            Klar  Leverantör och Datavärd        2014
# 1  Physical and Chemical            Klar  Leverantör och Datavärd        2014
# 2  Physical and Chemical            Klar  Leverantör och Datavärd        2014
# 3  Physical and Chemical            Klar  Leverantör och Datavärd        2014
# 4  Physical and Chemical            Klar  Leverantör och Datavärd        2014
#
#   platform_code  visit_id  expedition_id             station_name  \
# 0          77K9        66            NaN  C3S-SEDIMENTATIONSFÄLLA
# 1          7798      1716            NaN                  REF V2V
# 2          7798      1716            NaN                  REF V2V
# 3          7798      1718            NaN                     V1-V
# 4          7798      1718            NaN                     V1-V
#
#      reported_station_name sample_project_name_sv  \
# 0  C3S-SEDIMENTATIONSFÄLLA     PROJ Ospecificerat
# 1                  REF V2V         REG Kalmar KVK
# 2                  REF V2V         REG Kalmar KVK
# 3                     V1-V         REG Kalmar KVK
# 4                     V1-V         REG Kalmar KVK
#
#                          ...                          \
# 0                        ...
# 1                        ...
# 2                        ...
# 3                        ...
# 4                        ...
#
#   location_helcom_ospar_area location_economic_zone  location_county  \
# 0                     HELCOM   Svensk ekonomisk zon  Utanför gränser
# 1                     HELCOM   Svensk ekonomisk zon       Kalmar län
# 2                     HELCOM   Svensk ekonomisk zon       Kalmar län
# 3                     HELCOM   Svensk ekonomisk zon       Kalmar län
# 4                     HELCOM   Svensk ekonomisk zon       Kalmar län
#
#   location_municipality  station_viss_eu_id reporting_institute_name_sv  \
# 0       Utanför gränser                 NaN            Umeå Universitet
# 1             Västervik                 NaN                  Calluna AB
# 2             Västervik                 NaN                  Calluna AB
# 3             Västervik                 NaN                  Calluna AB
# 4             Västervik                 NaN                  Calluna AB
#
#                                  data_holding_centre  \
# 0  Swedish Meteorological and Hydrological Instit...
# 1  Swedish Meteorological and Hydrological Instit...
# 2  Swedish Meteorological and Hydrological Instit...
# 3  Swedish Meteorological and Hydrological Instit...
# 4  Swedish Meteorological and Hydrological Instit...
#
#                                 internet_access  \
# 0  http://sharkweb.smhi.se, http://sharkdata.se
# 1  http://sharkweb.smhi.se, http://sharkdata.se
# 2  http://sharkweb.smhi.se, http://sharkdata.se
# 3  http://sharkweb.smhi.se, http://sharkdata.se
# 4  http://sharkweb.smhi.se, http://sharkdata.se
#
#                              dataset_name  \
# 0    SHARK_PhysicalChemical_2014_XXX_UMSC
# 1  SHARK_PhysicalChemical_2014_KAL_CALLUN
# 2  SHARK_PhysicalChemical_2014_KAL_CALLUN
# 3  SHARK_PhysicalChemical_2014_KAL_CALLUN
# 4  SHARK_PhysicalChemical_2014_KAL_CALLUN
#
#                                    dataset_file_name
# 0  SHARK_PhysicalChemical_2014_XXX_UMSC_version_2...
# 1  SHARK_PhysicalChemical_2014_KAL_CALLUN_version...
# 2  SHARK_PhysicalChemical_2014_KAL_CALLUN_version...
# 3  SHARK_PhysicalChemical_2014_KAL_CALLUN_version...
# 4  SHARK_PhysicalChemical_2014_KAL_CALLUN_version...
#
# [5 rows x 125 columns]

# %%
def myfunc(x): 
    value = str(x[0]) + str(x[1]) 
    if value == '201477K9':
        print(x['visit_year'])
    return value


df['test'] = df[['visit_year', 'platform_code']].apply(myfunc, axis=1)
# Out:
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014
# 2014

# %%
df['test'].head()
# Out:
# 0    201477K9
# 1    20147798
# 2    20147798
# 3    20147798
# 4    20147798
# Name: test, dtype: object
